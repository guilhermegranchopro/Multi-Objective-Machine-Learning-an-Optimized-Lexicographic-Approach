# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import losses
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Metric
from tensorflow.keras import regularizers
from tensorflow.keras import models
import numpy as np
import logging
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(7)
from sklearn.model_selection import train_test_split
import time
import warnings
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model, clone_model
from sklearn.preprocessing import MinMaxScaler

# %%
# Load training and test datasets.
mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Divida os dados em conjuntos de treinamento e teste
validation_images, test_images, validation_labels, test_labels = train_test_split(test_images, test_labels, test_size=0.5, random_state=42)

# Standardize the data.
mean = np.mean(train_images)
stddev = np.std(train_images)
train_images = (train_images - mean) / stddev
test_images = (test_images - mean) / stddev
validation_images = (validation_images - mean) / stddev

# One-hot encode labels.
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)
validation_labels = to_categorical(validation_labels, num_classes=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
class L2ComplexityMetric(Metric):
    def __init__(self, name='l2_complexity', **kwargs):
        super(L2ComplexityMetric, self).__init__(name=name, **kwargs)
        self.l2_loss = self.add_weight(name='l2_loss', initializer='zeros')
        self.model = None

    def update_state(self, y_true, y_pred, sample_weight=None):
        if self.model is not None:
            # Calcula a perda de complexidade L2 (regularização L2)
            l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])
            self.l2_loss.assign_add(l2_loss)

    def result(self):
        return self.l2_loss

    def reset_state(self):  # Altere o nome deste método para reset_state
        # Zera as variáveis acumuladas no início de cada época ou avaliação
        self.l2_loss.assign(0.0)

# %%
class categorical_crossentropy_loss(tf.keras.losses.Loss):
    def __init__(self, model=None):
        super(categorical_crossentropy_loss, self).__init__()
        self.model = model

    def call(self, y_true, y_pred):
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return ce_loss

# %%
class l2_loss(tf.keras.losses.Loss):
    def __init__(self, model=None):
        super(l2_loss, self).__init__()
        self.model = model

    def call(self, y_true, y_pred):
        l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])
        return l2_loss

# %%
def neural_network():

  # Ignore UserWarning temporarily
  warnings.filterwarnings("ignore", category=UserWarning)
  # Object used to initialize weights.
  initializer = keras.initializers.RandomUniform(minval=-0.1, maxval=0.1)

  # Create a Sequential model.
  # 784 inputs.
  # Two Dense (fully connected) layers with 25 and 10 neurons.
  # tanh as activation function for hidden layer.
  # Logistic (sigmoid) as activation function for output layer.
  model = keras.Sequential([
      keras.layers.Flatten(input_shape=(28, 28)),
      keras.layers.Dense(50, activation='relu',
                        kernel_initializer=initializer,
                        bias_initializer='zeros'),
      keras.layers.Dense(10, activation='softmax',
                        kernel_initializer=initializer,
                        bias_initializer='zeros')])

  return model

# %%
def build_model(model=None):

  if model==None:
    model = neural_network()

  #Instancie a classe de perda personalizada.
  custom_loss = categorical_crossentropy_loss()
  custom_loss.model = model  # Associando o modelo à função de perda.

  # Criar uma instância da métrica personalizada
  l2_metric = L2ComplexityMetric()
  l2_metric.model = model  # Adicione esta linha para passar a referência do modelo para a métrica

  opt = keras.optimizers.Adam()

  model.compile(loss=custom_loss, optimizer = opt, metrics=['categorical_crossentropy', l2_metric, 'accuracy'])

  # Definindo o callback para salvar o melhor modelo
  checkpoint = ModelCheckpoint('best_model.h5', monitor='categorical_crossentropy', verbose=0, save_best_only=True, mode='min')

  return model, checkpoint

# %%
def rebuild_model(model=None):

  if model==None:
    model = neural_network()

  #Instancie a classe de perda personalizada.
  custom_loss = l2_loss()
  custom_loss.model = model  # Associando o modelo à função de perda.

  # Criar uma instância da métrica personalizada
  l2_metric = L2ComplexityMetric()
  l2_metric.model = model  # Adicione esta linha para passar a referência do modelo para a métrica

  opt = keras.optimizers.Adam()

  model.compile(loss=custom_loss, optimizer = opt, metrics=['categorical_crossentropy', l2_metric, 'accuracy'])

  # Definindo o callback para salvar o melhor modelo
  checkpoint = ModelCheckpoint('best_model.h5', monitor='l2_complexity', verbose=0, save_best_only=True, mode='min')

  return model, checkpoint

# %%
def clonning(old_model, changed):

  new_model = clone_model(old_model)
  new_model.set_weights(old_model.get_weights())

  if not changed:
    model, checkpoint = build_model(new_model)
  else:
    model, checkpoint = rebuild_model(new_model)

  return model, checkpoint

# %%
N = 30
tolerances = np.linspace(4.75, 5.2, N, endpoint=True)
training_times, ce_values, l2_values, coordenates_values, accuracy_values, best_ce_loss_values, best_L2_loss_values  = [], [], [], [], [], [], []

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)
for i in range(N):

  best_ce_loss, best_L2_loss  = float('inf'), float('inf')
  upgrading = 0
  tolerance = tolerances[i]
  coordenates = [0, 0]
  changed = False
  first_run = True

  print("model", i+1, "- relative tolerance", tolerance, ":")

  current_model, checkpoint = build_model()
  best_model, checkpoint = build_model()

  start_time = time.time()

  while upgrading < 4:

      current_model, checkpoint = clonning(best_model, changed)
      training_history = current_model.fit(train_images, train_labels, validation_data=(validation_images, validation_labels), epochs=1, batch_size=32, verbose=1, callbacks=[checkpoint])

      current_L2 = training_history.history["val_l2_complexity"][0]
      current_CE = training_history.history["val_categorical_crossentropy"][0]

      if (current_CE<best_ce_loss and not changed) or first_run:
        print("Best so far")
        first_run = False
        coordenates[0] += 1
        best_model, checkpoint = clonning(current_model, changed)
        best_ce_loss = current_CE
        best_L2_loss = current_L2
        upgrading = 0
      elif(current_CE<best_ce_loss*(1 + tolerance) and current_L2<best_L2_loss and changed):
        print("Best so far")
        coordenates[1] += 1
        best_model, checkpoint = clonning(current_model, changed)
        best_L2_loss = current_L2
        upgrading = 2
      else:
        upgrading += 1

      if upgrading==2 and not changed:
        best_model, checkpoint = rebuild_model(best_model)
        current_model, checkpoint = rebuild_model(best_model)
        print("loss function changed")
        changed = True

  end_time = time.time()
  delta_time = end_time - start_time
  training_times.append(delta_time)

  metrics = best_model.evaluate(test_images, test_labels)
  ce_values.append(metrics[1])
  l2_values.append(metrics[2])
  accuracy_values.append(metrics[3])

  coordenates_values.append(coordenates)

  best_ce_loss_values.append(best_ce_loss)
  best_L2_loss_values.append(best_L2_loss)

  print("best categorical cross entropy:", best_ce_loss)
  print("best L2:", best_L2_loss)
  print("training time:", delta_time, "s")
  print("best model coordenates:", coordenates)
  print("\n")
# Out:
# model 1 - relative tolerance 4.75 :
# 1875/1875 [==============================] - 21s 9ms/step - loss: 0.4816 - categorical_crossentropy: 0.4816 - l2_complexity: 174194.4219 - accuracy: 0.8264 - val_loss: 0.4340 - val_categorical_crossentropy: 0.4340 - val_l2_complexity: 17636.5762 - val_accuracy: 0.8466
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3700 - categorical_crossentropy: 0.3700 - l2_complexity: 246368.8438 - accuracy: 0.8644 - val_loss: 0.4028 - val_categorical_crossentropy: 0.4028 - val_l2_complexity: 23460.8535 - val_accuracy: 0.8582
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3342 - categorical_crossentropy: 0.3342 - l2_complexity: 314698.0000 - accuracy: 0.8770 - val_loss: 0.3949 - val_categorical_crossentropy: 0.3949 - val_l2_complexity: 29099.5176 - val_accuracy: 0.8590
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3113 - categorical_crossentropy: 0.3113 - l2_complexity: 382948.0625 - accuracy: 0.8850 - val_loss: 0.3915 - val_categorical_crossentropy: 0.3915 - val_l2_complexity: 34824.6328 - val_accuracy: 0.8644
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2951 - categorical_crossentropy: 0.2951 - l2_complexity: 450769.0625 - accuracy: 0.8920 - val_loss: 0.3889 - val_categorical_crossentropy: 0.3889 - val_l2_complexity: 40461.4766 - val_accuracy: 0.8662
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2818 - categorical_crossentropy: 0.2818 - l2_complexity: 517991.7812 - accuracy: 0.8955 - val_loss: 0.3860 - val_categorical_crossentropy: 0.3860 - val_l2_complexity: 46100.5156 - val_accuracy: 0.8714
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2706 - categorical_crossentropy: 0.2706 - l2_complexity: 585847.4375 - accuracy: 0.9001 - val_loss: 0.3923 - val_categorical_crossentropy: 0.3923 - val_l2_complexity: 51787.8828 - val_accuracy: 0.8690
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2706 - categorical_crossentropy: 0.2706 - l2_complexity: 585847.4375 - accuracy: 0.9001 - val_loss: 0.3923 - val_categorical_crossentropy: 0.3923 - val_l2_complexity: 51787.8828 - val_accuracy: 0.8690
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 13.4451 - categorical_crossentropy: 2.0860 - l2_complexity: 24915.9590 - accuracy: 0.2663 - val_loss: 4.0861e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0064 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 13.4451 - categorical_crossentropy: 2.0860 - l2_complexity: 24915.9590 - accuracy: 0.2663 - val_loss: 4.0861e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0064 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 293.6339 - categorical_crossentropy: 0.3575 - l2_complexity: 46100.5156 - accuracy: 0.8742
# best categorical cross entropy: 0.3860113024711609
# best L2: 46100.515625
# training time: 119.32391691207886 s
# best model coordenates: [6, 0]
#
#
# model 2 - relative tolerance 4.76551724137931 :
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4807 - categorical_crossentropy: 0.4807 - l2_complexity: 173691.4062 - accuracy: 0.8259 - val_loss: 0.4327 - val_categorical_crossentropy: 0.4327 - val_l2_complexity: 17753.8438 - val_accuracy: 0.8486
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3675 - categorical_crossentropy: 0.3675 - l2_complexity: 249632.5156 - accuracy: 0.8657 - val_loss: 0.3978 - val_categorical_crossentropy: 0.3978 - val_l2_complexity: 23895.5000 - val_accuracy: 0.8568
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3324 - categorical_crossentropy: 0.3324 - l2_complexity: 321865.6250 - accuracy: 0.8782 - val_loss: 0.3863 - val_categorical_crossentropy: 0.3863 - val_l2_complexity: 29791.6680 - val_accuracy: 0.8592
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3092 - categorical_crossentropy: 0.3092 - l2_complexity: 390786.0000 - accuracy: 0.8867 - val_loss: 0.3845 - val_categorical_crossentropy: 0.3845 - val_l2_complexity: 35519.9531 - val_accuracy: 0.8608
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2923 - categorical_crossentropy: 0.2923 - l2_complexity: 460084.2188 - accuracy: 0.8924 - val_loss: 0.3811 - val_categorical_crossentropy: 0.3811 - val_l2_complexity: 41308.3555 - val_accuracy: 0.8626
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2791 - categorical_crossentropy: 0.2791 - l2_complexity: 529353.8125 - accuracy: 0.8981 - val_loss: 0.3883 - val_categorical_crossentropy: 0.3883 - val_l2_complexity: 47182.3789 - val_accuracy: 0.8652
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2791 - categorical_crossentropy: 0.2791 - l2_complexity: 529353.8125 - accuracy: 0.8981 - val_loss: 0.3883 - val_categorical_crossentropy: 0.3883 - val_l2_complexity: 47182.3789 - val_accuracy: 0.8652
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.5929 - categorical_crossentropy: 2.0861 - l2_complexity: 21473.5293 - accuracy: 0.3013 - val_loss: 0.0021 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.3239 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 6s 3ms/step - loss: 11.5929 - categorical_crossentropy: 2.0861 - l2_complexity: 21473.5293 - accuracy: 0.3013 - val_loss: 0.0021 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.3239 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 263.1106 - categorical_crossentropy: 0.3594 - l2_complexity: 41308.3555 - accuracy: 0.8734
# best categorical cross entropy: 0.38114094734191895
# best L2: 41308.35546875
# training time: 98.12769770622253 s
# best model coordenates: [5, 0]
#
#
# model 3 - relative tolerance 4.781034482758621 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4800 - categorical_crossentropy: 0.4800 - l2_complexity: 175398.0469 - accuracy: 0.8277 - val_loss: 0.4286 - val_categorical_crossentropy: 0.4286 - val_l2_complexity: 17814.0098 - val_accuracy: 0.8472
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3684 - categorical_crossentropy: 0.3684 - l2_complexity: 249309.9688 - accuracy: 0.8658 - val_loss: 0.3976 - val_categorical_crossentropy: 0.3976 - val_l2_complexity: 23764.3691 - val_accuracy: 0.8570
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3344 - categorical_crossentropy: 0.3344 - l2_complexity: 319511.5312 - accuracy: 0.8770 - val_loss: 0.3830 - val_categorical_crossentropy: 0.3830 - val_l2_complexity: 29618.6406 - val_accuracy: 0.8648
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3120 - categorical_crossentropy: 0.3120 - l2_complexity: 389190.0938 - accuracy: 0.8867 - val_loss: 0.3805 - val_categorical_crossentropy: 0.3805 - val_l2_complexity: 35362.6289 - val_accuracy: 0.8642
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2948 - categorical_crossentropy: 0.2948 - l2_complexity: 457741.0312 - accuracy: 0.8928 - val_loss: 0.3771 - val_categorical_crossentropy: 0.3771 - val_l2_complexity: 41063.4727 - val_accuracy: 0.8694
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2811 - categorical_crossentropy: 0.2811 - l2_complexity: 525329.6875 - accuracy: 0.8965 - val_loss: 0.3755 - val_categorical_crossentropy: 0.3755 - val_l2_complexity: 46737.1094 - val_accuracy: 0.8692
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2695 - categorical_crossentropy: 0.2695 - l2_complexity: 593925.4375 - accuracy: 0.9010 - val_loss: 0.3744 - val_categorical_crossentropy: 0.3744 - val_l2_complexity: 52540.8867 - val_accuracy: 0.8720
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2590 - categorical_crossentropy: 0.2590 - l2_complexity: 663953.8750 - accuracy: 0.9051 - val_loss: 0.3806 - val_categorical_crossentropy: 0.3806 - val_l2_complexity: 58442.7969 - val_accuracy: 0.8724
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2590 - categorical_crossentropy: 0.2590 - l2_complexity: 663953.8750 - accuracy: 0.9051 - val_loss: 0.3806 - val_categorical_crossentropy: 0.3806 - val_l2_complexity: 58442.7969 - val_accuracy: 0.8724
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 17.0571 - categorical_crossentropy: 2.0546 - l2_complexity: 31647.3223 - accuracy: 0.3112 - val_loss: 9.7061e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.1524 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 17.0571 - categorical_crossentropy: 2.0546 - l2_complexity: 31647.3223 - accuracy: 0.3112 - val_loss: 9.7061e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.1524 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 334.6553 - categorical_crossentropy: 0.3553 - l2_complexity: 52540.8867 - accuracy: 0.8740
# best categorical cross entropy: 0.3743726909160614
# best L2: 52540.88671875
# training time: 116.6732280254364 s
# best model coordenates: [7, 0]
#
#
# model 4 - relative tolerance 4.796551724137931 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4819 - categorical_crossentropy: 0.4819 - l2_complexity: 173430.4688 - accuracy: 0.8267 - val_loss: 0.4311 - val_categorical_crossentropy: 0.4311 - val_l2_complexity: 17535.5781 - val_accuracy: 0.8460
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3721 - categorical_crossentropy: 0.3721 - l2_complexity: 245267.8281 - accuracy: 0.8643 - val_loss: 0.3962 - val_categorical_crossentropy: 0.3962 - val_l2_complexity: 23385.7227 - val_accuracy: 0.8604
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3369 - categorical_crossentropy: 0.3369 - l2_complexity: 315301.1562 - accuracy: 0.8765 - val_loss: 0.3823 - val_categorical_crossentropy: 0.3823 - val_l2_complexity: 29179.3027 - val_accuracy: 0.8676
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3137 - categorical_crossentropy: 0.3137 - l2_complexity: 384473.4062 - accuracy: 0.8859 - val_loss: 0.3744 - val_categorical_crossentropy: 0.3744 - val_l2_complexity: 34984.0000 - val_accuracy: 0.8678
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2976 - categorical_crossentropy: 0.2976 - l2_complexity: 454110.5938 - accuracy: 0.8921 - val_loss: 0.3679 - val_categorical_crossentropy: 0.3679 - val_l2_complexity: 40788.9102 - val_accuracy: 0.8710
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2836 - categorical_crossentropy: 0.2836 - l2_complexity: 523789.6250 - accuracy: 0.8968 - val_loss: 0.3693 - val_categorical_crossentropy: 0.3693 - val_l2_complexity: 46656.0273 - val_accuracy: 0.8730
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2836 - categorical_crossentropy: 0.2836 - l2_complexity: 523789.6250 - accuracy: 0.8968 - val_loss: 0.3693 - val_categorical_crossentropy: 0.3693 - val_l2_complexity: 46656.0273 - val_accuracy: 0.8730
# loss function changed
# 1875/1875 [==============================] - 7s 4ms/step - loss: 11.4155 - categorical_crossentropy: 2.1092 - l2_complexity: 21144.2695 - accuracy: 0.2229 - val_loss: 0.0026 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.4040 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 11.4155 - categorical_crossentropy: 2.1092 - l2_complexity: 21144.2695 - accuracy: 0.2229 - val_loss: 0.0026 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.4040 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 259.8020 - categorical_crossentropy: 0.3513 - l2_complexity: 40788.9102 - accuracy: 0.8762
# best categorical cross entropy: 0.36788755655288696
# best L2: 40788.91015625
# training time: 92.41377520561218 s
# best model coordenates: [5, 0]
#
#
# model 5 - relative tolerance 4.812068965517241 :
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4772 - categorical_crossentropy: 0.4772 - l2_complexity: 174604.3906 - accuracy: 0.8276 - val_loss: 0.4230 - val_categorical_crossentropy: 0.4230 - val_l2_complexity: 17662.5293 - val_accuracy: 0.8524
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3671 - categorical_crossentropy: 0.3671 - l2_complexity: 248706.7969 - accuracy: 0.8661 - val_loss: 0.3909 - val_categorical_crossentropy: 0.3909 - val_l2_complexity: 23816.4629 - val_accuracy: 0.8604
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3312 - categorical_crossentropy: 0.3312 - l2_complexity: 322060.3438 - accuracy: 0.8788 - val_loss: 0.3723 - val_categorical_crossentropy: 0.3723 - val_l2_complexity: 29857.5996 - val_accuracy: 0.8710
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3087 - categorical_crossentropy: 0.3087 - l2_complexity: 392934.0000 - accuracy: 0.8865 - val_loss: 0.3649 - val_categorical_crossentropy: 0.3649 - val_l2_complexity: 35697.8086 - val_accuracy: 0.8708
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2923 - categorical_crossentropy: 0.2923 - l2_complexity: 463525.9375 - accuracy: 0.8921 - val_loss: 0.3618 - val_categorical_crossentropy: 0.3618 - val_l2_complexity: 41662.4102 - val_accuracy: 0.8736
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2783 - categorical_crossentropy: 0.2783 - l2_complexity: 535422.4375 - accuracy: 0.8965 - val_loss: 0.3672 - val_categorical_crossentropy: 0.3672 - val_l2_complexity: 47714.5117 - val_accuracy: 0.8720
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2783 - categorical_crossentropy: 0.2783 - l2_complexity: 535422.4375 - accuracy: 0.8965 - val_loss: 0.3672 - val_categorical_crossentropy: 0.3672 - val_l2_complexity: 47714.5117 - val_accuracy: 0.8720
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 11.9218 - categorical_crossentropy: 2.0976 - l2_complexity: 22088.0625 - accuracy: 0.3066 - val_loss: 0.0059 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.9239 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.9218 - categorical_crossentropy: 2.0976 - l2_complexity: 22088.0625 - accuracy: 0.3066 - val_loss: 0.0059 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.9239 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 265.3657 - categorical_crossentropy: 0.3423 - l2_complexity: 41662.4102 - accuracy: 0.8756
# best categorical cross entropy: 0.3617912530899048
# best L2: 41662.41015625
# training time: 89.14358520507812 s
# best model coordenates: [5, 0]
#
#
# model 6 - relative tolerance 4.827586206896552 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4804 - categorical_crossentropy: 0.4804 - l2_complexity: 173943.2500 - accuracy: 0.8273 - val_loss: 0.4343 - val_categorical_crossentropy: 0.4343 - val_l2_complexity: 17647.9785 - val_accuracy: 0.8474
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3719 - categorical_crossentropy: 0.3719 - l2_complexity: 248710.4531 - accuracy: 0.8638 - val_loss: 0.4028 - val_categorical_crossentropy: 0.4028 - val_l2_complexity: 23769.7773 - val_accuracy: 0.8558
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3363 - categorical_crossentropy: 0.3363 - l2_complexity: 321258.1250 - accuracy: 0.8774 - val_loss: 0.3853 - val_categorical_crossentropy: 0.3853 - val_l2_complexity: 29783.7773 - val_accuracy: 0.8650
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3134 - categorical_crossentropy: 0.3134 - l2_complexity: 393599.4375 - accuracy: 0.8859 - val_loss: 0.3832 - val_categorical_crossentropy: 0.3832 - val_l2_complexity: 35803.6211 - val_accuracy: 0.8632
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2972 - categorical_crossentropy: 0.2972 - l2_complexity: 465067.3750 - accuracy: 0.8909 - val_loss: 0.3762 - val_categorical_crossentropy: 0.3762 - val_l2_complexity: 41752.5625 - val_accuracy: 0.8664
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2832 - categorical_crossentropy: 0.2832 - l2_complexity: 537018.6875 - accuracy: 0.8960 - val_loss: 0.3774 - val_categorical_crossentropy: 0.3774 - val_l2_complexity: 47773.5547 - val_accuracy: 0.8676
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2832 - categorical_crossentropy: 0.2832 - l2_complexity: 537018.6875 - accuracy: 0.8960 - val_loss: 0.3774 - val_categorical_crossentropy: 0.3774 - val_l2_complexity: 47773.5547 - val_accuracy: 0.8676
# loss function changed
# 1875/1875 [==============================] - 7s 4ms/step - loss: 11.8683 - categorical_crossentropy: 2.0965 - l2_complexity: 21987.1914 - accuracy: 0.2812 - val_loss: 9.8053e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.1539 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 4ms/step - loss: 11.8683 - categorical_crossentropy: 2.0965 - l2_complexity: 21987.1914 - accuracy: 0.2812 - val_loss: 9.8053e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.1539 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 3ms/step - loss: 265.9399 - categorical_crossentropy: 0.3504 - l2_complexity: 41752.5625 - accuracy: 0.8734
# best categorical cross entropy: 0.37618890404701233
# best L2: 41752.5625
# training time: 84.87553906440735 s
# best model coordenates: [5, 0]
#
#
# model 7 - relative tolerance 4.843103448275862 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4793 - categorical_crossentropy: 0.4793 - l2_complexity: 175272.0312 - accuracy: 0.8279 - val_loss: 0.4377 - val_categorical_crossentropy: 0.4377 - val_l2_complexity: 17846.8984 - val_accuracy: 0.8440
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3652 - categorical_crossentropy: 0.3652 - l2_complexity: 249878.5469 - accuracy: 0.8671 - val_loss: 0.4039 - val_categorical_crossentropy: 0.4039 - val_l2_complexity: 23756.9023 - val_accuracy: 0.8570
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3319 - categorical_crossentropy: 0.3319 - l2_complexity: 319679.1250 - accuracy: 0.8791 - val_loss: 0.3977 - val_categorical_crossentropy: 0.3977 - val_l2_complexity: 29549.0996 - val_accuracy: 0.8614
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3104 - categorical_crossentropy: 0.3104 - l2_complexity: 388400.6562 - accuracy: 0.8853 - val_loss: 0.3849 - val_categorical_crossentropy: 0.3849 - val_l2_complexity: 35280.8359 - val_accuracy: 0.8666
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2939 - categorical_crossentropy: 0.2939 - l2_complexity: 457354.6875 - accuracy: 0.8914 - val_loss: 0.3891 - val_categorical_crossentropy: 0.3891 - val_l2_complexity: 41069.6523 - val_accuracy: 0.8702
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2939 - categorical_crossentropy: 0.2939 - l2_complexity: 457354.6875 - accuracy: 0.8914 - val_loss: 0.3891 - val_categorical_crossentropy: 0.3891 - val_l2_complexity: 41069.6523 - val_accuracy: 0.8702
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.0188 - categorical_crossentropy: 2.1212 - l2_complexity: 16685.6055 - accuracy: 0.2919 - val_loss: 4.3329e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8027e-04 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 9.0188 - categorical_crossentropy: 2.1212 - l2_complexity: 16685.6055 - accuracy: 0.2919 - val_loss: 4.3329e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8027e-04 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 224.7187 - categorical_crossentropy: 0.3696 - l2_complexity: 35280.8359 - accuracy: 0.8660
# best categorical cross entropy: 0.3849388360977173
# best L2: 35280.8359375
# training time: 74.5129930973053 s
# best model coordenates: [4, 0]
#
#
# model 8 - relative tolerance 4.858620689655172 :
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4820 - categorical_crossentropy: 0.4820 - l2_complexity: 172132.8594 - accuracy: 0.8279 - val_loss: 0.4258 - val_categorical_crossentropy: 0.4258 - val_l2_complexity: 17485.3770 - val_accuracy: 0.8528
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3692 - categorical_crossentropy: 0.3692 - l2_complexity: 245364.2031 - accuracy: 0.8662 - val_loss: 0.3927 - val_categorical_crossentropy: 0.3927 - val_l2_complexity: 23482.4375 - val_accuracy: 0.8578
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3334 - categorical_crossentropy: 0.3334 - l2_complexity: 317022.5938 - accuracy: 0.8784 - val_loss: 0.3831 - val_categorical_crossentropy: 0.3831 - val_l2_complexity: 29404.6250 - val_accuracy: 0.8642
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3099 - categorical_crossentropy: 0.3099 - l2_complexity: 387384.0938 - accuracy: 0.8865 - val_loss: 0.3810 - val_categorical_crossentropy: 0.3810 - val_l2_complexity: 35234.4648 - val_accuracy: 0.8632
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2933 - categorical_crossentropy: 0.2933 - l2_complexity: 455516.8750 - accuracy: 0.8929 - val_loss: 0.3845 - val_categorical_crossentropy: 0.3845 - val_l2_complexity: 40872.3711 - val_accuracy: 0.8668
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2933 - categorical_crossentropy: 0.2933 - l2_complexity: 455516.8750 - accuracy: 0.8929 - val_loss: 0.3845 - val_categorical_crossentropy: 0.3845 - val_l2_complexity: 40872.3711 - val_accuracy: 0.8668
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 8.9211 - categorical_crossentropy: 2.1276 - l2_complexity: 16502.5508 - accuracy: 0.2734 - val_loss: 2.6021e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0041 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 4ms/step - loss: 8.9211 - categorical_crossentropy: 2.1276 - l2_complexity: 16502.5508 - accuracy: 0.2734 - val_loss: 2.6021e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0041 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 224.4234 - categorical_crossentropy: 0.3561 - l2_complexity: 35234.4648 - accuracy: 0.8746
# best categorical cross entropy: 0.3810270428657532
# best L2: 35234.46484375
# training time: 78.75828146934509 s
# best model coordenates: [4, 0]
#
#
# model 9 - relative tolerance 4.874137931034483 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4829 - categorical_crossentropy: 0.4829 - l2_complexity: 173209.2969 - accuracy: 0.8271 - val_loss: 0.4280 - val_categorical_crossentropy: 0.4280 - val_l2_complexity: 17545.9473 - val_accuracy: 0.8470
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3701 - categorical_crossentropy: 0.3701 - l2_complexity: 247096.6406 - accuracy: 0.8648 - val_loss: 0.4017 - val_categorical_crossentropy: 0.4017 - val_l2_complexity: 23736.8477 - val_accuracy: 0.8560
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3351 - categorical_crossentropy: 0.3351 - l2_complexity: 318968.3125 - accuracy: 0.8778 - val_loss: 0.3845 - val_categorical_crossentropy: 0.3845 - val_l2_complexity: 29590.7988 - val_accuracy: 0.8640
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3130 - categorical_crossentropy: 0.3130 - l2_complexity: 389089.6250 - accuracy: 0.8849 - val_loss: 0.3806 - val_categorical_crossentropy: 0.3806 - val_l2_complexity: 35414.9336 - val_accuracy: 0.8664
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2961 - categorical_crossentropy: 0.2961 - l2_complexity: 458772.8438 - accuracy: 0.8915 - val_loss: 0.3778 - val_categorical_crossentropy: 0.3778 - val_l2_complexity: 41296.5664 - val_accuracy: 0.8668
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2831 - categorical_crossentropy: 0.2831 - l2_complexity: 529378.8750 - accuracy: 0.8958 - val_loss: 0.3833 - val_categorical_crossentropy: 0.3833 - val_l2_complexity: 47221.4258 - val_accuracy: 0.8656
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2831 - categorical_crossentropy: 0.2831 - l2_complexity: 529378.8750 - accuracy: 0.8958 - val_loss: 0.3833 - val_categorical_crossentropy: 0.3833 - val_l2_complexity: 47221.4258 - val_accuracy: 0.8656
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 11.4430 - categorical_crossentropy: 2.0976 - l2_complexity: 21192.5723 - accuracy: 0.2616 - val_loss: 3.8536e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0061 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 9s 5ms/step - loss: 11.4430 - categorical_crossentropy: 2.0976 - l2_complexity: 21192.5723 - accuracy: 0.2616 - val_loss: 3.8536e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0061 - val_accuracy: 0.1026
# 157/157 [==============================] - 2s 6ms/step - loss: 263.0355 - categorical_crossentropy: 0.3483 - l2_complexity: 41296.5664 - accuracy: 0.8774
# best categorical cross entropy: 0.3777863681316376
# best L2: 41296.56640625
# training time: 92.06701421737671 s
# best model coordenates: [5, 0]
#
#
# model 10 - relative tolerance 4.889655172413793 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4819 - categorical_crossentropy: 0.4819 - l2_complexity: 173227.3281 - accuracy: 0.8267 - val_loss: 0.4286 - val_categorical_crossentropy: 0.4286 - val_l2_complexity: 17536.4707 - val_accuracy: 0.8506
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3709 - categorical_crossentropy: 0.3709 - l2_complexity: 245779.5938 - accuracy: 0.8654 - val_loss: 0.4031 - val_categorical_crossentropy: 0.4031 - val_l2_complexity: 23493.5996 - val_accuracy: 0.8572
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3364 - categorical_crossentropy: 0.3364 - l2_complexity: 315106.4688 - accuracy: 0.8773 - val_loss: 0.3834 - val_categorical_crossentropy: 0.3834 - val_l2_complexity: 29163.1230 - val_accuracy: 0.8660
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3154 - categorical_crossentropy: 0.3154 - l2_complexity: 384157.4062 - accuracy: 0.8850 - val_loss: 0.3820 - val_categorical_crossentropy: 0.3820 - val_l2_complexity: 34991.0312 - val_accuracy: 0.8674
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2981 - categorical_crossentropy: 0.2981 - l2_complexity: 452539.5000 - accuracy: 0.8917 - val_loss: 0.3765 - val_categorical_crossentropy: 0.3765 - val_l2_complexity: 40652.5234 - val_accuracy: 0.8668
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2846 - categorical_crossentropy: 0.2846 - l2_complexity: 521526.8438 - accuracy: 0.8964 - val_loss: 0.3773 - val_categorical_crossentropy: 0.3773 - val_l2_complexity: 46412.5273 - val_accuracy: 0.8686
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.2846 - categorical_crossentropy: 0.2846 - l2_complexity: 521526.8438 - accuracy: 0.8964 - val_loss: 0.3773 - val_categorical_crossentropy: 0.3773 - val_l2_complexity: 46412.5273 - val_accuracy: 0.8686
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.2351 - categorical_crossentropy: 2.1002 - l2_complexity: 20806.9062 - accuracy: 0.2878 - val_loss: 0.0014 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.2239 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 11.2351 - categorical_crossentropy: 2.1002 - l2_complexity: 20806.9062 - accuracy: 0.2878 - val_loss: 0.0014 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.2239 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 258.9333 - categorical_crossentropy: 0.3633 - l2_complexity: 40652.5234 - accuracy: 0.8714
# best categorical cross entropy: 0.37647685408592224
# best L2: 40652.5234375
# training time: 90.92279529571533 s
# best model coordenates: [5, 0]
#
#
# model 11 - relative tolerance 4.905172413793103 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4832 - categorical_crossentropy: 0.4832 - l2_complexity: 174818.5938 - accuracy: 0.8256 - val_loss: 0.4214 - val_categorical_crossentropy: 0.4214 - val_l2_complexity: 17786.6875 - val_accuracy: 0.8480
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3677 - categorical_crossentropy: 0.3677 - l2_complexity: 250192.5781 - accuracy: 0.8655 - val_loss: 0.3935 - val_categorical_crossentropy: 0.3935 - val_l2_complexity: 23902.4297 - val_accuracy: 0.8614
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3311 - categorical_crossentropy: 0.3311 - l2_complexity: 322118.7812 - accuracy: 0.8802 - val_loss: 0.3811 - val_categorical_crossentropy: 0.3811 - val_l2_complexity: 29929.4141 - val_accuracy: 0.8628
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3092 - categorical_crossentropy: 0.3092 - l2_complexity: 393750.3125 - accuracy: 0.8870 - val_loss: 0.3798 - val_categorical_crossentropy: 0.3798 - val_l2_complexity: 35837.0352 - val_accuracy: 0.8672
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2922 - categorical_crossentropy: 0.2922 - l2_complexity: 464537.9375 - accuracy: 0.8935 - val_loss: 0.3802 - val_categorical_crossentropy: 0.3802 - val_l2_complexity: 41763.8359 - val_accuracy: 0.8698
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2922 - categorical_crossentropy: 0.2922 - l2_complexity: 464537.9375 - accuracy: 0.8935 - val_loss: 0.3802 - val_categorical_crossentropy: 0.3802 - val_l2_complexity: 41763.8359 - val_accuracy: 0.8698
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.0589 - categorical_crossentropy: 2.1205 - l2_complexity: 16757.2305 - accuracy: 0.2441 - val_loss: 1.6664e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.6163e-04 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 8s 4ms/step - loss: 9.0589 - categorical_crossentropy: 2.1205 - l2_complexity: 16757.2305 - accuracy: 0.2441 - val_loss: 1.6664e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.6163e-04 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 3ms/step - loss: 228.2614 - categorical_crossentropy: 0.3549 - l2_complexity: 35837.0352 - accuracy: 0.8728
# best categorical cross entropy: 0.37976598739624023
# best L2: 35837.03515625
# training time: 72.70370650291443 s
# best model coordenates: [4, 0]
#
#
# model 12 - relative tolerance 4.9206896551724135 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4803 - categorical_crossentropy: 0.4803 - l2_complexity: 175039.6094 - accuracy: 0.8262 - val_loss: 0.4271 - val_categorical_crossentropy: 0.4271 - val_l2_complexity: 17763.8301 - val_accuracy: 0.8530
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3683 - categorical_crossentropy: 0.3683 - l2_complexity: 251091.2969 - accuracy: 0.8650 - val_loss: 0.3936 - val_categorical_crossentropy: 0.3936 - val_l2_complexity: 23991.0293 - val_accuracy: 0.8602
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3336 - categorical_crossentropy: 0.3336 - l2_complexity: 323958.7188 - accuracy: 0.8768 - val_loss: 0.3873 - val_categorical_crossentropy: 0.3873 - val_l2_complexity: 30013.6719 - val_accuracy: 0.8610
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3125 - categorical_crossentropy: 0.3125 - l2_complexity: 394966.2188 - accuracy: 0.8849 - val_loss: 0.3741 - val_categorical_crossentropy: 0.3741 - val_l2_complexity: 35874.2734 - val_accuracy: 0.8694
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2952 - categorical_crossentropy: 0.2952 - l2_complexity: 465003.8438 - accuracy: 0.8913 - val_loss: 0.3757 - val_categorical_crossentropy: 0.3757 - val_l2_complexity: 41791.4414 - val_accuracy: 0.8704
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2952 - categorical_crossentropy: 0.2952 - l2_complexity: 465003.8438 - accuracy: 0.8913 - val_loss: 0.3757 - val_categorical_crossentropy: 0.3757 - val_l2_complexity: 41791.4414 - val_accuracy: 0.8704
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.3383 - categorical_crossentropy: 2.1275 - l2_complexity: 17280.8965 - accuracy: 0.2150 - val_loss: 1.4662e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0023 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 4ms/step - loss: 9.3383 - categorical_crossentropy: 2.1275 - l2_complexity: 17280.8965 - accuracy: 0.2150 - val_loss: 1.4662e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0023 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 228.4986 - categorical_crossentropy: 0.3529 - l2_complexity: 35874.2734 - accuracy: 0.8734
# best categorical cross entropy: 0.37407955527305603
# best L2: 35874.2734375
# training time: 78.63625383377075 s
# best model coordenates: [4, 0]
#
#
# model 13 - relative tolerance 4.936206896551724 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4824 - categorical_crossentropy: 0.4824 - l2_complexity: 175388.0781 - accuracy: 0.8273 - val_loss: 0.4257 - val_categorical_crossentropy: 0.4257 - val_l2_complexity: 17891.2441 - val_accuracy: 0.8484
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3692 - categorical_crossentropy: 0.3692 - l2_complexity: 251206.4844 - accuracy: 0.8667 - val_loss: 0.3961 - val_categorical_crossentropy: 0.3961 - val_l2_complexity: 24029.6113 - val_accuracy: 0.8534
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3342 - categorical_crossentropy: 0.3342 - l2_complexity: 323291.6562 - accuracy: 0.8779 - val_loss: 0.3814 - val_categorical_crossentropy: 0.3814 - val_l2_complexity: 29950.7949 - val_accuracy: 0.8590
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3115 - categorical_crossentropy: 0.3115 - l2_complexity: 394320.3438 - accuracy: 0.8865 - val_loss: 0.3745 - val_categorical_crossentropy: 0.3745 - val_l2_complexity: 35825.8281 - val_accuracy: 0.8650
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2950 - categorical_crossentropy: 0.2950 - l2_complexity: 464714.6250 - accuracy: 0.8917 - val_loss: 0.3719 - val_categorical_crossentropy: 0.3719 - val_l2_complexity: 41731.5625 - val_accuracy: 0.8690
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2811 - categorical_crossentropy: 0.2811 - l2_complexity: 535770.9375 - accuracy: 0.8967 - val_loss: 0.3658 - val_categorical_crossentropy: 0.3658 - val_l2_complexity: 47713.3320 - val_accuracy: 0.8732
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2694 - categorical_crossentropy: 0.2694 - l2_complexity: 607608.0000 - accuracy: 0.9011 - val_loss: 0.3707 - val_categorical_crossentropy: 0.3707 - val_l2_complexity: 53747.3984 - val_accuracy: 0.8734
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2694 - categorical_crossentropy: 0.2694 - l2_complexity: 607608.0000 - accuracy: 0.9011 - val_loss: 0.3707 - val_categorical_crossentropy: 0.3707 - val_l2_complexity: 53747.3984 - val_accuracy: 0.8734
# loss function changed
# 1875/1875 [==============================] - 10s 4ms/step - loss: 14.4347 - categorical_crossentropy: 2.0795 - l2_complexity: 26761.0957 - accuracy: 0.3433 - val_loss: 3.6707e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0576 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 9s 4ms/step - loss: 14.4347 - categorical_crossentropy: 2.0795 - l2_complexity: 26761.0957 - accuracy: 0.3433 - val_loss: 3.6707e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0576 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 3ms/step - loss: 303.9066 - categorical_crossentropy: 0.3575 - l2_complexity: 47713.3320 - accuracy: 0.8754
# best categorical cross entropy: 0.3658300042152405
# best L2: 47713.33203125
# training time: 100.20051693916321 s
# best model coordenates: [6, 0]
#
#
# model 14 - relative tolerance 4.951724137931034 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4796 - categorical_crossentropy: 0.4796 - l2_complexity: 176331.8906 - accuracy: 0.8269 - val_loss: 0.4253 - val_categorical_crossentropy: 0.4253 - val_l2_complexity: 18009.5117 - val_accuracy: 0.8508
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3647 - categorical_crossentropy: 0.3647 - l2_complexity: 253101.1406 - accuracy: 0.8672 - val_loss: 0.3969 - val_categorical_crossentropy: 0.3969 - val_l2_complexity: 24152.3203 - val_accuracy: 0.8592
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3302 - categorical_crossentropy: 0.3302 - l2_complexity: 324147.8438 - accuracy: 0.8799 - val_loss: 0.3785 - val_categorical_crossentropy: 0.3785 - val_l2_complexity: 29877.9180 - val_accuracy: 0.8646
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3085 - categorical_crossentropy: 0.3085 - l2_complexity: 392389.6562 - accuracy: 0.8869 - val_loss: 0.3668 - val_categorical_crossentropy: 0.3668 - val_l2_complexity: 35546.3359 - val_accuracy: 0.8734
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2923 - categorical_crossentropy: 0.2923 - l2_complexity: 460257.5000 - accuracy: 0.8925 - val_loss: 0.3641 - val_categorical_crossentropy: 0.3641 - val_l2_complexity: 41251.0781 - val_accuracy: 0.8748
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2786 - categorical_crossentropy: 0.2786 - l2_complexity: 528161.7500 - accuracy: 0.8979 - val_loss: 0.3684 - val_categorical_crossentropy: 0.3684 - val_l2_complexity: 46940.7578 - val_accuracy: 0.8754
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2786 - categorical_crossentropy: 0.2786 - l2_complexity: 528161.7500 - accuracy: 0.8979 - val_loss: 0.3684 - val_categorical_crossentropy: 0.3684 - val_l2_complexity: 46940.7578 - val_accuracy: 0.8754
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.5593 - categorical_crossentropy: 2.1012 - l2_complexity: 21410.9512 - accuracy: 0.2476 - val_loss: 5.9465e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0093 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.5593 - categorical_crossentropy: 2.1012 - l2_complexity: 21410.9512 - accuracy: 0.2476 - val_loss: 5.9465e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0093 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 3ms/step - loss: 262.7457 - categorical_crossentropy: 0.3490 - l2_complexity: 41251.0781 - accuracy: 0.8774
# best categorical cross entropy: 0.3641104996204376
# best L2: 41251.078125
# training time: 98.56516599655151 s
# best model coordenates: [5, 0]
#
#
# model 15 - relative tolerance 4.9672413793103445 :
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4847 - categorical_crossentropy: 0.4847 - l2_complexity: 173453.4688 - accuracy: 0.8245 - val_loss: 0.4238 - val_categorical_crossentropy: 0.4238 - val_l2_complexity: 17645.4375 - val_accuracy: 0.8532
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3685 - categorical_crossentropy: 0.3685 - l2_complexity: 249521.1719 - accuracy: 0.8655 - val_loss: 0.3840 - val_categorical_crossentropy: 0.3840 - val_l2_complexity: 23836.7148 - val_accuracy: 0.8624
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3331 - categorical_crossentropy: 0.3331 - l2_complexity: 321688.4375 - accuracy: 0.8779 - val_loss: 0.3756 - val_categorical_crossentropy: 0.3756 - val_l2_complexity: 29782.7988 - val_accuracy: 0.8668
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3110 - categorical_crossentropy: 0.3110 - l2_complexity: 392490.6250 - accuracy: 0.8862 - val_loss: 0.3728 - val_categorical_crossentropy: 0.3728 - val_l2_complexity: 35712.9961 - val_accuracy: 0.8672
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2946 - categorical_crossentropy: 0.2946 - l2_complexity: 462810.5625 - accuracy: 0.8909 - val_loss: 0.3746 - val_categorical_crossentropy: 0.3746 - val_l2_complexity: 41563.6719 - val_accuracy: 0.8684
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2946 - categorical_crossentropy: 0.2946 - l2_complexity: 462810.5625 - accuracy: 0.8909 - val_loss: 0.3746 - val_categorical_crossentropy: 0.3746 - val_l2_complexity: 41563.6719 - val_accuracy: 0.8684
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.1642 - categorical_crossentropy: 2.1271 - l2_complexity: 16955.4512 - accuracy: 0.2688 - val_loss: 6.3488e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0100 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.1642 - categorical_crossentropy: 2.1271 - l2_complexity: 16955.4512 - accuracy: 0.2688 - val_loss: 6.3488e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0100 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 227.4713 - categorical_crossentropy: 0.3524 - l2_complexity: 35712.9961 - accuracy: 0.8708
# best categorical cross entropy: 0.3727567195892334
# best L2: 35712.99609375
# training time: 83.68436980247498 s
# best model coordenates: [4, 0]
#
#
# model 16 - relative tolerance 4.982758620689656 :
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4793 - categorical_crossentropy: 0.4793 - l2_complexity: 173842.7031 - accuracy: 0.8280 - val_loss: 0.4198 - val_categorical_crossentropy: 0.4198 - val_l2_complexity: 17725.2461 - val_accuracy: 0.8540
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3666 - categorical_crossentropy: 0.3666 - l2_complexity: 249254.9531 - accuracy: 0.8671 - val_loss: 0.4026 - val_categorical_crossentropy: 0.4026 - val_l2_complexity: 23794.7012 - val_accuracy: 0.8564
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3316 - categorical_crossentropy: 0.3316 - l2_complexity: 320395.0938 - accuracy: 0.8796 - val_loss: 0.3828 - val_categorical_crossentropy: 0.3828 - val_l2_complexity: 29642.3535 - val_accuracy: 0.8644
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3099 - categorical_crossentropy: 0.3099 - l2_complexity: 390248.8125 - accuracy: 0.8875 - val_loss: 0.3788 - val_categorical_crossentropy: 0.3788 - val_l2_complexity: 35444.5859 - val_accuracy: 0.8674
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2932 - categorical_crossentropy: 0.2932 - l2_complexity: 459407.1250 - accuracy: 0.8937 - val_loss: 0.3824 - val_categorical_crossentropy: 0.3824 - val_l2_complexity: 41202.5039 - val_accuracy: 0.8662
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2932 - categorical_crossentropy: 0.2932 - l2_complexity: 459407.1250 - accuracy: 0.8937 - val_loss: 0.3824 - val_categorical_crossentropy: 0.3824 - val_l2_complexity: 41202.5039 - val_accuracy: 0.8662
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.1060 - categorical_crossentropy: 2.1279 - l2_complexity: 16848.0059 - accuracy: 0.2609 - val_loss: 2.8324e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0445 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.1060 - categorical_crossentropy: 2.1279 - l2_complexity: 16848.0059 - accuracy: 0.2609 - val_loss: 2.8324e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0445 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 2ms/step - loss: 225.7617 - categorical_crossentropy: 0.3514 - l2_complexity: 35444.5859 - accuracy: 0.8742
# best categorical cross entropy: 0.3788467049598694
# best L2: 35444.5859375
# training time: 85.96360492706299 s
# best model coordenates: [4, 0]
#
#
# model 17 - relative tolerance 4.998275862068966 :
# 1875/1875 [==============================] - 15s 5ms/step - loss: 0.4787 - categorical_crossentropy: 0.4787 - l2_complexity: 173911.7656 - accuracy: 0.8281 - val_loss: 0.4262 - val_categorical_crossentropy: 0.4262 - val_l2_complexity: 17633.9902 - val_accuracy: 0.8504
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3684 - categorical_crossentropy: 0.3684 - l2_complexity: 247398.2188 - accuracy: 0.8659 - val_loss: 0.3967 - val_categorical_crossentropy: 0.3967 - val_l2_complexity: 23574.3262 - val_accuracy: 0.8622
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3332 - categorical_crossentropy: 0.3332 - l2_complexity: 317423.1250 - accuracy: 0.8784 - val_loss: 0.3780 - val_categorical_crossentropy: 0.3780 - val_l2_complexity: 29343.6699 - val_accuracy: 0.8662
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3104 - categorical_crossentropy: 0.3104 - l2_complexity: 386439.6250 - accuracy: 0.8864 - val_loss: 0.3671 - val_categorical_crossentropy: 0.3671 - val_l2_complexity: 35053.9336 - val_accuracy: 0.8730
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2938 - categorical_crossentropy: 0.2938 - l2_complexity: 454310.8438 - accuracy: 0.8923 - val_loss: 0.3698 - val_categorical_crossentropy: 0.3698 - val_l2_complexity: 40707.2188 - val_accuracy: 0.8700
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2938 - categorical_crossentropy: 0.2938 - l2_complexity: 454310.8438 - accuracy: 0.8923 - val_loss: 0.3698 - val_categorical_crossentropy: 0.3698 - val_l2_complexity: 40707.2188 - val_accuracy: 0.8700
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 8.9961 - categorical_crossentropy: 2.1184 - l2_complexity: 16644.3496 - accuracy: 0.2896 - val_loss: 3.0984e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0049 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 8.9961 - categorical_crossentropy: 2.1184 - l2_complexity: 16644.3496 - accuracy: 0.2896 - val_loss: 3.0984e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0049 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 3ms/step - loss: 223.2735 - categorical_crossentropy: 0.3474 - l2_complexity: 35053.9336 - accuracy: 0.8772
# best categorical cross entropy: 0.3671324849128723
# best L2: 35053.93359375
# training time: 96.18408107757568 s
# best model coordenates: [4, 0]
#
#
# model 18 - relative tolerance 5.013793103448276 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4771 - categorical_crossentropy: 0.4771 - l2_complexity: 175538.9688 - accuracy: 0.8280 - val_loss: 0.4340 - val_categorical_crossentropy: 0.4340 - val_l2_complexity: 17884.3086 - val_accuracy: 0.8464
# Best so far
# ...
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2826 - categorical_crossentropy: 0.2826 - l2_complexity: 535370.1875 - accuracy: 0.8961 - val_loss: 0.3851 - val_categorical_crossentropy: 0.3851 - val_l2_complexity: 47676.6445 - val_accuracy: 0.8668
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2826 - categorical_crossentropy: 0.2826 - l2_complexity: 535370.1875 - accuracy: 0.8961 - val_loss: 0.3851 - val_categorical_crossentropy: 0.3851 - val_l2_complexity: 47676.6445 - val_accuracy: 0.8668
# loss function changed
# 1875/1875 [==============================] - 7s 4ms/step - loss: 11.8372 - categorical_crossentropy: 2.1008 - l2_complexity: 21929.4082 - accuracy: 0.2803 - val_loss: 9.1781e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.1441 - val_accuracy: 0.1026
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1165e-05 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0200 - accuracy: 0.1006 - val_loss: 3.4125e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.3577e-04 - val_accuracy: 0.1112
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.1783e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0097 - accuracy: 0.1019 - val_loss: 5.3978e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.4746e-04 - val_accuracy: 0.1112
# 1875/1875 [==============================] - 7s 3ms/step - loss: 5.1783e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0097 - accuracy: 0.1019 - val_loss: 5.3978e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.4746e-04 - val_accuracy: 0.1112
# 157/157 [==============================] - 1s 3ms/step - loss: 3.4125e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 5.3577e-04 - accuracy: 0.1064
# best categorical cross entropy: 0.3762165307998657
# best L2: 0.0005357679910957813
# training time: 105.03256630897522 s
# best model coordenates: [5, 2]
#
#
# model 27 - relative tolerance 5.153448275862069 :
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4769 - categorical_crossentropy: 0.4769 - l2_complexity: 172861.6250 - accuracy: 0.8292 - val_loss: 0.4282 - val_categorical_crossentropy: 0.4282 - val_l2_complexity: 17534.8027 - val_accuracy: 0.8482
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3671 - categorical_crossentropy: 0.3671 - l2_complexity: 246324.5312 - accuracy: 0.8665 - val_loss: 0.3914 - val_categorical_crossentropy: 0.3914 - val_l2_complexity: 23550.6113 - val_accuracy: 0.8598
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3318 - categorical_crossentropy: 0.3318 - l2_complexity: 317245.7500 - accuracy: 0.8791 - val_loss: 0.3873 - val_categorical_crossentropy: 0.3873 - val_l2_complexity: 29387.9043 - val_accuracy: 0.8602
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3088 - categorical_crossentropy: 0.3088 - l2_complexity: 386714.1250 - accuracy: 0.8877 - val_loss: 0.3747 - val_categorical_crossentropy: 0.3747 - val_l2_complexity: 35195.1992 - val_accuracy: 0.8684
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2925 - categorical_crossentropy: 0.2925 - l2_complexity: 455945.1875 - accuracy: 0.8932 - val_loss: 0.3792 - val_categorical_crossentropy: 0.3792 - val_l2_complexity: 40961.4844 - val_accuracy: 0.8696
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2925 - categorical_crossentropy: 0.2925 - l2_complexity: 455945.1875 - accuracy: 0.8932 - val_loss: 0.3792 - val_categorical_crossentropy: 0.3792 - val_l2_complexity: 40961.4844 - val_accuracy: 0.8696
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 8.9066 - categorical_crossentropy: 2.1222 - l2_complexity: 16475.7402 - accuracy: 0.2603 - val_loss: 1.5620e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0025 - val_accuracy: 0.1026
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 6.3786e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0119 - accuracy: 0.1010 - val_loss: 2.7442e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.3083e-04 - val_accuracy: 0.1094
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.5822e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0086 - accuracy: 0.0987 - val_loss: 4.3659e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8545e-04 - val_accuracy: 0.0868
# 1875/1875 [==============================] - 11s 4ms/step - loss: 4.5822e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0086 - accuracy: 0.0987 - val_loss: 4.3659e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8545e-04 - val_accuracy: 0.0868
# 157/157 [==============================] - 1s 3ms/step - loss: 2.7442e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 4.3083e-04 - accuracy: 0.1026
# best categorical cross entropy: 0.3746827244758606
# best L2: 0.00043083360651507974
# training time: 113.19130086898804 s
# best model coordenates: [4, 2]
#
#
# model 28 - relative tolerance 5.1689655172413795 :
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4823 - categorical_crossentropy: 0.4823 - l2_complexity: 173421.0938 - accuracy: 0.8267 - val_loss: 0.4357 - val_categorical_crossentropy: 0.4357 - val_l2_complexity: 17430.2305 - val_accuracy: 0.8500
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3718 - categorical_crossentropy: 0.3718 - l2_complexity: 244037.8750 - accuracy: 0.8645 - val_loss: 0.4107 - val_categorical_crossentropy: 0.4107 - val_l2_complexity: 23335.0527 - val_accuracy: 0.8550
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3363 - categorical_crossentropy: 0.3363 - l2_complexity: 314468.7188 - accuracy: 0.8763 - val_loss: 0.3872 - val_categorical_crossentropy: 0.3872 - val_l2_complexity: 29268.0098 - val_accuracy: 0.8630
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3140 - categorical_crossentropy: 0.3140 - l2_complexity: 384104.6875 - accuracy: 0.8847 - val_loss: 0.3824 - val_categorical_crossentropy: 0.3824 - val_l2_complexity: 34937.3398 - val_accuracy: 0.8678
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2967 - categorical_crossentropy: 0.2967 - l2_complexity: 452450.0000 - accuracy: 0.8917 - val_loss: 0.3817 - val_categorical_crossentropy: 0.3817 - val_l2_complexity: 40643.1445 - val_accuracy: 0.8682
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2831 - categorical_crossentropy: 0.2831 - l2_complexity: 521150.5938 - accuracy: 0.8969 - val_loss: 0.3771 - val_categorical_crossentropy: 0.3771 - val_l2_complexity: 46421.3008 - val_accuracy: 0.8734
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2715 - categorical_crossentropy: 0.2715 - l2_complexity: 590585.1875 - accuracy: 0.9001 - val_loss: 0.3835 - val_categorical_crossentropy: 0.3835 - val_l2_complexity: 52216.0312 - val_accuracy: 0.8680
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2715 - categorical_crossentropy: 0.2715 - l2_complexity: 590585.1875 - accuracy: 0.9001 - val_loss: 0.3835 - val_categorical_crossentropy: 0.3835 - val_l2_complexity: 52216.0312 - val_accuracy: 0.8680
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 13.9716 - categorical_crossentropy: 2.0672 - l2_complexity: 25901.1523 - accuracy: 0.3045 - val_loss: 0.0027 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.4231 - val_accuracy: 0.1026
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.6137e-05 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0651 - accuracy: 0.1016 - val_loss: 3.3576e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.2714e-04 - val_accuracy: 0.0956
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 5.8151e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0109 - accuracy: 0.0992 - val_loss: 6.2047e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.7413e-04 - val_accuracy: 0.0508
# 1875/1875 [==============================] - 11s 4ms/step - loss: 5.8151e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0109 - accuracy: 0.0992 - val_loss: 6.2047e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.7413e-04 - val_accuracy: 0.0508
# 157/157 [==============================] - 1s 3ms/step - loss: 3.3576e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 5.2714e-04 - accuracy: 0.1044
# best categorical cross entropy: 0.3770579397678375
# best L2: 0.0005271370173431933
# training time: 122.167729139328 s
# best model coordenates: [6, 2]
#
#
# model 29 - relative tolerance 5.18448275862069 :
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4787 - categorical_crossentropy: 0.4787 - l2_complexity: 175543.3750 - accuracy: 0.8284 - val_loss: 0.4297 - val_categorical_crossentropy: 0.4297 - val_l2_complexity: 17830.0938 - val_accuracy: 0.8498
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3670 - categorical_crossentropy: 0.3670 - l2_complexity: 250378.4062 - accuracy: 0.8658 - val_loss: 0.4029 - val_categorical_crossentropy: 0.4029 - val_l2_complexity: 23952.6211 - val_accuracy: 0.8566
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3330 - categorical_crossentropy: 0.3330 - l2_complexity: 323028.5312 - accuracy: 0.8785 - val_loss: 0.3828 - val_categorical_crossentropy: 0.3828 - val_l2_complexity: 29999.2031 - val_accuracy: 0.8670
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3116 - categorical_crossentropy: 0.3116 - l2_complexity: 393924.6250 - accuracy: 0.8861 - val_loss: 0.3753 - val_categorical_crossentropy: 0.3753 - val_l2_complexity: 35875.7305 - val_accuracy: 0.8706
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2949 - categorical_crossentropy: 0.2949 - l2_complexity: 464645.4062 - accuracy: 0.8926 - val_loss: 0.3735 - val_categorical_crossentropy: 0.3735 - val_l2_complexity: 41803.0938 - val_accuracy: 0.8718
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2815 - categorical_crossentropy: 0.2815 - l2_complexity: 535762.1250 - accuracy: 0.8974 - val_loss: 0.3777 - val_categorical_crossentropy: 0.3777 - val_l2_complexity: 47772.5625 - val_accuracy: 0.8704
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2815 - categorical_crossentropy: 0.2815 - l2_complexity: 535762.1250 - accuracy: 0.8974 - val_loss: 0.3777 - val_categorical_crossentropy: 0.3777 - val_l2_complexity: 47772.5625 - val_accuracy: 0.8704
# loss function changed
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.9351 - categorical_crossentropy: 2.0877 - l2_complexity: 22112.0430 - accuracy: 0.3066 - val_loss: 1.4241e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0224 - val_accuracy: 0.1508
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 7.1129e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0132 - accuracy: 0.1019 - val_loss: 6.6378e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0010 - val_accuracy: 0.1124
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 5.2399e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0098 - accuracy: 0.0995 - val_loss: 5.9642e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.3638e-04 - val_accuracy: 0.0844
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.9102e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0092 - accuracy: 0.1004 - val_loss: 5.8325e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.1570e-04 - val_accuracy: 0.1376
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.8893e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0092 - accuracy: 0.1001 - val_loss: 5.1051e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.0150e-04 - val_accuracy: 0.0316
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 4.7095e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0088 - accuracy: 0.0985 - val_loss: 4.9238e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.7304e-04 - val_accuracy: 0.1020
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.5781e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0086 - accuracy: 0.0985 - val_loss: 5.6446e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.8620e-04 - val_accuracy: 0.1452
# 1875/1875 [==============================] - 8s 4ms/step - loss: 4.5781e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0086 - accuracy: 0.0985 - val_loss: 5.6446e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.8620e-04 - val_accuracy: 0.1452
# 157/157 [==============================] - 1s 3ms/step - loss: 4.9238e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 7.7304e-04 - accuracy: 0.0980
# best categorical cross entropy: 0.37354573607444763
# best L2: 0.0007730351062491536
# training time: 136.70518040657043 s
# best model coordenates: [5, 6]
#
#
# model 30 - relative tolerance 5.2 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4787 - categorical_crossentropy: 0.4787 - l2_complexity: 174282.4375 - accuracy: 0.8292 - val_loss: 0.4328 - val_categorical_crossentropy: 0.4328 - val_l2_complexity: 17731.6328 - val_accuracy: 0.8478
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3664 - categorical_crossentropy: 0.3664 - l2_complexity: 247918.8125 - accuracy: 0.8670 - val_loss: 0.4037 - val_categorical_crossentropy: 0.4037 - val_l2_complexity: 23618.4668 - val_accuracy: 0.8556
# Best so far
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3322 - categorical_crossentropy: 0.3322 - l2_complexity: 317888.6562 - accuracy: 0.8784 - val_loss: 0.3795 - val_categorical_crossentropy: 0.3795 - val_l2_complexity: 29412.8848 - val_accuracy: 0.8696
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3103 - categorical_crossentropy: 0.3103 - l2_complexity: 387492.1875 - accuracy: 0.8867 - val_loss: 0.3689 - val_categorical_crossentropy: 0.3689 - val_l2_complexity: 35210.9961 - val_accuracy: 0.8718
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2941 - categorical_crossentropy: 0.2941 - l2_complexity: 456392.4375 - accuracy: 0.8923 - val_loss: 0.3733 - val_categorical_crossentropy: 0.3733 - val_l2_complexity: 41001.9453 - val_accuracy: 0.8698
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2941 - categorical_crossentropy: 0.2941 - l2_complexity: 456392.4375 - accuracy: 0.8923 - val_loss: 0.3733 - val_categorical_crossentropy: 0.3733 - val_l2_complexity: 41001.9453 - val_accuracy: 0.8698
# loss function changed
# 1875/1875 [==============================] - 7s 4ms/step - loss: 8.8816 - categorical_crossentropy: 2.1316 - l2_complexity: 16428.7402 - accuracy: 0.2467 - val_loss: 1.2629e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.9828e-04 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 9s 4ms/step - loss: 8.8816 - categorical_crossentropy: 2.1316 - l2_complexity: 16428.7402 - accuracy: 0.2467 - val_loss: 1.2629e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.9828e-04 - val_accuracy: 0.1026
# 157/157 [==============================] - 1s 3ms/step - loss: 224.2739 - categorical_crossentropy: 0.3539 - l2_complexity: 35210.9961 - accuracy: 0.8766
# best categorical cross entropy: 0.3688773810863495
# best L2: 35210.99609375
# training time: 79.75743246078491 s
# best model coordenates: [4, 0]

# %%
# Convert the list to a NumPy array for easier manipulation
accuracy_values_array = np.array(accuracy_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(accuracy_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the original data and the running average
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='blue', linestyle=':', label='Running Average')
plt.plot(tolerances, accuracy_values_array, marker='o', color='red', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
ce_values_array = np.array(ce_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(ce_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the original data and the running average
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='blue', linestyle=':', label='Running Average')
plt.plot(tolerances, ce_values_array, marker='o', color='red', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Categorical Crossentropy vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
l2_values_array = np.array(l2_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(l2_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, l2_values_array, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2')
plt.title('Norm L2 vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the lists to NumPy arrays for easier manipulation
ce_values_array = np.array(ce_values)
l2_values_array = np.array(l2_values)

# Normalize the data between 0 and 1
scaler = MinMaxScaler()
ce_normalized = scaler.fit_transform(ce_values_array.reshape(-1, 1)).flatten()
l2_normalized = scaler.fit_transform(l2_values_array.reshape(-1, 1)).flatten()

# Calculate the mean after normalization
mean_normalized = (ce_normalized + l2_normalized) / 2.0

# Find the indices of the three smallest values of mean_normalized
min_indices = np.argsort(mean_normalized)[:3]
min_values = mean_normalized[min_indices]

# Define marcadores para os três pontos mínimos em ordem crescente
markers = ['*', 'x', 'o']

# Plot the combined graph
plt.figure(figsize=(8, 6))

# Plot Categorical Crossentropy
plt.plot(tolerances, ce_normalized, marker='o', color='red', linestyle=':', label='CE Normalized Data')

# Plot Norm L2
plt.plot(tolerances, l2_normalized, marker='o', color='blue', linestyle=':', label='L2 Normalized Data')

# Plot the mean of CE and L2
plt.plot(tolerances, mean_normalized, marker='d', color='m', label='Mean Normalized Data')

# Highlight the points with the three smallest values using different markers
for value, marker in zip(min_values, markers):
    plt.scatter(tolerances[min_indices[np.where(min_values == value)]], value, color='black', zorder=5, marker=marker)

# Create legend labels for the three smallest values
legend_labels_min_values = [f'Min Value {min_indices[i]+1}: {min_values[i]:.2f} ' for i in range(3)]

# Create legend labels including the values of the three smallest mean_normalized
legend_labels = ['CE Normalized Data', 'L2 Normalized Data', 'Mean Normalized Data']
legend_labels.extend(legend_labels_min_values)

plt.xlabel('Relative Tolerance')
plt.ylabel('Normalized Values')
plt.title('Normalized Categorical Crossentropy, Norm L2, and Mean vs Relative Tolerance')

# Adjust legend position to be outside the plot
plt.legend(legend_labels, loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
# Valores de x e y
x_values = tolerances
y1_values = best_ce_loss_values
y2_values = ce_values

# Plotar o gráfico de pontos
plt.plot(x_values, y1_values, 'bo', label='Best Value')
plt.plot(x_values, y2_values, 'ro', label='Final Value')

# Conectar os pontos com uma linha
for i in range(len(x_values)):
    if y2_values[i] > y1_values[i]:
        plt.plot([x_values[i], x_values[i]], [y1_values[i], y2_values[i]], 'r--')
    elif y2_values[i] < y1_values[i]:
        plt.plot([x_values[i], x_values[i]], [y1_values[i], y2_values[i]], 'g--')

plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Variação da Categorical Crossentropy Durante a Otimização da Norma L2 Vs Tolerância Relativa')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
training_times_array = np.array(training_times)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(training_times_array, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, training_times_array, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Gerando pontos 3D
x = np.array([point[0] for point in coordenates_values])
y = np.array([point[1] for point in coordenates_values])
z = np.array(tolerances)

# Definindo cores com base na tolerância (ou qualquer outra variável)
colors = z

# Plotando
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x, y, z, c=colors, cmap='plasma')  # Usando cmap='plasma' para um gradiente de cores diferente

plt.title('Número de épocas para encontrar o melhor valor vs Tolerancia Relativa')
ax.set_xlabel('Categorical Crossentropy')
ax.set_ylabel('Norma L2')
ax.set_zlabel('Tolerância Relativa')

# Definindo intervalos para os eixos x e y
ax.set_xticks(np.arange(min(x), max(x)+1, 1))
ax.set_yticks(np.arange(min(y), max(y)+1, 1))

# Adicionando barra de cores
plt.colorbar(sc, label='Tolerância Relativa')

plt.show()

# %%
# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(x, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, x, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(y, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, y, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
sum = x + y

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(sum, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, sum, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2 + Categorical Crossentropy')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
def sort_models(CE, L2, Time, Tol, AC, min_indices):
    num_models = len(CE)
    decimal_places = 2

    while True:
        # Ordenar os modelos de acordo com a Categorical Crossentropy
        indices = sorted(range(num_models), key=lambda i: (round(CE[i], decimal_places), round(L2[i], decimal_places), round(Time[i], decimal_places)))

        # Verificar se há empates
        is_tie = False
        for i in range(1, num_models):
            if CE[indices[i]] == CE[indices[i - 1]] and \
               L2[indices[i]] == L2[indices[i - 1]] and \
               Time[indices[i]] == Time[indices[i - 1]]:
                is_tie = True
                break

        # Se não houver empates, terminar o loop
        if not is_tie:
            break

        # Aumentar as casas decimais em caso de empate
        decimal_places += 1

    # Imprimir os modelos ordenados
    for i, idx in enumerate(indices):
        print(f'{i+1}º:')
        print(f' - Model {min_indices[idx]+1}: (Relative Tolerance={Tol[idx]}; Accuracy={AC[idx]})')
        print(f'   + Categorical Crossentropy: {CE[idx]}')
        print(f'   + Norm L2: {L2[idx]}')
        print(f'   + Training Time (seconds): {Time[idx]}')
        print()

    return Tol[0]

# %%
CE, L2, Time, Tol, AC = [], [], [], [], []

for i in range(len(min_indices)):
 CE.append(ce_values_array[min_indices[i]])
 L2.append(l2_values_array[min_indices[i]])
 Time.append(training_times_array[min_indices[i]])
 Tol.append(tolerances[min_indices[i]])
 AC.append(accuracy_values_array[min_indices[i]])

Best_Tolerance = sort_models(CE, L2, Time, Tol, AC, min_indices)
# Out:
# 1º:
#  - Model 17: (Relative Tolerance=4.998275862068966; Accuracy=0.8772000074386597)
#    + Categorical Crossentropy: 0.3474271595478058
#    + Norm L2: 35053.93359375
#    + Training Time (seconds): 96.18408107757568
#
# 2º:
#  - Model 30: (Relative Tolerance=5.2; Accuracy=0.8766000270843506)
#    + Categorical Crossentropy: 0.3538631200790405
#    + Norm L2: 35210.99609375
#    + Training Time (seconds): 79.75743246078491
#
# 3º:
#  - Model 8: (Relative Tolerance=4.858620689655172; Accuracy=0.8745999932289124)
#    + Categorical Crossentropy: 0.3560515344142914
#    + Norm L2: 35234.46484375
#    + Training Time (seconds): 78.75828146934509

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)

best_ce_loss, best_L2_loss  = float('inf'), float('inf')
upgrading = 0
tolerance = Best_Tolerance
changed = False
first_run = True

current_model, checkpoint = build_model()
best_model, checkpoint = build_model()

while upgrading < 4:

    current_model, checkpoint = clonning(best_model, changed)
    training_history = current_model.fit(train_images, train_labels, validation_data=(validation_images, validation_labels), epochs=1, batch_size=32, verbose=1, callbacks=[checkpoint])

    current_L2 = training_history.history["val_l2_complexity"][0]
    current_CE = training_history.history["val_categorical_crossentropy"][0]

    if (current_CE<best_ce_loss and not changed) or first_run:
      print("Best so far")
      first_run = False
      coordenates[0] += 1
      best_model, checkpoint = clonning(current_model, changed)
      best_ce_loss = current_CE
      best_L2_loss = current_L2
      upgrading = 0
    elif(current_CE<best_ce_loss*(1 + tolerance) and current_L2<best_L2_loss and changed):
      print("Best so far")
      coordenates[1] += 1
      best_model, checkpoint = clonning(current_model, changed)
      best_L2_loss = current_L2
      upgrading = 2
    else:
      upgrading += 1

    if upgrading==2 and not changed:
      best_model, checkpoint = rebuild_model(best_model)
      current_model, checkpoint = rebuild_model(best_model)
      print("loss function changed")
      changed = True
# Out:
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4770 - categorical_crossentropy: 0.4770 - l2_complexity: 174403.3281 - accuracy: 0.8278 - val_loss: 0.4221 - val_categorical_crossentropy: 0.4221 - val_l2_complexity: 17728.5957 - val_accuracy: 0.8510
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3677 - categorical_crossentropy: 0.3677 - l2_complexity: 247987.0312 - accuracy: 0.8662 - val_loss: 0.3913 - val_categorical_crossentropy: 0.3913 - val_l2_complexity: 23637.7246 - val_accuracy: 0.8592
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3331 - categorical_crossentropy: 0.3331 - l2_complexity: 317874.1250 - accuracy: 0.8777 - val_loss: 0.3799 - val_categorical_crossentropy: 0.3799 - val_l2_complexity: 29414.1777 - val_accuracy: 0.8686
# Best so far
# 1875/1875 [==============================] - 11s 4ms/step - loss: 0.3112 - categorical_crossentropy: 0.3112 - l2_complexity: 386475.9062 - accuracy: 0.8856 - val_loss: 0.3694 - val_categorical_crossentropy: 0.3694 - val_l2_complexity: 35137.6172 - val_accuracy: 0.8732
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2938 - categorical_crossentropy: 0.2938 - l2_complexity: 454604.5312 - accuracy: 0.8915 - val_loss: 0.3729 - val_categorical_crossentropy: 0.3729 - val_l2_complexity: 40850.2461 - val_accuracy: 0.8740
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2938 - categorical_crossentropy: 0.2938 - l2_complexity: 454604.5312 - accuracy: 0.8915 - val_loss: 0.3729 - val_categorical_crossentropy: 0.3729 - val_l2_complexity: 40850.2461 - val_accuracy: 0.8740
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 8.8058 - categorical_crossentropy: 2.1353 - l2_complexity: 16287.1484 - accuracy: 0.2375 - val_loss: 1.0323e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.6207e-04 - val_accuracy: 0.1026
# 1875/1875 [==============================] - 7s 3ms/step - loss: 8.8058 - categorical_crossentropy: 2.1353 - l2_complexity: 16287.1484 - accuracy: 0.2375 - val_loss: 1.0323e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.6207e-04 - val_accuracy: 0.1026

# %%
metrics = best_model.evaluate(test_images, test_labels)
# Out:
# 157/157 [==============================] - 1s 4ms/step - loss: 223.8065 - categorical_crossentropy: 0.3447 - l2_complexity: 35137.6172 - accuracy: 0.8756

# %%
best_model.save('best_model.h5')
