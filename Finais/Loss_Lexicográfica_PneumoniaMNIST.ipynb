# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import losses
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Metric
from tensorflow.keras import regularizers
from tensorflow.keras import models
import numpy as np
import logging
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(7)
from sklearn.model_selection import train_test_split
import time
import warnings
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model, clone_model
from sklearn.preprocessing import MinMaxScaler

# %%
# !pip install medmnist
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.19.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medmnist) (4.66.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medmnist) (9.4.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.17.1+cu121)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2024.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (24.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->medmnist)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 21.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->medmnist)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 31.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->medmnist)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 25.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->medmnist)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->medmnist)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.9 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->medmnist)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->medmnist)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->medmnist)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->medmnist)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->medmnist)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->medmnist)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->medmnist)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->medmnist) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->medmnist) (1.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=715873180b911a3404eede2da93a99df67ff15bd3838528ebd336928a781674c
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fire, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, medmnist
# Successfully installed fire-0.6.0 medmnist-3.0.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
from medmnist import PneumoniaMNIST

# Carregar o conjunto de dados de treinamento com download automático ativado
train_dataset = PneumoniaMNIST(split="train", download=True)

# Acessar todos os dados de treinamento
train_images, train_labels = [], []
for i in range(len(train_dataset)):
    image, label = train_dataset[i]
    train_images.append(image)
    train_labels.append(label)

# Carregar o conjunto de dados de validação com download automático ativado
val_dataset = PneumoniaMNIST(split="val", download=True)

# Acessar todos os dados de validação
validation_images, validation_labels = [], []
for i in range(len(val_dataset)):
    image, label = val_dataset[i]
    validation_images.append(image)
    validation_labels.append(label)

# Carregar o conjunto de dados de teste com download automático ativado
test_dataset = PneumoniaMNIST(split="test", download=True)

# Acessar todos os dados de teste
test_images, test_labels = [], []
for i in range(len(test_dataset)):
    image, label = test_dataset[i]
    test_images.append(image)
    test_labels.append(label)
# Out:
# Downloading https://zenodo.org/records/10519652/files/pneumoniamnist.npz?download=1 to /root/.medmnist/pneumoniamnist.npz
# 100%|██████████| 4170669/4170669 [00:00<00:00, 4935420.11it/s]
# Using downloaded and verified file: /root/.medmnist/pneumoniamnist.npz
# Using downloaded and verified file: /root/.medmnist/pneumoniamnist.npz

# %%
train_dataset.montage()
# Out:
# /usr/local/lib/python3.10/dist-packages/medmnist/utils.py:32: FutureWarning: `multichannel` is a deprecated argument name for `montage`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   montage_arr = skimage_montage(sel_img, multichannel=(n_channels == 3))
# <PIL.Image.Image image mode=L size=560x560>

# %%
# Standardize the data.
mean = np.mean(train_images)
stddev = np.std(train_images)
train_images = (train_images - mean) / stddev
test_images = (test_images - mean) / stddev
validation_images = (validation_images - mean) / stddev

# One-hot encode labels.
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)
validation_labels = to_categorical(validation_labels, num_classes=10)

# %%
class L2ComplexityMetric(Metric):
    def __init__(self, name='l2_complexity', **kwargs):
        super(L2ComplexityMetric, self).__init__(name=name, **kwargs)
        self.l2_loss = self.add_weight(name='l2_loss', initializer='zeros')
        self.model = None

    def update_state(self, y_true, y_pred, sample_weight=None):
        if self.model is not None:
            # Calcula a perda de complexidade L2 (regularização L2)
            l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])
            self.l2_loss.assign_add(l2_loss)

    def result(self):
        return self.l2_loss

    def reset_state(self):  # Altere o nome deste método para reset_state
        # Zera as variáveis acumuladas no início de cada época ou avaliação
        self.l2_loss.assign(0.0)

# %%
class categorical_crossentropy_loss(tf.keras.losses.Loss):
    def __init__(self, model=None):
        super(categorical_crossentropy_loss, self).__init__()
        self.model = model

    def call(self, y_true, y_pred):
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return ce_loss

# %%
class l2_loss(tf.keras.losses.Loss):
    def __init__(self, model=None):
        super(l2_loss, self).__init__()
        self.model = model

    def call(self, y_true, y_pred):
        l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])
        return l2_loss

# %%
def neural_network():

  # Ignore UserWarning temporarily
  warnings.filterwarnings("ignore", category=UserWarning)
  # Object used to initialize weights.
  initializer = keras.initializers.RandomUniform(minval=-0.1, maxval=0.1)

  # Create a Sequential model.
  # 784 inputs.
  # Two Dense (fully connected) layers with 25 and 10 neurons.
  # tanh as activation function for hidden layer.
  # Logistic (sigmoid) as activation function for output layer.
  model = keras.Sequential([
      keras.layers.Flatten(input_shape=(28, 28)),
      keras.layers.Dense(50, activation='relu',
                        kernel_initializer=initializer,
                        bias_initializer='zeros'),
      keras.layers.Dense(10, activation='softmax',
                        kernel_initializer=initializer,
                        bias_initializer='zeros')])

  return model

# %%
def build_model(model=None):

  if model==None:
    model = neural_network()

  #Instancie a classe de perda personalizada.
  custom_loss = categorical_crossentropy_loss()
  custom_loss.model = model  # Associando o modelo à função de perda.

  # Criar uma instância da métrica personalizada
  l2_metric = L2ComplexityMetric()
  l2_metric.model = model  # Adicione esta linha para passar a referência do modelo para a métrica

  opt = keras.optimizers.Adam()

  model.compile(loss=custom_loss, optimizer = opt, metrics=['categorical_crossentropy', l2_metric, 'accuracy'])

  # Definindo o callback para salvar o melhor modelo
  checkpoint = ModelCheckpoint('best_model.h5', monitor='categorical_crossentropy', verbose=0, save_best_only=True, mode='min')

  return model, checkpoint

# %%
def rebuild_model(model=None):

  if model==None:
    model = neural_network()

  #Instancie a classe de perda personalizada.
  custom_loss = l2_loss()
  custom_loss.model = model  # Associando o modelo à função de perda.

  # Criar uma instância da métrica personalizada
  l2_metric = L2ComplexityMetric()
  l2_metric.model = model  # Adicione esta linha para passar a referência do modelo para a métrica

  opt = keras.optimizers.Adam()

  model.compile(loss=custom_loss, optimizer = opt, metrics=['categorical_crossentropy', l2_metric, 'accuracy'])

  # Definindo o callback para salvar o melhor modelo
  checkpoint = ModelCheckpoint('best_model.h5', monitor='l2_complexity', verbose=0, save_best_only=True, mode='min')

  return model, checkpoint

# %%
def clonning(old_model, changed):

  new_model = clone_model(old_model)
  new_model.set_weights(old_model.get_weights())

  if not changed:
    model, checkpoint = build_model(new_model)
  else:
    model, checkpoint = rebuild_model(new_model)

  return model, checkpoint

# %%
N = 33
tolerances = np.linspace(14.3, 16.5, N, endpoint=True)
training_times, ce_values, l2_values, coordenates_values, accuracy_values, best_ce_loss_values, best_L2_loss_values  = [], [], [], [], [], [], []

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)
for i in range(N):

  best_ce_loss, best_L2_loss  = float('inf'), float('inf')
  upgrading = 0
  tolerance = tolerances[i]
  coordenates = [0, 0]
  changed = False
  first_run = True

  print("model", i+1, "- relative tolerance", tolerance, ":")

  current_model, checkpoint = build_model()
  best_model, checkpoint = build_model()

  start_time = time.time()

  while upgrading < 4:

      current_model, checkpoint = clonning(best_model, changed)
      training_history = current_model.fit(train_images, train_labels, validation_data=(validation_images, validation_labels), epochs=1, batch_size=32, verbose=1, callbacks=[checkpoint])

      current_L2 = training_history.history["val_l2_complexity"][0]
      current_CE = training_history.history["val_categorical_crossentropy"][0]

      if (current_CE<best_ce_loss and not changed) or first_run:
        print("Best so far")
        first_run = False
        coordenates[0] += 1
        best_model, checkpoint = clonning(current_model, changed)
        best_ce_loss = current_CE
        best_L2_loss = current_L2
        upgrading = 0
      elif(current_CE<best_ce_loss*(1 + tolerance) and current_L2<best_L2_loss and changed):
        print("Best so far")
        coordenates[1] += 1
        best_model, checkpoint = clonning(current_model, changed)
        best_L2_loss = current_L2
        upgrading = 2
      else:
        upgrading += 1

      if upgrading==2 and not changed:
        best_model, checkpoint = rebuild_model(best_model)
        current_model, checkpoint = rebuild_model(best_model)
        print("loss function changed")
        changed = True

  end_time = time.time()
  delta_time = end_time - start_time
  training_times.append(delta_time)

  metrics = best_model.evaluate(test_images, test_labels)
  ce_values.append(metrics[1])
  l2_values.append(metrics[2])
  accuracy_values.append(metrics[3])

  coordenates_values.append(coordenates)

  best_ce_loss_values.append(best_ce_loss)
  best_L2_loss_values.append(best_L2_loss)

  print("best categorical cross entropy:", best_ce_loss)
  print("best L2:", best_L2_loss)
  print("training time:", delta_time, "s")
  print("best model coordenates:", coordenates)
  print("\n")
# Out:
# model 1 - relative tolerance 14.3 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2355 - categorical_crossentropy: 0.2355 - l2_complexity: 10315.0811 - accuracy: 0.9191 - val_loss: 0.1337 - val_categorical_crossentropy: 0.1337 - val_l2_complexity: 1205.7080 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1303 - categorical_crossentropy: 0.1303 - l2_complexity: 10700.6406 - accuracy: 0.9516 - val_loss: 0.1336 - val_categorical_crossentropy: 0.1336 - val_l2_complexity: 1250.4580 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 5ms/step - loss: 0.1158 - categorical_crossentropy: 0.1158 - l2_complexity: 11131.7451 - accuracy: 0.9575 - val_loss: 0.1370 - val_categorical_crossentropy: 0.1370 - val_l2_complexity: 1303.1473 - val_accuracy: 0.9447
# 148/148 [==============================] - 2s 6ms/step - loss: 0.1158 - categorical_crossentropy: 0.1158 - l2_complexity: 11131.7451 - accuracy: 0.9575 - val_loss: 0.1370 - val_categorical_crossentropy: 0.1370 - val_l2_complexity: 1303.1473 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 2s 4ms/step - loss: 15.7819 - categorical_crossentropy: 1.0157 - l2_complexity: 2249.0796 - accuracy: 0.9577 - val_loss: 0.3816 - val_categorical_crossentropy: 2.1814 - val_l2_complexity: 6.4868 - val_accuracy: 0.9637
# 148/148 [==============================] - 2s 5ms/step - loss: 15.7819 - categorical_crossentropy: 1.0157 - l2_complexity: 2249.0796 - accuracy: 0.9577 - val_loss: 0.3816 - val_categorical_crossentropy: 2.1814 - val_l2_complexity: 6.4868 - val_accuracy: 0.9637
# 20/20 [==============================] - 0s 2ms/step - loss: 73.5564 - categorical_crossentropy: 0.4738 - l2_complexity: 1471.1272 - accuracy: 0.8718
# best categorical cross entropy: 0.13358646631240845
# best L2: 1250.4580078125
# training time: 10.47817087173462 s
# best model coordenates: [2, 0]
#
#
# model 2 - relative tolerance 14.36875 :
# 148/148 [==============================] - 2s 4ms/step - loss: 0.2631 - categorical_crossentropy: 0.2631 - l2_complexity: 10378.9033 - accuracy: 0.9063 - val_loss: 0.1362 - val_categorical_crossentropy: 0.1362 - val_l2_complexity: 1212.9768 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 2s 6ms/step - loss: 0.1290 - categorical_crossentropy: 0.1290 - l2_complexity: 10773.9395 - accuracy: 0.9522 - val_loss: 0.1373 - val_categorical_crossentropy: 0.1373 - val_l2_complexity: 1261.6754 - val_accuracy: 0.9427
# 148/148 [==============================] - 2s 11ms/step - loss: 0.1290 - categorical_crossentropy: 0.1290 - l2_complexity: 10773.9395 - accuracy: 0.9522 - val_loss: 0.1373 - val_categorical_crossentropy: 0.1373 - val_l2_complexity: 1261.6754 - val_accuracy: 0.9427
# loss function changed
# 148/148 [==============================] - 2s 6ms/step - loss: 14.8803 - categorical_crossentropy: 1.2463 - l2_complexity: 2118.4241 - accuracy: 0.8173 - val_loss: 0.2666 - val_categorical_crossentropy: 2.2583 - val_l2_complexity: 4.5329 - val_accuracy: 0.5534
# 148/148 [==============================] - 2s 6ms/step - loss: 14.8803 - categorical_crossentropy: 1.2463 - l2_complexity: 2118.4241 - accuracy: 0.8173 - val_loss: 0.2666 - val_categorical_crossentropy: 2.2583 - val_l2_complexity: 4.5329 - val_accuracy: 0.5534
# 20/20 [==============================] - 0s 1ms/step - loss: 71.3516 - categorical_crossentropy: 0.4529 - l2_complexity: 1427.0315 - accuracy: 0.8606
# best categorical cross entropy: 0.13617533445358276
# best L2: 1212.976806640625
# training time: 10.75434684753418 s
# best model coordenates: [1, 0]
#
#
# model 3 - relative tolerance 14.4375 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2522 - categorical_crossentropy: 0.2522 - l2_complexity: 10293.0156 - accuracy: 0.9110 - val_loss: 0.1471 - val_categorical_crossentropy: 0.1471 - val_l2_complexity: 1203.5801 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1300 - categorical_crossentropy: 0.1300 - l2_complexity: 10702.2178 - accuracy: 0.9511 - val_loss: 0.1478 - val_categorical_crossentropy: 0.1478 - val_l2_complexity: 1250.6105 - val_accuracy: 0.9447
# 148/148 [==============================] - 2s 3ms/step - loss: 0.1300 - categorical_crossentropy: 0.1300 - l2_complexity: 10702.2178 - accuracy: 0.9511 - val_loss: 0.1478 - val_categorical_crossentropy: 0.1478 - val_l2_complexity: 1250.6105 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.6825 - categorical_crossentropy: 1.2314 - l2_complexity: 2089.8442 - accuracy: 0.8583 - val_loss: 0.2547 - val_categorical_crossentropy: 2.2496 - val_l2_complexity: 4.3300 - val_accuracy: 0.7004
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0106 - categorical_crossentropy: 2.3012 - l2_complexity: 1.3018 - accuracy: 0.1944 - val_loss: 2.5732e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.3744e-07 - val_accuracy: 0.2576
# 148/148 [==============================] - 1s 4ms/step - loss: 0.0106 - categorical_crossentropy: 2.3012 - l2_complexity: 1.3018 - accuracy: 0.1944 - val_loss: 2.5732e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.3744e-07 - val_accuracy: 0.2576
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2547 - categorical_crossentropy: 2.2490 - l2_complexity: 5.0941 - accuracy: 0.7644
# best categorical cross entropy: 0.14706076681613922
# best L2: 4.330013275146484
# training time: 7.25862979888916 s
# best model coordenates: [1, 1]
#
#
# model 4 - relative tolerance 14.506250000000001 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2351 - categorical_crossentropy: 0.2351 - l2_complexity: 10395.1309 - accuracy: 0.9167 - val_loss: 0.1410 - val_categorical_crossentropy: 0.1410 - val_l2_complexity: 1214.0475 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1322 - categorical_crossentropy: 0.1322 - l2_complexity: 10771.3926 - accuracy: 0.9505 - val_loss: 0.1423 - val_categorical_crossentropy: 0.1423 - val_l2_complexity: 1256.4076 - val_accuracy: 0.9427
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1322 - categorical_crossentropy: 0.1322 - l2_complexity: 10771.3926 - accuracy: 0.9505 - val_loss: 0.1423 - val_categorical_crossentropy: 0.1423 - val_l2_complexity: 1256.4076 - val_accuracy: 0.9427
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8527 - categorical_crossentropy: 1.2859 - l2_complexity: 2114.2607 - accuracy: 0.7487 - val_loss: 0.2499 - val_categorical_crossentropy: 2.2594 - val_l2_complexity: 4.2478 - val_accuracy: 0.4618
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8527 - categorical_crossentropy: 1.2859 - l2_complexity: 2114.2607 - accuracy: 0.7487 - val_loss: 0.2499 - val_categorical_crossentropy: 2.2594 - val_l2_complexity: 4.2478 - val_accuracy: 0.4618
# 20/20 [==============================] - 0s 2ms/step - loss: 71.4146 - categorical_crossentropy: 0.4995 - l2_complexity: 1428.2911 - accuracy: 0.8429
# best categorical cross entropy: 0.14098455011844635
# best L2: 1214.0474853515625
# training time: 5.195143699645996 s
# best model coordenates: [1, 0]
#
#
# model 5 - relative tolerance 14.575000000000001 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2291 - categorical_crossentropy: 0.2291 - l2_complexity: 10268.8906 - accuracy: 0.9150 - val_loss: 0.1356 - val_categorical_crossentropy: 0.1356 - val_l2_complexity: 1200.1725 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1272 - categorical_crossentropy: 0.1272 - l2_complexity: 10650.5596 - accuracy: 0.9501 - val_loss: 0.1440 - val_categorical_crossentropy: 0.1440 - val_l2_complexity: 1246.9407 - val_accuracy: 0.9370
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1272 - categorical_crossentropy: 0.1272 - l2_complexity: 10650.5596 - accuracy: 0.9501 - val_loss: 0.1440 - val_categorical_crossentropy: 0.1440 - val_l2_complexity: 1246.9407 - val_accuracy: 0.9370
# loss function changed
# 148/148 [==============================] - 1s 4ms/step - loss: 14.5980 - categorical_crossentropy: 1.2245 - l2_complexity: 2077.6077 - accuracy: 0.8836 - val_loss: 0.2446 - val_categorical_crossentropy: 2.2537 - val_l2_complexity: 4.1589 - val_accuracy: 0.8531
# 148/148 [==============================] - 1s 3ms/step - loss: 14.5980 - categorical_crossentropy: 1.2245 - l2_complexity: 2077.6077 - accuracy: 0.8836 - val_loss: 0.2446 - val_categorical_crossentropy: 2.2537 - val_l2_complexity: 4.1589 - val_accuracy: 0.8531
# 20/20 [==============================] - 0s 1ms/step - loss: 70.5984 - categorical_crossentropy: 0.4629 - l2_complexity: 1411.9677 - accuracy: 0.8638
# best categorical cross entropy: 0.1356138288974762
# best L2: 1200.1724853515625
# training time: 5.768042087554932 s
# best model coordenates: [1, 0]
#
#
# model 6 - relative tolerance 14.64375 :
# 148/148 [==============================] - 1s 5ms/step - loss: 0.2229 - categorical_crossentropy: 0.2229 - l2_complexity: 10375.2354 - accuracy: 0.9189 - val_loss: 0.1204 - val_categorical_crossentropy: 0.1204 - val_l2_complexity: 1212.5358 - val_accuracy: 0.9561
# Best so far
# 148/148 [==============================] - 1s 5ms/step - loss: 0.1304 - categorical_crossentropy: 0.1304 - l2_complexity: 10756.9727 - accuracy: 0.9514 - val_loss: 0.1327 - val_categorical_crossentropy: 0.1327 - val_l2_complexity: 1254.6599 - val_accuracy: 0.9485
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1304 - categorical_crossentropy: 0.1304 - l2_complexity: 10756.9727 - accuracy: 0.9514 - val_loss: 0.1327 - val_categorical_crossentropy: 0.1327 - val_l2_complexity: 1254.6599 - val_accuracy: 0.9485
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8039 - categorical_crossentropy: 1.2062 - l2_complexity: 2107.1658 - accuracy: 0.9354 - val_loss: 0.2454 - val_categorical_crossentropy: 2.2524 - val_l2_complexity: 4.1721 - val_accuracy: 0.8817
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8039 - categorical_crossentropy: 1.2062 - l2_complexity: 2107.1658 - accuracy: 0.9354 - val_loss: 0.2454 - val_categorical_crossentropy: 2.2524 - val_l2_complexity: 4.1721 - val_accuracy: 0.8817
# 20/20 [==============================] - 0s 1ms/step - loss: 71.3256 - categorical_crossentropy: 0.5066 - l2_complexity: 1426.5128 - accuracy: 0.8526
# best categorical cross entropy: 0.12044405937194824
# best L2: 1212.5357666015625
# training time: 6.404191493988037 s
# best model coordenates: [1, 0]
#
#
# model 7 - relative tolerance 14.7125 :
# 148/148 [==============================] - 2s 10ms/step - loss: 0.2392 - categorical_crossentropy: 0.2392 - l2_complexity: 10320.4268 - accuracy: 0.9165 - val_loss: 0.1394 - val_categorical_crossentropy: 0.1394 - val_l2_complexity: 1205.5524 - val_accuracy: 0.9408
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1267 - categorical_crossentropy: 0.1267 - l2_complexity: 10704.1963 - accuracy: 0.9518 - val_loss: 0.1335 - val_categorical_crossentropy: 0.1335 - val_l2_complexity: 1252.3990 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1129 - categorical_crossentropy: 0.1129 - l2_complexity: 11132.0479 - accuracy: 0.9565 - val_loss: 0.1415 - val_categorical_crossentropy: 0.1415 - val_l2_complexity: 1305.8423 - val_accuracy: 0.9447
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1129 - categorical_crossentropy: 0.1129 - l2_complexity: 11132.0479 - accuracy: 0.9565 - val_loss: 0.1415 - val_categorical_crossentropy: 0.1415 - val_l2_complexity: 1305.8423 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.8448 - categorical_crossentropy: 0.9861 - l2_complexity: 2258.2437 - accuracy: 0.9420 - val_loss: 0.3943 - val_categorical_crossentropy: 2.1622 - val_l2_complexity: 6.7026 - val_accuracy: 0.8931
# 148/148 [==============================] - 1s 3ms/step - loss: 15.8448 - categorical_crossentropy: 0.9861 - l2_complexity: 2258.2437 - accuracy: 0.9420 - val_loss: 0.3943 - val_categorical_crossentropy: 2.1622 - val_l2_complexity: 6.7026 - val_accuracy: 0.8931
# 20/20 [==============================] - 0s 1ms/step - loss: 73.6705 - categorical_crossentropy: 0.5055 - l2_complexity: 1473.4106 - accuracy: 0.8638
# best categorical cross entropy: 0.13351334631443024
# best L2: 1252.3990478515625
# training time: 8.712518453598022 s
# best model coordenates: [2, 0]
#
#
# model 8 - relative tolerance 14.78125 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2361 - categorical_crossentropy: 0.2361 - l2_complexity: 10379.6289 - accuracy: 0.9165 - val_loss: 0.1267 - val_categorical_crossentropy: 0.1267 - val_l2_complexity: 1212.5571 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1305 - categorical_crossentropy: 0.1305 - l2_complexity: 10726.6562 - accuracy: 0.9492 - val_loss: 0.1281 - val_categorical_crossentropy: 0.1281 - val_l2_complexity: 1251.6289 - val_accuracy: 0.9447
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1305 - categorical_crossentropy: 0.1305 - l2_complexity: 10726.6562 - accuracy: 0.9492 - val_loss: 0.1281 - val_categorical_crossentropy: 0.1281 - val_l2_complexity: 1251.6289 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 1s 4ms/step - loss: 14.8185 - categorical_crossentropy: 1.2141 - l2_complexity: 2109.3306 - accuracy: 0.9509 - val_loss: 0.2535 - val_categorical_crossentropy: 2.2589 - val_l2_complexity: 4.3098 - val_accuracy: 0.8760
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8185 - categorical_crossentropy: 1.2141 - l2_complexity: 2109.3306 - accuracy: 0.9509 - val_loss: 0.2535 - val_categorical_crossentropy: 2.2589 - val_l2_complexity: 4.3098 - val_accuracy: 0.8760
# 20/20 [==============================] - 0s 1ms/step - loss: 71.3269 - categorical_crossentropy: 0.5174 - l2_complexity: 1426.5378 - accuracy: 0.8413
# best categorical cross entropy: 0.12665049731731415
# best L2: 1212.55712890625
# training time: 5.786581039428711 s
# best model coordenates: [1, 0]
#
#
# model 9 - relative tolerance 14.850000000000001 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2679 - categorical_crossentropy: 0.2679 - l2_complexity: 10325.7900 - accuracy: 0.9102 - val_loss: 0.1411 - val_categorical_crossentropy: 0.1411 - val_l2_complexity: 1207.4857 - val_accuracy: 0.9408
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1303 - categorical_crossentropy: 0.1303 - l2_complexity: 10689.1299 - accuracy: 0.9492 - val_loss: 0.1398 - val_categorical_crossentropy: 0.1398 - val_l2_complexity: 1244.9048 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1166 - categorical_crossentropy: 0.1166 - l2_complexity: 11061.3545 - accuracy: 0.9565 - val_loss: 0.1445 - val_categorical_crossentropy: 0.1445 - val_l2_complexity: 1293.7383 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1166 - categorical_crossentropy: 0.1166 - l2_complexity: 11061.3545 - accuracy: 0.9565 - val_loss: 0.1445 - val_categorical_crossentropy: 0.1445 - val_l2_complexity: 1293.7383 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.6864 - categorical_crossentropy: 1.0389 - l2_complexity: 2235.3594 - accuracy: 0.9486 - val_loss: 0.3782 - val_categorical_crossentropy: 2.1758 - val_l2_complexity: 6.4292 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0207 - categorical_crossentropy: 2.2978 - l2_complexity: 2.6700 - accuracy: 0.2865 - val_loss: 1.9963e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.3937e-06 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0207 - categorical_crossentropy: 2.2978 - l2_complexity: 2.6700 - accuracy: 0.2865 - val_loss: 1.9963e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.3937e-06 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3782 - categorical_crossentropy: 2.1766 - l2_complexity: 7.5637 - accuracy: 0.8333
# best categorical cross entropy: 0.1398281753063202
# best L2: 6.429173946380615
# training time: 8.187946081161499 s
# best model coordenates: [2, 1]
#
#
# model 10 - relative tolerance 14.918750000000001 :
# 148/148 [==============================] - 1s 4ms/step - loss: 0.2693 - categorical_crossentropy: 0.2693 - l2_complexity: 10367.9961 - accuracy: 0.9053 - val_loss: 0.1537 - val_categorical_crossentropy: 0.1537 - val_l2_complexity: 1211.5342 - val_accuracy: 0.9389
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1284 - categorical_crossentropy: 0.1284 - l2_complexity: 10773.9980 - accuracy: 0.9503 - val_loss: 0.1558 - val_categorical_crossentropy: 0.1558 - val_l2_complexity: 1259.7455 - val_accuracy: 0.9370
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1284 - categorical_crossentropy: 0.1284 - l2_complexity: 10773.9980 - accuracy: 0.9503 - val_loss: 0.1558 - val_categorical_crossentropy: 0.1558 - val_l2_complexity: 1259.7455 - val_accuracy: 0.9370
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.7776 - categorical_crossentropy: 1.2228 - l2_complexity: 2103.3525 - accuracy: 0.9282 - val_loss: 0.2445 - val_categorical_crossentropy: 2.2488 - val_l2_complexity: 4.1557 - val_accuracy: 0.8912
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0098 - categorical_crossentropy: 2.3011 - l2_complexity: 1.1938 - accuracy: 0.1752 - val_loss: 2.3401e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9781e-07 - val_accuracy: 0.7424
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3145e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0341 - accuracy: 0.0525 - val_loss: 1.0820e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8395e-08 - val_accuracy: 0.7424
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5049e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0369 - accuracy: 0.0518 - val_loss: 1.4146e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4048e-08 - val_accuracy: 0.7424
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5049e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0369 - accuracy: 0.0518 - val_loss: 1.4146e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4048e-08 - val_accuracy: 0.7424
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0820e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1641e-08 - accuracy: 0.6250
# best categorical cross entropy: 0.15366293489933014
# best L2: 1.8394677780975144e-08
# training time: 10.431838750839233 s
# best model coordenates: [1, 3]
#
#
# model 11 - relative tolerance 14.9875 :
# 148/148 [==============================] - 1s 4ms/step - loss: 0.2488 - categorical_crossentropy: 0.2488 - l2_complexity: 10214.6172 - accuracy: 0.9131 - val_loss: 0.1329 - val_categorical_crossentropy: 0.1329 - val_l2_complexity: 1192.4216 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1290 - categorical_crossentropy: 0.1290 - l2_complexity: 10596.8643 - accuracy: 0.9503 - val_loss: 0.1299 - val_categorical_crossentropy: 0.1299 - val_l2_complexity: 1239.1282 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1127 - categorical_crossentropy: 0.1127 - l2_complexity: 11083.0508 - accuracy: 0.9567 - val_loss: 0.1392 - val_categorical_crossentropy: 0.1392 - val_l2_complexity: 1304.1025 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1127 - categorical_crossentropy: 0.1127 - l2_complexity: 11083.0508 - accuracy: 0.9567 - val_loss: 0.1392 - val_categorical_crossentropy: 0.1392 - val_l2_complexity: 1304.1025 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.5858 - categorical_crossentropy: 1.0434 - l2_complexity: 2220.8967 - accuracy: 0.9556 - val_loss: 0.3771 - val_categorical_crossentropy: 2.1879 - val_l2_complexity: 6.4114 - val_accuracy: 0.9294
# 148/148 [==============================] - 1s 3ms/step - loss: 15.5858 - categorical_crossentropy: 1.0434 - l2_complexity: 2220.8967 - accuracy: 0.9556 - val_loss: 0.3771 - val_categorical_crossentropy: 2.1879 - val_l2_complexity: 6.4114 - val_accuracy: 0.9294
# 20/20 [==============================] - 0s 1ms/step - loss: 72.8899 - categorical_crossentropy: 0.4813 - l2_complexity: 1457.7979 - accuracy: 0.8606
# best categorical cross entropy: 0.12992243468761444
# best L2: 1239.128173828125
# training time: 7.094302177429199 s
# best model coordenates: [2, 0]
#
#
# model 12 - relative tolerance 15.05625 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2750 - categorical_crossentropy: 0.2750 - l2_complexity: 10369.6953 - accuracy: 0.9082 - val_loss: 0.1318 - val_categorical_crossentropy: 0.1318 - val_l2_complexity: 1212.2162 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1311 - categorical_crossentropy: 0.1311 - l2_complexity: 10740.3252 - accuracy: 0.9503 - val_loss: 0.1235 - val_categorical_crossentropy: 0.1235 - val_l2_complexity: 1250.9731 - val_accuracy: 0.9408
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1170 - categorical_crossentropy: 0.1170 - l2_complexity: 11115.3213 - accuracy: 0.9558 - val_loss: 0.1239 - val_categorical_crossentropy: 0.1239 - val_l2_complexity: 1296.8588 - val_accuracy: 0.9466
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1170 - categorical_crossentropy: 0.1170 - l2_complexity: 11115.3213 - accuracy: 0.9558 - val_loss: 0.1239 - val_categorical_crossentropy: 0.1239 - val_l2_complexity: 1296.8588 - val_accuracy: 0.9466
# loss function changed
# 148/148 [==============================] - 1s 4ms/step - loss: 15.8206 - categorical_crossentropy: 1.0027 - l2_complexity: 2254.7615 - accuracy: 0.9575 - val_loss: 0.3879 - val_categorical_crossentropy: 2.1758 - val_l2_complexity: 6.5941 - val_accuracy: 0.9542
# 148/148 [==============================] - 1s 3ms/step - loss: 15.8206 - categorical_crossentropy: 1.0027 - l2_complexity: 2254.7615 - accuracy: 0.9575 - val_loss: 0.3879 - val_categorical_crossentropy: 2.1758 - val_l2_complexity: 6.5941 - val_accuracy: 0.9542
# 20/20 [==============================] - 0s 2ms/step - loss: 73.5867 - categorical_crossentropy: 0.5016 - l2_complexity: 1471.7332 - accuracy: 0.8494
# best categorical cross entropy: 0.12346427887678146
# best L2: 1250.97314453125
# training time: 6.782728672027588 s
# best model coordenates: [2, 0]
#
#
# model 13 - relative tolerance 15.125 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2226 - categorical_crossentropy: 0.2226 - l2_complexity: 10284.2217 - accuracy: 0.9212 - val_loss: 0.1318 - val_categorical_crossentropy: 0.1318 - val_l2_complexity: 1201.4227 - val_accuracy: 0.9504
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1297 - categorical_crossentropy: 0.1297 - l2_complexity: 10666.8350 - accuracy: 0.9505 - val_loss: 0.1416 - val_categorical_crossentropy: 0.1416 - val_l2_complexity: 1248.7163 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1297 - categorical_crossentropy: 0.1297 - l2_complexity: 10666.8350 - accuracy: 0.9505 - val_loss: 0.1416 - val_categorical_crossentropy: 0.1416 - val_l2_complexity: 1248.7163 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.6604 - categorical_crossentropy: 1.2147 - l2_complexity: 2086.7175 - accuracy: 0.9452 - val_loss: 0.2512 - val_categorical_crossentropy: 2.2572 - val_l2_complexity: 4.2705 - val_accuracy: 0.9351
# 148/148 [==============================] - 1s 3ms/step - loss: 14.6604 - categorical_crossentropy: 1.2147 - l2_complexity: 2086.7175 - accuracy: 0.9452 - val_loss: 0.2512 - val_categorical_crossentropy: 2.2572 - val_l2_complexity: 4.2705 - val_accuracy: 0.9351
# 20/20 [==============================] - 0s 1ms/step - loss: 70.6719 - categorical_crossentropy: 0.4987 - l2_complexity: 1413.4384 - accuracy: 0.8494
# best categorical cross entropy: 0.13177791237831116
# best L2: 1201.4227294921875
# training time: 5.770983934402466 s
# best model coordenates: [1, 0]
#
#
# model 14 - relative tolerance 15.19375 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2410 - categorical_crossentropy: 0.2410 - l2_complexity: 10247.9033 - accuracy: 0.9138 - val_loss: 0.1313 - val_categorical_crossentropy: 0.1313 - val_l2_complexity: 1196.6490 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1293 - categorical_crossentropy: 0.1293 - l2_complexity: 10615.9248 - accuracy: 0.9501 - val_loss: 0.1348 - val_categorical_crossentropy: 0.1348 - val_l2_complexity: 1237.7534 - val_accuracy: 0.9351
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1293 - categorical_crossentropy: 0.1293 - l2_complexity: 10615.9248 - accuracy: 0.9501 - val_loss: 0.1348 - val_categorical_crossentropy: 0.1348 - val_l2_complexity: 1237.7534 - val_accuracy: 0.9351
# loss function changed
# 148/148 [==============================] - 2s 10ms/step - loss: 14.5447 - categorical_crossentropy: 1.2440 - l2_complexity: 2069.9536 - accuracy: 0.9454 - val_loss: 0.2402 - val_categorical_crossentropy: 2.2583 - val_l2_complexity: 4.0838 - val_accuracy: 0.9141
# 148/148 [==============================] - 1s 3ms/step - loss: 14.5447 - categorical_crossentropy: 1.2440 - l2_complexity: 2069.9536 - accuracy: 0.9454 - val_loss: 0.2402 - val_categorical_crossentropy: 2.2583 - val_l2_complexity: 4.0838 - val_accuracy: 0.9141
# 20/20 [==============================] - 0s 2ms/step - loss: 70.3911 - categorical_crossentropy: 0.4927 - l2_complexity: 1407.8224 - accuracy: 0.8558
# best categorical cross entropy: 0.13130278885364532
# best L2: 1196.6490478515625
# training time: 8.61620020866394 s
# best model coordenates: [1, 0]
#
#
# model 15 - relative tolerance 15.262500000000001 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2443 - categorical_crossentropy: 0.2443 - l2_complexity: 10365.8320 - accuracy: 0.9138 - val_loss: 0.1385 - val_categorical_crossentropy: 0.1385 - val_l2_complexity: 1211.7789 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1301 - categorical_crossentropy: 0.1301 - l2_complexity: 10756.1621 - accuracy: 0.9505 - val_loss: 0.1350 - val_categorical_crossentropy: 0.1350 - val_l2_complexity: 1253.5797 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1150 - categorical_crossentropy: 0.1150 - l2_complexity: 11143.7910 - accuracy: 0.9582 - val_loss: 0.1474 - val_categorical_crossentropy: 0.1474 - val_l2_complexity: 1306.9457 - val_accuracy: 0.9427
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1150 - categorical_crossentropy: 0.1150 - l2_complexity: 11143.7910 - accuracy: 0.9582 - val_loss: 0.1474 - val_categorical_crossentropy: 0.1474 - val_l2_complexity: 1306.9457 - val_accuracy: 0.9427
# loss function changed
# 148/148 [==============================] - 1s 5ms/step - loss: 15.8314 - categorical_crossentropy: 1.0234 - l2_complexity: 2256.1853 - accuracy: 0.9543 - val_loss: 0.3810 - val_categorical_crossentropy: 2.1856 - val_l2_complexity: 6.4767 - val_accuracy: 0.9408
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0192 - categorical_crossentropy: 2.2985 - l2_complexity: 2.4427 - accuracy: 0.2451 - val_loss: 4.4540e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.5717e-07 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0192 - categorical_crossentropy: 2.2985 - l2_complexity: 2.4427 - accuracy: 0.2451 - val_loss: 4.4540e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.5717e-07 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3810 - categorical_crossentropy: 2.1897 - l2_complexity: 7.6197 - accuracy: 0.7933
# best categorical cross entropy: 0.13496772944927216
# best L2: 6.476726055145264
# training time: 8.780303478240967 s
# best model coordenates: [2, 1]
#
#
# model 16 - relative tolerance 15.33125 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2364 - categorical_crossentropy: 0.2364 - l2_complexity: 10188.0430 - accuracy: 0.9184 - val_loss: 0.1446 - val_categorical_crossentropy: 0.1446 - val_l2_complexity: 1189.8550 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1283 - categorical_crossentropy: 0.1283 - l2_complexity: 10593.5645 - accuracy: 0.9505 - val_loss: 0.1392 - val_categorical_crossentropy: 0.1392 - val_l2_complexity: 1239.4974 - val_accuracy: 0.9408
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1157 - categorical_crossentropy: 0.1157 - l2_complexity: 11053.7949 - accuracy: 0.9556 - val_loss: 0.1442 - val_categorical_crossentropy: 0.1442 - val_l2_complexity: 1293.1801 - val_accuracy: 0.9447
# 148/148 [==============================] - 1s 7ms/step - loss: 0.1157 - categorical_crossentropy: 0.1157 - l2_complexity: 11053.7949 - accuracy: 0.9556 - val_loss: 0.1442 - val_categorical_crossentropy: 0.1442 - val_l2_complexity: 1293.1801 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.5902 - categorical_crossentropy: 1.0101 - l2_complexity: 2221.5269 - accuracy: 0.9465 - val_loss: 0.3788 - val_categorical_crossentropy: 2.1782 - val_l2_complexity: 6.4389 - val_accuracy: 0.9389
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.0205 - categorical_crossentropy: 2.2982 - l2_complexity: 2.6321 - accuracy: 0.2619 - val_loss: 1.1575e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.9678e-06 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0205 - categorical_crossentropy: 2.2982 - l2_complexity: 2.6321 - accuracy: 0.2619 - val_loss: 1.1575e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.9678e-06 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3788 - categorical_crossentropy: 2.1821 - l2_complexity: 7.5751 - accuracy: 0.8846
# best categorical cross entropy: 0.139229416847229
# best L2: 6.4388604164123535
# training time: 9.25894808769226 s
# best model coordenates: [2, 1]
#
#
# model 17 - relative tolerance 15.4 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2434 - categorical_crossentropy: 0.2434 - l2_complexity: 10243.2227 - accuracy: 0.9144 - val_loss: 0.1387 - val_categorical_crossentropy: 0.1387 - val_l2_complexity: 1197.9467 - val_accuracy: 0.9389
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1317 - categorical_crossentropy: 0.1317 - l2_complexity: 10609.8076 - accuracy: 0.9499 - val_loss: 0.1431 - val_categorical_crossentropy: 0.1431 - val_l2_complexity: 1241.6973 - val_accuracy: 0.9447
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1317 - categorical_crossentropy: 0.1317 - l2_complexity: 10609.8076 - accuracy: 0.9499 - val_loss: 0.1431 - val_categorical_crossentropy: 0.1431 - val_l2_complexity: 1241.6973 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.5767 - categorical_crossentropy: 1.1981 - l2_complexity: 2074.5977 - accuracy: 0.9507 - val_loss: 0.2415 - val_categorical_crossentropy: 2.2485 - val_l2_complexity: 4.1055 - val_accuracy: 0.9523
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0095 - categorical_crossentropy: 2.3012 - l2_complexity: 1.1545 - accuracy: 0.1306 - val_loss: 2.2307e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.7923e-07 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0095 - categorical_crossentropy: 2.3012 - l2_complexity: 1.1545 - accuracy: 0.1306 - val_loss: 2.2307e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.7923e-07 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2415 - categorical_crossentropy: 2.2516 - l2_complexity: 4.8300 - accuracy: 0.8077
# best categorical cross entropy: 0.1387367844581604
# best L2: 4.1055426597595215
# training time: 6.67606782913208 s
# best model coordenates: [1, 1]
#
#
# model 18 - relative tolerance 15.46875 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2111 - categorical_crossentropy: 0.2111 - l2_complexity: 10303.4551 - accuracy: 0.9254 - val_loss: 0.1438 - val_categorical_crossentropy: 0.1438 - val_l2_complexity: 1204.2589 - val_accuracy: 0.9427
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1268 - categorical_crossentropy: 0.1268 - l2_complexity: 10711.1719 - accuracy: 0.9509 - val_loss: 0.1429 - val_categorical_crossentropy: 0.1429 - val_l2_complexity: 1254.0880 - val_accuracy: 0.9389
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1121 - categorical_crossentropy: 0.1121 - l2_complexity: 11201.6201 - accuracy: 0.9569 - val_loss: 0.1486 - val_categorical_crossentropy: 0.1486 - val_l2_complexity: 1313.9221 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1121 - categorical_crossentropy: 0.1121 - l2_complexity: 11201.6201 - accuracy: 0.9569 - val_loss: 0.1486 - val_categorical_crossentropy: 0.1486 - val_l2_complexity: 1313.9221 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.8204 - categorical_crossentropy: 1.0327 - l2_complexity: 2254.5269 - accuracy: 0.9548 - val_loss: 0.3790 - val_categorical_crossentropy: 2.1861 - val_l2_complexity: 6.4425 - val_accuracy: 0.9504
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0200 - categorical_crossentropy: 2.2985 - l2_complexity: 2.5630 - accuracy: 0.2249 - val_loss: 8.1605e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.3873e-06 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 3s 3ms/step - loss: 2.3220e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0342 - accuracy: 0.1183 - val_loss: 1.0919e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8562e-08 - val_accuracy: 0.7424
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5034e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.0769 - val_loss: 1.4140e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4038e-08 - val_accuracy: 0.7424
# 148/148 [==============================] - 1s 4ms/step - loss: 2.5034e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.0769 - val_loss: 1.4140e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4038e-08 - val_accuracy: 0.7424
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0919e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1838e-08 - accuracy: 0.6250
# best categorical cross entropy: 0.14291630685329437
# best L2: 1.856238895925344e-08
# training time: 12.908432245254517 s
# best model coordenates: [2, 3]
#
#
# model 19 - relative tolerance 15.5375 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2212 - categorical_crossentropy: 0.2212 - l2_complexity: 10243.9580 - accuracy: 0.9225 - val_loss: 0.1354 - val_categorical_crossentropy: 0.1354 - val_l2_complexity: 1195.9497 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1307 - categorical_crossentropy: 0.1307 - l2_complexity: 10608.4033 - accuracy: 0.9497 - val_loss: 0.1328 - val_categorical_crossentropy: 0.1328 - val_l2_complexity: 1237.5717 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1165 - categorical_crossentropy: 0.1165 - l2_complexity: 11042.9775 - accuracy: 0.9575 - val_loss: 0.1384 - val_categorical_crossentropy: 0.1384 - val_l2_complexity: 1295.2968 - val_accuracy: 0.9351
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1165 - categorical_crossentropy: 0.1165 - l2_complexity: 11042.9775 - accuracy: 0.9575 - val_loss: 0.1384 - val_categorical_crossentropy: 0.1384 - val_l2_complexity: 1295.2968 - val_accuracy: 0.9351
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.4814 - categorical_crossentropy: 1.0313 - l2_complexity: 2205.5820 - accuracy: 0.9516 - val_loss: 0.3553 - val_categorical_crossentropy: 2.1858 - val_l2_complexity: 6.0406 - val_accuracy: 0.9427
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0188 - categorical_crossentropy: 2.2986 - l2_complexity: 2.4115 - accuracy: 0.1965 - val_loss: 5.6898e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.6726e-07 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0188 - categorical_crossentropy: 2.2986 - l2_complexity: 2.4115 - accuracy: 0.1965 - val_loss: 5.6898e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.6726e-07 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3553 - categorical_crossentropy: 2.1874 - l2_complexity: 7.1066 - accuracy: 0.8558
# best categorical cross entropy: 0.1328420490026474
# best L2: 6.040594100952148
# training time: 7.892597436904907 s
# best model coordenates: [2, 1]
#
#
# model 20 - relative tolerance 15.60625 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2287 - categorical_crossentropy: 0.2287 - l2_complexity: 10259.6855 - accuracy: 0.9172 - val_loss: 0.1379 - val_categorical_crossentropy: 0.1379 - val_l2_complexity: 1196.3645 - val_accuracy: 0.9504
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1286 - categorical_crossentropy: 0.1286 - l2_complexity: 10584.6377 - accuracy: 0.9505 - val_loss: 0.1400 - val_categorical_crossentropy: 0.1400 - val_l2_complexity: 1234.6766 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1286 - categorical_crossentropy: 0.1286 - l2_complexity: 10584.6377 - accuracy: 0.9505 - val_loss: 0.1400 - val_categorical_crossentropy: 0.1400 - val_l2_complexity: 1234.6766 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.5300 - categorical_crossentropy: 1.2418 - l2_complexity: 2067.8110 - accuracy: 0.9526 - val_loss: 0.2366 - val_categorical_crossentropy: 2.2624 - val_l2_complexity: 4.0230 - val_accuracy: 0.9504
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0093 - categorical_crossentropy: 2.3017 - l2_complexity: 1.1275 - accuracy: 0.1202 - val_loss: 2.1635e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.6779e-07 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0093 - categorical_crossentropy: 2.3017 - l2_complexity: 1.1275 - accuracy: 0.1202 - val_loss: 2.1635e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.6779e-07 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2366 - categorical_crossentropy: 2.2631 - l2_complexity: 4.7329 - accuracy: 0.8285
# best categorical cross entropy: 0.13787667453289032
# best L2: 4.022972583770752
# training time: 7.271087884902954 s
# best model coordenates: [1, 1]
#
#
# model 21 - relative tolerance 15.675 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2159 - categorical_crossentropy: 0.2159 - l2_complexity: 10218.5977 - accuracy: 0.9250 - val_loss: 0.1444 - val_categorical_crossentropy: 0.1444 - val_l2_complexity: 1193.3729 - val_accuracy: 0.9523
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1300 - categorical_crossentropy: 0.1300 - l2_complexity: 10613.4746 - accuracy: 0.9511 - val_loss: 0.1484 - val_categorical_crossentropy: 0.1484 - val_l2_complexity: 1241.8412 - val_accuracy: 0.9389
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1300 - categorical_crossentropy: 0.1300 - l2_complexity: 10613.4746 - accuracy: 0.9511 - val_loss: 0.1484 - val_categorical_crossentropy: 0.1484 - val_l2_complexity: 1241.8412 - val_accuracy: 0.9389
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.4285 - categorical_crossentropy: 1.2247 - l2_complexity: 2053.0271 - accuracy: 0.8932 - val_loss: 0.2249 - val_categorical_crossentropy: 2.2547 - val_l2_complexity: 3.8232 - val_accuracy: 0.7443
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0087 - categorical_crossentropy: 2.3014 - l2_complexity: 1.0573 - accuracy: 0.1780 - val_loss: 2.0122e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.4207e-07 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3187e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0341 - accuracy: 0.1631 - val_loss: 1.0920e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8564e-08 - val_accuracy: 0.2576
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5035e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1096 - val_loss: 1.4152e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4059e-08 - val_accuracy: 0.2576
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5035e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1096 - val_loss: 1.4152e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4059e-08 - val_accuracy: 0.2576
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0920e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1840e-08 - accuracy: 0.3750
# best categorical cross entropy: 0.14439478516578674
# best L2: 1.8564263015719007e-08
# training time: 8.789173364639282 s
# best model coordenates: [1, 3]
#
#
# model 22 - relative tolerance 15.74375 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2590 - categorical_crossentropy: 0.2590 - l2_complexity: 10233.1846 - accuracy: 0.9131 - val_loss: 0.1421 - val_categorical_crossentropy: 0.1421 - val_l2_complexity: 1196.0576 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1279 - categorical_crossentropy: 0.1279 - l2_complexity: 10579.1416 - accuracy: 0.9518 - val_loss: 0.1444 - val_categorical_crossentropy: 0.1444 - val_l2_complexity: 1231.6053 - val_accuracy: 0.9447
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1279 - categorical_crossentropy: 0.1279 - l2_complexity: 10579.1416 - accuracy: 0.9518 - val_loss: 0.1444 - val_categorical_crossentropy: 0.1444 - val_l2_complexity: 1231.6053 - val_accuracy: 0.9447
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.5961 - categorical_crossentropy: 1.2721 - l2_complexity: 2077.5674 - accuracy: 0.9099 - val_loss: 0.2482 - val_categorical_crossentropy: 2.2663 - val_l2_complexity: 4.2190 - val_accuracy: 0.7424
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0099 - categorical_crossentropy: 2.3018 - l2_complexity: 1.2057 - accuracy: 0.2077 - val_loss: 2.2875e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.8887e-07 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3223e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0342 - accuracy: 0.0387 - val_loss: 1.0900e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8529e-08 - val_accuracy: 0.2576
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 2.5024e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1175 - val_loss: 1.4064e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.3909e-08 - val_accuracy: 0.2576
# 148/148 [==============================] - 3s 3ms/step - loss: 2.5024e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1175 - val_loss: 1.4064e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.3909e-08 - val_accuracy: 0.2576
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0900e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1799e-08 - accuracy: 0.3750
# best categorical cross entropy: 0.14205345511436462
# best L2: 1.8529487277874068e-08
# training time: 10.704286336898804 s
# best model coordenates: [1, 3]
#
#
# model 23 - relative tolerance 15.8125 :
# 148/148 [==============================] - 1s 4ms/step - loss: 0.2549 - categorical_crossentropy: 0.2549 - l2_complexity: 10291.5137 - accuracy: 0.9093 - val_loss: 0.1333 - val_categorical_crossentropy: 0.1333 - val_l2_complexity: 1202.3818 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1300 - categorical_crossentropy: 0.1300 - l2_complexity: 10678.4238 - accuracy: 0.9507 - val_loss: 0.1308 - val_categorical_crossentropy: 0.1308 - val_l2_complexity: 1249.6389 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1138 - categorical_crossentropy: 0.1138 - l2_complexity: 11135.4131 - accuracy: 0.9588 - val_loss: 0.1339 - val_categorical_crossentropy: 0.1339 - val_l2_complexity: 1307.4517 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1138 - categorical_crossentropy: 0.1138 - l2_complexity: 11135.4131 - accuracy: 0.9588 - val_loss: 0.1339 - val_categorical_crossentropy: 0.1339 - val_l2_complexity: 1307.4517 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.8178 - categorical_crossentropy: 1.0409 - l2_complexity: 2254.4473 - accuracy: 0.9446 - val_loss: 0.3988 - val_categorical_crossentropy: 2.1902 - val_l2_complexity: 6.7790 - val_accuracy: 0.8893
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0219 - categorical_crossentropy: 2.2985 - l2_complexity: 2.8261 - accuracy: 0.1922 - val_loss: 1.7341e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.9479e-05 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 4ms/step - loss: 0.0219 - categorical_crossentropy: 2.2985 - l2_complexity: 2.8261 - accuracy: 0.1922 - val_loss: 1.7341e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.9479e-05 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3988 - categorical_crossentropy: 2.1951 - l2_complexity: 7.9753 - accuracy: 0.7212
# best categorical cross entropy: 0.13082928955554962
# best L2: 6.778992652893066
# training time: 8.81568694114685 s
# best model coordenates: [2, 1]
#
#
# model 24 - relative tolerance 15.88125 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2544 - categorical_crossentropy: 0.2544 - l2_complexity: 10251.9473 - accuracy: 0.9070 - val_loss: 0.1371 - val_categorical_crossentropy: 0.1371 - val_l2_complexity: 1197.7810 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1335 - categorical_crossentropy: 0.1335 - l2_complexity: 10617.6377 - accuracy: 0.9492 - val_loss: 0.1299 - val_categorical_crossentropy: 0.1299 - val_l2_complexity: 1239.3607 - val_accuracy: 0.9447
# Best so far
# ...
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0211 - categorical_crossentropy: 2.2986 - l2_complexity: 2.7149 - accuracy: 0.2906 - val_loss: 3.9777e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.7621e-06 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3874 - categorical_crossentropy: 2.1887 - l2_complexity: 7.7475 - accuracy: 0.7580
# best categorical cross entropy: 0.13358114659786224
# best L2: 6.5853400230407715
# training time: 8.089020490646362 s
# best model coordenates: [2, 1]
#
#
# model 28 - relative tolerance 16.15625 :
# 148/148 [==============================] - 3s 4ms/step - loss: 0.2472 - categorical_crossentropy: 0.2472 - l2_complexity: 10341.4678 - accuracy: 0.9133 - val_loss: 0.1321 - val_categorical_crossentropy: 0.1321 - val_l2_complexity: 1208.1204 - val_accuracy: 0.9542
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1265 - categorical_crossentropy: 0.1265 - l2_complexity: 10710.8262 - accuracy: 0.9514 - val_loss: 0.1345 - val_categorical_crossentropy: 0.1345 - val_l2_complexity: 1254.1134 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1265 - categorical_crossentropy: 0.1265 - l2_complexity: 10710.8262 - accuracy: 0.9514 - val_loss: 0.1345 - val_categorical_crossentropy: 0.1345 - val_l2_complexity: 1254.1134 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.7549 - categorical_crossentropy: 1.2188 - l2_complexity: 2100.2322 - accuracy: 0.9301 - val_loss: 0.2542 - val_categorical_crossentropy: 2.2506 - val_l2_complexity: 4.3206 - val_accuracy: 0.8454
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.0103 - categorical_crossentropy: 2.3013 - l2_complexity: 1.2673 - accuracy: 0.2022 - val_loss: 2.3250e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9525e-07 - val_accuracy: 0.2576
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0103 - categorical_crossentropy: 2.3013 - l2_complexity: 1.2673 - accuracy: 0.2022 - val_loss: 2.3250e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9525e-07 - val_accuracy: 0.2576
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2542 - categorical_crossentropy: 2.2519 - l2_complexity: 5.0831 - accuracy: 0.8317
# best categorical cross entropy: 0.13212202489376068
# best L2: 4.320640563964844
# training time: 9.188511610031128 s
# best model coordenates: [1, 1]
#
#
# model 29 - relative tolerance 16.225 :
# 148/148 [==============================] - 1s 4ms/step - loss: 0.2308 - categorical_crossentropy: 0.2308 - l2_complexity: 10388.0781 - accuracy: 0.9157 - val_loss: 0.1420 - val_categorical_crossentropy: 0.1420 - val_l2_complexity: 1212.8622 - val_accuracy: 0.9447
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1309 - categorical_crossentropy: 0.1309 - l2_complexity: 10758.7080 - accuracy: 0.9511 - val_loss: 0.1526 - val_categorical_crossentropy: 0.1526 - val_l2_complexity: 1255.9707 - val_accuracy: 0.9370
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1309 - categorical_crossentropy: 0.1309 - l2_complexity: 10758.7080 - accuracy: 0.9511 - val_loss: 0.1526 - val_categorical_crossentropy: 0.1526 - val_l2_complexity: 1255.9707 - val_accuracy: 0.9370
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8444 - categorical_crossentropy: 1.2613 - l2_complexity: 2113.1274 - accuracy: 0.9503 - val_loss: 0.2564 - val_categorical_crossentropy: 2.2652 - val_l2_complexity: 4.3589 - val_accuracy: 0.9542
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0102 - categorical_crossentropy: 2.3018 - l2_complexity: 1.2465 - accuracy: 0.0905 - val_loss: 2.3307e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9623e-07 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3171e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0341 - accuracy: 0.1761 - val_loss: 1.0885e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8505e-08 - val_accuracy: 0.7424
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5032e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.0709 - val_loss: 1.4131e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4023e-08 - val_accuracy: 0.7424
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5032e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.0709 - val_loss: 1.4131e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4023e-08 - val_accuracy: 0.7424
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0885e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1771e-08 - accuracy: 0.6250
# best categorical cross entropy: 0.1420115977525711
# best L2: 1.8505142307390088e-08
# training time: 8.928985595703125 s
# best model coordenates: [1, 3]
#
#
# model 30 - relative tolerance 16.29375 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2369 - categorical_crossentropy: 0.2369 - l2_complexity: 10412.6758 - accuracy: 0.9169 - val_loss: 0.1348 - val_categorical_crossentropy: 0.1348 - val_l2_complexity: 1215.3528 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1326 - categorical_crossentropy: 0.1326 - l2_complexity: 10802.6162 - accuracy: 0.9475 - val_loss: 0.1438 - val_categorical_crossentropy: 0.1438 - val_l2_complexity: 1263.7345 - val_accuracy: 0.9408
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1326 - categorical_crossentropy: 0.1326 - l2_complexity: 10802.6162 - accuracy: 0.9475 - val_loss: 0.1438 - val_categorical_crossentropy: 0.1438 - val_l2_complexity: 1263.7345 - val_accuracy: 0.9408
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.8406 - categorical_crossentropy: 1.2153 - l2_complexity: 2112.4111 - accuracy: 0.9541 - val_loss: 0.2485 - val_categorical_crossentropy: 2.2538 - val_l2_complexity: 4.2244 - val_accuracy: 0.9580
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0099 - categorical_crossentropy: 2.3015 - l2_complexity: 1.2144 - accuracy: 0.2137 - val_loss: 2.3316e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9636e-07 - val_accuracy: 0.2576
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3156e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0341 - accuracy: 0.1910 - val_loss: 1.0843e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8433e-08 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5042e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1604 - val_loss: 1.4188e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4120e-08 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5042e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1604 - val_loss: 1.4188e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4120e-08 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0843e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1686e-08 - accuracy: 0.0000e+00
# best categorical cross entropy: 0.13480232656002045
# best L2: 1.8433095050340853e-08
# training time: 9.157044410705566 s
# best model coordenates: [1, 3]
#
#
# model 31 - relative tolerance 16.3625 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2367 - categorical_crossentropy: 0.2367 - l2_complexity: 10185.9463 - accuracy: 0.9189 - val_loss: 0.1375 - val_categorical_crossentropy: 0.1375 - val_l2_complexity: 1188.4330 - val_accuracy: 0.9427
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1320 - categorical_crossentropy: 0.1320 - l2_complexity: 10565.9307 - accuracy: 0.9497 - val_loss: 0.1373 - val_categorical_crossentropy: 0.1373 - val_l2_complexity: 1231.3647 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1178 - categorical_crossentropy: 0.1178 - l2_complexity: 10948.8506 - accuracy: 0.9560 - val_loss: 0.1397 - val_categorical_crossentropy: 0.1397 - val_l2_complexity: 1280.2157 - val_accuracy: 0.9389
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1178 - categorical_crossentropy: 0.1178 - l2_complexity: 10948.8506 - accuracy: 0.9560 - val_loss: 0.1397 - val_categorical_crossentropy: 0.1397 - val_l2_complexity: 1280.2157 - val_accuracy: 0.9389
# loss function changed
# 148/148 [==============================] - 1s 4ms/step - loss: 15.4148 - categorical_crossentropy: 1.0550 - l2_complexity: 2196.1479 - accuracy: 0.9467 - val_loss: 0.3583 - val_categorical_crossentropy: 2.1896 - val_l2_complexity: 6.0919 - val_accuracy: 0.9198
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0189 - categorical_crossentropy: 2.2988 - l2_complexity: 2.4223 - accuracy: 0.2749 - val_loss: 5.4169e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 9.2087e-07 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3223e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0342 - accuracy: 0.0983 - val_loss: 1.0916e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8557e-08 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5037e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.2026 - val_loss: 1.4153e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4060e-08 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5037e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.2026 - val_loss: 1.4153e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4060e-08 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 1ms/step - loss: 1.0916e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1832e-08 - accuracy: 0.0000e+00
# best categorical cross entropy: 0.13733220100402832
# best L2: 1.8556800540636686e-08
# training time: 10.965332746505737 s
# best model coordenates: [2, 3]
#
#
# model 32 - relative tolerance 16.43125 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2401 - categorical_crossentropy: 0.2401 - l2_complexity: 10358.3125 - accuracy: 0.9142 - val_loss: 0.1326 - val_categorical_crossentropy: 0.1326 - val_l2_complexity: 1208.8574 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1294 - categorical_crossentropy: 0.1294 - l2_complexity: 10702.6182 - accuracy: 0.9501 - val_loss: 0.1324 - val_categorical_crossentropy: 0.1324 - val_l2_complexity: 1244.5421 - val_accuracy: 0.9466
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1151 - categorical_crossentropy: 0.1151 - l2_complexity: 11091.7217 - accuracy: 0.9565 - val_loss: 0.1315 - val_categorical_crossentropy: 0.1315 - val_l2_complexity: 1299.7931 - val_accuracy: 0.9504
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1041 - categorical_crossentropy: 0.1041 - l2_complexity: 11599.8330 - accuracy: 0.9620 - val_loss: 0.1356 - val_categorical_crossentropy: 0.1356 - val_l2_complexity: 1359.4570 - val_accuracy: 0.9504
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1041 - categorical_crossentropy: 0.1041 - l2_complexity: 11599.8330 - accuracy: 0.9620 - val_loss: 0.1356 - val_categorical_crossentropy: 0.1356 - val_l2_complexity: 1359.4570 - val_accuracy: 0.9504
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 17.0241 - categorical_crossentropy: 0.8764 - l2_complexity: 2429.4028 - accuracy: 0.9590 - val_loss: 0.6287 - val_categorical_crossentropy: 2.0781 - val_l2_complexity: 10.6886 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0546 - categorical_crossentropy: 2.2927 - l2_complexity: 7.3975 - accuracy: 0.1682 - val_loss: 7.3174e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0012 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0546 - categorical_crossentropy: 2.2927 - l2_complexity: 7.3975 - accuracy: 0.1682 - val_loss: 7.3174e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0012 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6287 - categorical_crossentropy: 2.0832 - l2_complexity: 12.5748 - accuracy: 0.7853
# best categorical cross entropy: 0.13146977126598358
# best L2: 10.688587188720703
# training time: 9.681779146194458 s
# best model coordenates: [3, 1]
#
#
# model 33 - relative tolerance 16.5 :
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2330 - categorical_crossentropy: 0.2330 - l2_complexity: 10335.1152 - accuracy: 0.9180 - val_loss: 0.1386 - val_categorical_crossentropy: 0.1386 - val_l2_complexity: 1204.7461 - val_accuracy: 0.9485
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1308 - categorical_crossentropy: 0.1308 - l2_complexity: 10665.8018 - accuracy: 0.9501 - val_loss: 0.1336 - val_categorical_crossentropy: 0.1336 - val_l2_complexity: 1244.3777 - val_accuracy: 0.9408
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1170 - categorical_crossentropy: 0.1170 - l2_complexity: 11036.1338 - accuracy: 0.9577 - val_loss: 0.1404 - val_categorical_crossentropy: 0.1404 - val_l2_complexity: 1288.2104 - val_accuracy: 0.9389
# 148/148 [==============================] - 1s 5ms/step - loss: 0.1170 - categorical_crossentropy: 0.1170 - l2_complexity: 11036.1338 - accuracy: 0.9577 - val_loss: 0.1404 - val_categorical_crossentropy: 0.1404 - val_l2_complexity: 1288.2104 - val_accuracy: 0.9389
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 15.6175 - categorical_crossentropy: 1.0033 - l2_complexity: 2225.2451 - accuracy: 0.9565 - val_loss: 0.3768 - val_categorical_crossentropy: 2.1695 - val_l2_complexity: 6.4050 - val_accuracy: 0.9389
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0206 - categorical_crossentropy: 2.2980 - l2_complexity: 2.6606 - accuracy: 0.2383 - val_loss: 5.2529e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.9300e-07 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3243e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0342 - accuracy: 0.1049 - val_loss: 1.0921e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8565e-08 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 2.5035e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.0618 - val_loss: 1.4167e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4084e-08 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5035e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.0618 - val_loss: 1.4167e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.4084e-08 - val_accuracy: 0.0000e+00
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0921e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1841e-08 - accuracy: 0.0000e+00
# best categorical cross entropy: 0.1335604190826416
# best L2: 1.856517073406394e-08
# training time: 12.953043699264526 s
# best model coordenates: [2, 3]

# %%
# Convert the list to a NumPy array for easier manipulation
accuracy_values_array = np.array(accuracy_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(accuracy_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the original data and the running average
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='blue', linestyle=':', label='Running Average')
plt.plot(tolerances, accuracy_values_array, marker='o', color='red', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
ce_values_array = np.array(ce_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(ce_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the original data and the running average
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='blue', linestyle=':', label='Running Average')
plt.plot(tolerances, ce_values_array, marker='o', color='red', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Categorical Crossentropy vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
l2_values_array = np.array(l2_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(l2_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, l2_values_array, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2')
plt.title('Norm L2 vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the lists to NumPy arrays for easier manipulation
ce_values_array = np.array(ce_values)
l2_values_array = np.array(l2_values)

# Normalize the data between 0 and 1
scaler = MinMaxScaler()
ce_normalized = scaler.fit_transform(ce_values_array.reshape(-1, 1)).flatten()
l2_normalized = scaler.fit_transform(l2_values_array.reshape(-1, 1)).flatten()

# Calculate the mean after normalization
mean_normalized = (ce_normalized + l2_normalized) / 2.0

# Find the indices of the three smallest values of mean_normalized
min_indices = np.argsort(mean_normalized)[:3]
min_values = mean_normalized[min_indices]

# Define marcadores para os três pontos mínimos em ordem crescente
markers = ['*', 'x', 'o']

# Plot the combined graph
plt.figure(figsize=(8, 6))

# Plot Categorical Crossentropy
plt.plot(tolerances, ce_normalized, marker='o', color='red', linestyle=':', label='CE Normalized Data')

# Plot Norm L2
plt.plot(tolerances, l2_normalized, marker='o', color='blue', linestyle=':', label='L2 Normalized Data')

# Plot the mean of CE and L2
plt.plot(tolerances, mean_normalized, marker='d', color='m', label='Mean Normalized Data')

# Highlight the points with the three smallest values using different markers
for value, marker in zip(min_values, markers):
    plt.scatter(tolerances[min_indices[np.where(min_values == value)]], value, color='black', zorder=5, marker=marker)

# Create legend labels for the three smallest values
legend_labels_min_values = [f'Min Value {min_indices[i]+1}: {min_values[i]:.2f} ' for i in range(3)]

# Create legend labels including the values of the three smallest mean_normalized
legend_labels = ['CE Normalized Data', 'L2 Normalized Data', 'Mean Normalized Data']
legend_labels.extend(legend_labels_min_values)

plt.xlabel('Relative Tolerance')
plt.ylabel('Normalized Values')
plt.title('Normalized Categorical Crossentropy, Norm L2, and Mean vs Relative Tolerance')

# Adjust legend position to be outside the plot
plt.legend(legend_labels, loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
# Valores de x e y
x_values = tolerances
y1_values = best_ce_loss_values
y2_values = ce_values

# Plotar o gráfico de pontos
plt.plot(x_values, y1_values, 'bo', label='Best Value')
plt.plot(x_values, y2_values, 'ro', label='Final Value')

# Conectar os pontos com uma linha
for i in range(len(x_values)):
    if y2_values[i] > y1_values[i]:
        plt.plot([x_values[i], x_values[i]], [y1_values[i], y2_values[i]], 'r--')
    elif y2_values[i] < y1_values[i]:
        plt.plot([x_values[i], x_values[i]], [y1_values[i], y2_values[i]], 'g--')

plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Variação da Categorical Crossentropy Durante a Otimização da Norma L2 Vs Tolerância Relativa')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
training_times_array = np.array(training_times)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(training_times_array, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, training_times_array, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Gerando pontos 3D
x = np.array([point[0] for point in coordenates_values])
y = np.array([point[1] for point in coordenates_values])
z = np.array(tolerances)

# Definindo cores com base na tolerância (ou qualquer outra variável)
colors = z

# Plotando
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x, y, z, c=colors, cmap='plasma')  # Usando cmap='plasma' para um gradiente de cores diferente

plt.title('Número de épocas para encontrar o melhor valor vs Tolerancia Relativa')
ax.set_xlabel('Categorical Crossentropy')
ax.set_ylabel('Norma L2')
ax.set_zlabel('Tolerância Relativa')

# Definindo intervalos para os eixos x e y
ax.set_xticks(np.arange(min(x), max(x)+1, 1))
ax.set_yticks(np.arange(min(y), max(y)+1, 1))

# Adicionando barra de cores
plt.colorbar(sc, label='Tolerância Relativa')

plt.show()

# %%
# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(x, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, x, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(y, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, y, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
sum = x + y

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(sum, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, sum, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2 + Categorical Crossentropy')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
def sort_models(CE, L2, Time, Tol, AC, min_indices):
    num_models = len(CE)
    decimal_places = 2

    while True:
        # Ordenar os modelos de acordo com a Categorical Crossentropy
        indices = sorted(range(num_models), key=lambda i: (round(CE[i], decimal_places), round(L2[i], decimal_places), round(Time[i], decimal_places)))

        # Verificar se há empates
        is_tie = False
        for i in range(1, num_models):
            if CE[indices[i]] == CE[indices[i - 1]] and \
               L2[indices[i]] == L2[indices[i - 1]] and \
               Time[indices[i]] == Time[indices[i - 1]]:
                is_tie = True
                break

        # Se não houver empates, terminar o loop
        if not is_tie:
            break

        # Aumentar as casas decimais em caso de empate
        decimal_places += 1

    # Imprimir os modelos ordenados
    for i, idx in enumerate(indices):
        print(f'{i+1}º:')
        print(f' - Model {min_indices[idx]+1}: (Relative Tolerance={Tol[idx]}; Accuracy={AC[idx]})')
        print(f'   + Categorical Crossentropy: {CE[idx]}')
        print(f'   + Norm L2: {L2[idx]}')
        print(f'   + Training Time (seconds): {Time[idx]}')
        print()

    return Tol[0]

# %%
CE, L2, Time, Tol, AC = [], [], [], [], []

for i in range(len(min_indices)):
 CE.append(ce_values_array[min_indices[i]])
 L2.append(l2_values_array[min_indices[i]])
 Time.append(training_times_array[min_indices[i]])
 Tol.append(tolerances[min_indices[i]])
 AC.append(accuracy_values_array[min_indices[i]])

Best_Tolerance = sort_models(CE, L2, Time, Tol, AC, min_indices)
# Out:
# 1º:
#  - Model 32: (Relative Tolerance=16.43125; Accuracy=0.7852563858032227)
#    + Categorical Crossentropy: 2.083155870437622
#    + Norm L2: 12.574808120727539
#    + Training Time (seconds): 9.681779146194458
#
# 2º:
#  - Model 9: (Relative Tolerance=14.850000000000001; Accuracy=0.8333333134651184)
#    + Categorical Crossentropy: 2.1766395568847656
#    + Norm L2: 7.56373405456543
#    + Training Time (seconds): 8.187946081161499
#
# 3º:
#  - Model 16: (Relative Tolerance=15.33125; Accuracy=0.8846153616905212)
#    + Categorical Crossentropy: 2.182124376296997
#    + Norm L2: 7.575129985809326
#    + Training Time (seconds): 9.25894808769226

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)

best_ce_loss, best_L2_loss  = float('inf'), float('inf')
upgrading = 0
tolerance = Best_Tolerance
changed = False
first_run = True

current_model, checkpoint = build_model()
best_model, checkpoint = build_model()

while upgrading < 4:

    current_model, checkpoint = clonning(best_model, changed)
    training_history = current_model.fit(train_images, train_labels, validation_data=(validation_images, validation_labels), epochs=1, batch_size=32, verbose=1, callbacks=[checkpoint])

    current_L2 = training_history.history["val_l2_complexity"][0]
    current_CE = training_history.history["val_categorical_crossentropy"][0]

    if (current_CE<best_ce_loss and not changed) or first_run:
      print("Best so far")
      first_run = False
      coordenates[0] += 1
      best_model, checkpoint = clonning(current_model, changed)
      best_ce_loss = current_CE
      best_L2_loss = current_L2
      upgrading = 0
    elif(current_CE<best_ce_loss*(1 + tolerance) and current_L2<best_L2_loss and changed):
      print("Best so far")
      coordenates[1] += 1
      best_model, checkpoint = clonning(current_model, changed)
      best_L2_loss = current_L2
      upgrading = 2
    else:
      upgrading += 1

    if upgrading==2 and not changed:
      best_model, checkpoint = rebuild_model(best_model)
      current_model, checkpoint = rebuild_model(best_model)
      print("loss function changed")
      changed = True
# Out:
# 148/148 [==============================] - 1s 3ms/step - loss: 0.2220 - categorical_crossentropy: 0.2220 - l2_complexity: 10304.3916 - accuracy: 0.9216 - val_loss: 0.1334 - val_categorical_crossentropy: 0.1334 - val_l2_complexity: 1205.9199 - val_accuracy: 0.9523
# Best so far
# 148/148 [==============================] - 1s 4ms/step - loss: 0.1255 - categorical_crossentropy: 0.1255 - l2_complexity: 10714.8252 - accuracy: 0.9548 - val_loss: 0.1362 - val_categorical_crossentropy: 0.1362 - val_l2_complexity: 1253.5135 - val_accuracy: 0.9427
# 148/148 [==============================] - 1s 3ms/step - loss: 0.1255 - categorical_crossentropy: 0.1255 - l2_complexity: 10714.8252 - accuracy: 0.9548 - val_loss: 0.1362 - val_categorical_crossentropy: 0.1362 - val_l2_complexity: 1253.5135 - val_accuracy: 0.9427
# loss function changed
# 148/148 [==============================] - 1s 3ms/step - loss: 14.7110 - categorical_crossentropy: 1.1992 - l2_complexity: 2093.8997 - accuracy: 0.9582 - val_loss: 0.2472 - val_categorical_crossentropy: 2.2518 - val_l2_complexity: 4.2026 - val_accuracy: 0.9504
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 0.0098 - categorical_crossentropy: 2.3014 - l2_complexity: 1.1879 - accuracy: 0.2332 - val_loss: 2.3704e-08 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.0297e-07 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.3205e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0341 - accuracy: 0.1189 - val_loss: 1.0849e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 1.8443e-08 - val_accuracy: 0.0000e+00
# Best so far
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5024e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1060 - val_loss: 1.4067e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.3913e-08 - val_accuracy: 0.0000e+00
# 148/148 [==============================] - 1s 3ms/step - loss: 2.5024e-04 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0368 - accuracy: 0.1060 - val_loss: 1.4067e-09 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.3913e-08 - val_accuracy: 0.0000e+00

# %%
metrics = best_model.evaluate(test_images, test_labels)
# Out:
# 20/20 [==============================] - 0s 1ms/step - loss: 1.0849e-09 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1697e-08 - accuracy: 0.0000e+00

# %%
best_model.save('best_model.h5')
