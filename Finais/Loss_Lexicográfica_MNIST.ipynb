# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import losses
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Metric
from tensorflow.keras import regularizers
from tensorflow.keras import models
import numpy as np
import logging
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(7)
from sklearn.model_selection import train_test_split
import time
import warnings
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model, clone_model
from sklearn.preprocessing import MinMaxScaler

# %%
# Load training and test datasets.
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Divida os dados em conjuntos de treinamento e teste
validation_images, test_images, validation_labels, test_labels = train_test_split(test_images, test_labels, test_size=0.5, random_state=42)

# Standardize the data.
mean = np.mean(train_images)
stddev = np.std(train_images)
train_images = (train_images - mean) / stddev
test_images = (test_images - mean) / stddev
validation_images = (validation_images - mean) / stddev

# One-hot encode labels.
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)
validation_labels = to_categorical(validation_labels, num_classes=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
class L2ComplexityMetric(Metric):
    def __init__(self, name='l2_complexity', **kwargs):
        super(L2ComplexityMetric, self).__init__(name=name, **kwargs)
        self.l2_loss = self.add_weight(name='l2_loss', initializer='zeros')
        self.model = None

    def update_state(self, y_true, y_pred, sample_weight=None):
        if self.model is not None:
            # Calcula a perda de complexidade L2 (regularização L2)
            l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])
            self.l2_loss.assign_add(l2_loss)

    def result(self):
        return self.l2_loss

    def reset_state(self):  # Altere o nome deste método para reset_state
        # Zera as variáveis acumuladas no início de cada época ou avaliação
        self.l2_loss.assign(0.0)

# %%
class categorical_crossentropy_loss(tf.keras.losses.Loss):
    def __init__(self, model=None):
        super(categorical_crossentropy_loss, self).__init__()
        self.model = model

    def call(self, y_true, y_pred):
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return ce_loss

# %%
class l2_loss(tf.keras.losses.Loss):
    def __init__(self, model=None):
        super(l2_loss, self).__init__()
        self.model = model

    def call(self, y_true, y_pred):
        l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])
        return l2_loss

# %%
def neural_network():

  # Ignore UserWarning temporarily
  warnings.filterwarnings("ignore", category=UserWarning)
  # Object used to initialize weights.
  initializer = keras.initializers.RandomUniform(minval=-0.1, maxval=0.1)

  # Create a Sequential model.
  # 784 inputs.
  # Two Dense (fully connected) layers with 25 and 10 neurons.
  # tanh as activation function for hidden layer.
  # Logistic (sigmoid) as activation function for output layer.
  model = keras.Sequential([
      keras.layers.Flatten(input_shape=(28, 28)),
      keras.layers.Dense(50, activation='relu',
                        kernel_initializer=initializer,
                        bias_initializer='zeros'),
      keras.layers.Dense(10, activation='softmax',
                        kernel_initializer=initializer,
                        bias_initializer='zeros')])

  return model

# %%
def build_model(model=None):

  if model==None:
    model = neural_network()

  #Instancie a classe de perda personalizada.
  custom_loss = categorical_crossentropy_loss()
  custom_loss.model = model  # Associando o modelo à função de perda.

  # Criar uma instância da métrica personalizada
  l2_metric = L2ComplexityMetric()
  l2_metric.model = model  # Adicione esta linha para passar a referência do modelo para a métrica

  opt = keras.optimizers.Adam()

  model.compile(loss=custom_loss, optimizer = opt, metrics=['categorical_crossentropy', l2_metric, 'accuracy'])

  # Definindo o callback para salvar o melhor modelo
  checkpoint = ModelCheckpoint('best_model.h5', monitor='categorical_crossentropy', verbose=0, save_best_only=True, mode='min')

  return model, checkpoint

# %%
def rebuild_model(model=None):

  if model==None:
    model = neural_network()

  #Instancie a classe de perda personalizada.
  custom_loss = l2_loss()
  custom_loss.model = model  # Associando o modelo à função de perda.

  # Criar uma instância da métrica personalizada
  l2_metric = L2ComplexityMetric()
  l2_metric.model = model  # Adicione esta linha para passar a referência do modelo para a métrica

  opt = keras.optimizers.Adam()

  model.compile(loss=custom_loss, optimizer = opt, metrics=['categorical_crossentropy', l2_metric, 'accuracy'])

  # Definindo o callback para salvar o melhor modelo
  checkpoint = ModelCheckpoint('best_model.h5', monitor='l2_complexity', verbose=0, save_best_only=True, mode='min')

  return model, checkpoint

# %%
def clonning(old_model, changed):

  new_model = clone_model(old_model)
  new_model.set_weights(old_model.get_weights())

  if not changed:
    model, checkpoint = build_model(new_model)
  else:
    model, checkpoint = rebuild_model(new_model)

  return model, checkpoint

# %%
N = 33
tolerances = np.linspace(20.25, 24, N, endpoint=True)
training_times, ce_values, l2_values, coordenates_values, accuracy_values, best_ce_loss_values, best_L2_loss_values  = [], [], [], [], [], [], []

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)
for i in range(N):

  best_ce_loss, best_L2_loss  = float('inf'), float('inf')
  upgrading = 0
  tolerance = tolerances[i]
  coordenates = [0, 0]
  changed = False
  first_run = True

  print("model", i+1, "- relative tolerance", tolerance, ":")

  current_model, checkpoint = build_model()
  best_model, checkpoint = build_model()

  start_time = time.time()

  while upgrading < 4:

      current_model, checkpoint = clonning(best_model, changed)
      training_history = current_model.fit(train_images, train_labels, validation_data=(validation_images, validation_labels), epochs=1, batch_size=32, verbose=1, callbacks=[checkpoint])

      current_L2 = training_history.history["val_l2_complexity"][0]
      current_CE = training_history.history["val_categorical_crossentropy"][0]

      if (current_CE<best_ce_loss and not changed) or first_run:
        print("Best so far")
        first_run = False
        coordenates[0] += 1
        best_model, checkpoint = clonning(current_model, changed)
        best_ce_loss = current_CE
        best_L2_loss = current_L2
        upgrading = 0
      elif(current_CE<best_ce_loss*(1 + tolerance) and current_L2<best_L2_loss and changed):
        print("Best so far")
        coordenates[1] += 1
        best_model, checkpoint = clonning(current_model, changed)
        best_L2_loss = current_L2
        upgrading = 2
      else:
        upgrading += 1

      if upgrading==2 and not changed:
        best_model, checkpoint = rebuild_model(best_model)
        current_model, checkpoint = rebuild_model(best_model)
        print("loss function changed")
        changed = True

  end_time = time.time()
  delta_time = end_time - start_time
  training_times.append(delta_time)

  metrics = best_model.evaluate(test_images, test_labels)
  ce_values.append(metrics[1])
  l2_values.append(metrics[2])
  accuracy_values.append(metrics[3])

  coordenates_values.append(coordenates)

  best_ce_loss_values.append(best_ce_loss)
  best_L2_loss_values.append(best_L2_loss)

  print("best categorical cross entropy:", best_ce_loss)
  print("best L2:", best_L2_loss)
  print("training time:", delta_time, "s")
  print("best model coordenates:", coordenates)
  print("\n")
# Out:
# model 1 - relative tolerance 20.25 :
# 1875/1875 [==============================] - 18s 8ms/step - loss: 0.2831 - categorical_crossentropy: 0.2831 - l2_complexity: 175010.5312 - accuracy: 0.9179 - val_loss: 0.1575 - val_categorical_crossentropy: 0.1575 - val_l2_complexity: 17749.7793 - val_accuracy: 0.9512
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1390 - categorical_crossentropy: 0.1390 - l2_complexity: 247174.7500 - accuracy: 0.9586 - val_loss: 0.1167 - val_categorical_crossentropy: 0.1167 - val_l2_complexity: 23549.4141 - val_accuracy: 0.9636
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1014 - categorical_crossentropy: 0.1014 - l2_complexity: 314228.7500 - accuracy: 0.9691 - val_loss: 0.1011 - val_categorical_crossentropy: 0.1011 - val_l2_complexity: 28967.4141 - val_accuracy: 0.9704
# Best so far
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.0799 - categorical_crossentropy: 0.0799 - l2_complexity: 377850.0625 - accuracy: 0.9760 - val_loss: 0.0963 - val_categorical_crossentropy: 0.0963 - val_l2_complexity: 34267.3789 - val_accuracy: 0.9726
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0656 - categorical_crossentropy: 0.0656 - l2_complexity: 441488.1562 - accuracy: 0.9804 - val_loss: 0.0966 - val_categorical_crossentropy: 0.0966 - val_l2_complexity: 39614.9492 - val_accuracy: 0.9720
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0656 - categorical_crossentropy: 0.0656 - l2_complexity: 441488.1562 - accuracy: 0.9804 - val_loss: 0.0966 - val_categorical_crossentropy: 0.0966 - val_l2_complexity: 39614.9492 - val_accuracy: 0.9720
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.1226 - categorical_crossentropy: 2.0836 - l2_complexity: 16886.5312 - accuracy: 0.2816 - val_loss: 8.8751e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0014 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.1226 - categorical_crossentropy: 2.0836 - l2_complexity: 16886.5312 - accuracy: 0.2816 - val_loss: 8.8751e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0014 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 218.2636 - categorical_crossentropy: 0.1048 - l2_complexity: 34267.3789 - accuracy: 0.9678
# best categorical cross entropy: 0.09630151093006134
# best L2: 34267.37890625
# training time: 74.74684762954712 s
# best model coordenates: [4, 0]
#
#
# model 2 - relative tolerance 20.3671875 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2812 - categorical_crossentropy: 0.2812 - l2_complexity: 177582.9688 - accuracy: 0.9176 - val_loss: 0.1542 - val_categorical_crossentropy: 0.1542 - val_l2_complexity: 17981.8203 - val_accuracy: 0.9540
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1381 - categorical_crossentropy: 0.1381 - l2_complexity: 249451.4688 - accuracy: 0.9582 - val_loss: 0.1176 - val_categorical_crossentropy: 0.1176 - val_l2_complexity: 23625.1348 - val_accuracy: 0.9628
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1010 - categorical_crossentropy: 0.1010 - l2_complexity: 314807.1562 - accuracy: 0.9696 - val_loss: 0.1024 - val_categorical_crossentropy: 0.1024 - val_l2_complexity: 28975.3906 - val_accuracy: 0.9654
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0804 - categorical_crossentropy: 0.0804 - l2_complexity: 378157.9062 - accuracy: 0.9757 - val_loss: 0.0958 - val_categorical_crossentropy: 0.0958 - val_l2_complexity: 34307.9570 - val_accuracy: 0.9682
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - l2_complexity: 442112.5312 - accuracy: 0.9796 - val_loss: 0.0961 - val_categorical_crossentropy: 0.0961 - val_l2_complexity: 39646.2305 - val_accuracy: 0.9696
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - l2_complexity: 442112.5312 - accuracy: 0.9796 - val_loss: 0.0961 - val_categorical_crossentropy: 0.0961 - val_l2_complexity: 39646.2305 - val_accuracy: 0.9696
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.4901 - categorical_crossentropy: 2.0729 - l2_complexity: 17575.3398 - accuracy: 0.2639 - val_loss: 1.3142e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0206 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.4901 - categorical_crossentropy: 2.0729 - l2_complexity: 17575.3398 - accuracy: 0.2639 - val_loss: 1.3142e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0206 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 3ms/step - loss: 218.5220 - categorical_crossentropy: 0.0988 - l2_complexity: 34307.9570 - accuracy: 0.9688
# best categorical cross entropy: 0.09576954692602158
# best L2: 34307.95703125
# training time: 49.76267766952515 s
# best model coordenates: [4, 0]
#
#
# model 3 - relative tolerance 20.484375 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2857 - categorical_crossentropy: 0.2857 - l2_complexity: 177251.4375 - accuracy: 0.9165 - val_loss: 0.1617 - val_categorical_crossentropy: 0.1617 - val_l2_complexity: 17852.1113 - val_accuracy: 0.9482
# Best so far
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.1375 - categorical_crossentropy: 0.1375 - l2_complexity: 247261.4375 - accuracy: 0.9592 - val_loss: 0.1203 - val_categorical_crossentropy: 0.1203 - val_l2_complexity: 23413.0137 - val_accuracy: 0.9600
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1001 - categorical_crossentropy: 0.1001 - l2_complexity: 312102.9062 - accuracy: 0.9702 - val_loss: 0.1074 - val_categorical_crossentropy: 0.1074 - val_l2_complexity: 28719.3418 - val_accuracy: 0.9650
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0806 - categorical_crossentropy: 0.0806 - l2_complexity: 375217.7188 - accuracy: 0.9753 - val_loss: 0.1047 - val_categorical_crossentropy: 0.1047 - val_l2_complexity: 34012.6484 - val_accuracy: 0.9664
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0665 - categorical_crossentropy: 0.0665 - l2_complexity: 439109.2812 - accuracy: 0.9798 - val_loss: 0.1063 - val_categorical_crossentropy: 0.1063 - val_l2_complexity: 39444.3477 - val_accuracy: 0.9674
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0665 - categorical_crossentropy: 0.0665 - l2_complexity: 439109.2812 - accuracy: 0.9798 - val_loss: 0.1063 - val_categorical_crossentropy: 0.1063 - val_l2_complexity: 39444.3477 - val_accuracy: 0.9674
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.2683 - categorical_crossentropy: 2.0719 - l2_complexity: 17161.3398 - accuracy: 0.3090 - val_loss: 1.6707e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0026 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.2683 - categorical_crossentropy: 2.0719 - l2_complexity: 17161.3398 - accuracy: 0.3090 - val_loss: 1.6707e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0026 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 216.6411 - categorical_crossentropy: 0.1126 - l2_complexity: 34012.6484 - accuracy: 0.9682
# best categorical cross entropy: 0.10471607744693756
# best L2: 34012.6484375
# training time: 66.52241158485413 s
# best model coordenates: [4, 0]
#
#
# model 4 - relative tolerance 20.6015625 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2889 - categorical_crossentropy: 0.2889 - l2_complexity: 177546.9375 - accuracy: 0.9144 - val_loss: 0.1633 - val_categorical_crossentropy: 0.1633 - val_l2_complexity: 17953.9766 - val_accuracy: 0.9504
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1434 - categorical_crossentropy: 0.1434 - l2_complexity: 249000.1406 - accuracy: 0.9578 - val_loss: 0.1200 - val_categorical_crossentropy: 0.1200 - val_l2_complexity: 23625.7617 - val_accuracy: 0.9606
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1052 - categorical_crossentropy: 0.1052 - l2_complexity: 313613.0312 - accuracy: 0.9682 - val_loss: 0.1030 - val_categorical_crossentropy: 0.1030 - val_l2_complexity: 28930.9512 - val_accuracy: 0.9678
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0849 - categorical_crossentropy: 0.0849 - l2_complexity: 376991.8125 - accuracy: 0.9744 - val_loss: 0.0920 - val_categorical_crossentropy: 0.0920 - val_l2_complexity: 34202.3594 - val_accuracy: 0.9732
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0711 - categorical_crossentropy: 0.0711 - l2_complexity: 440191.7812 - accuracy: 0.9785 - val_loss: 0.0944 - val_categorical_crossentropy: 0.0944 - val_l2_complexity: 39504.2617 - val_accuracy: 0.9734
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0711 - categorical_crossentropy: 0.0711 - l2_complexity: 440191.7812 - accuracy: 0.9785 - val_loss: 0.0944 - val_categorical_crossentropy: 0.0944 - val_l2_complexity: 39504.2617 - val_accuracy: 0.9734
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 9.0955 - categorical_crossentropy: 2.0865 - l2_complexity: 16836.2715 - accuracy: 0.2793 - val_loss: 2.7264e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.2804e-04 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.0955 - categorical_crossentropy: 2.0865 - l2_complexity: 16836.2715 - accuracy: 0.2793 - val_loss: 2.7264e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.2804e-04 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 217.8494 - categorical_crossentropy: 0.1101 - l2_complexity: 34202.3594 - accuracy: 0.9666
# best categorical cross entropy: 0.09202861785888672
# best L2: 34202.359375
# training time: 53.66164255142212 s
# best model coordenates: [4, 0]
#
#
# model 5 - relative tolerance 20.71875 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2816 - categorical_crossentropy: 0.2816 - l2_complexity: 178218.0000 - accuracy: 0.9179 - val_loss: 0.1461 - val_categorical_crossentropy: 0.1461 - val_l2_complexity: 18139.4629 - val_accuracy: 0.9560
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1357 - categorical_crossentropy: 0.1357 - l2_complexity: 250919.4375 - accuracy: 0.9593 - val_loss: 0.1100 - val_categorical_crossentropy: 0.1100 - val_l2_complexity: 23743.0840 - val_accuracy: 0.9658
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0998 - categorical_crossentropy: 0.0998 - l2_complexity: 314955.1875 - accuracy: 0.9697 - val_loss: 0.0997 - val_categorical_crossentropy: 0.0997 - val_l2_complexity: 28942.9062 - val_accuracy: 0.9694
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0804 - categorical_crossentropy: 0.0804 - l2_complexity: 377194.7188 - accuracy: 0.9759 - val_loss: 0.0987 - val_categorical_crossentropy: 0.0987 - val_l2_complexity: 34123.1953 - val_accuracy: 0.9704
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - l2_complexity: 439215.5312 - accuracy: 0.9799 - val_loss: 0.0980 - val_categorical_crossentropy: 0.0980 - val_l2_complexity: 39319.3633 - val_accuracy: 0.9694
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0567 - categorical_crossentropy: 0.0567 - l2_complexity: 501681.5938 - accuracy: 0.9829 - val_loss: 0.1024 - val_categorical_crossentropy: 0.1024 - val_l2_complexity: 44565.1250 - val_accuracy: 0.9696
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0567 - categorical_crossentropy: 0.0567 - l2_complexity: 501681.5938 - accuracy: 0.9829 - val_loss: 0.1024 - val_categorical_crossentropy: 0.1024 - val_l2_complexity: 44565.1250 - val_accuracy: 0.9696
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 11.9281 - categorical_crossentropy: 2.0377 - l2_complexity: 22114.7246 - accuracy: 0.3122 - val_loss: 4.0571e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0637 - val_accuracy: 0.1202
# 1875/1875 [==============================] - 5s 2ms/step - loss: 11.9281 - categorical_crossentropy: 2.0377 - l2_complexity: 22114.7246 - accuracy: 0.3122 - val_loss: 4.0571e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0637 - val_accuracy: 0.1202
# 157/157 [==============================] - 1s 2ms/step - loss: 250.4418 - categorical_crossentropy: 0.1156 - l2_complexity: 39319.3633 - accuracy: 0.9688
# best categorical cross entropy: 0.09797853976488113
# best L2: 39319.36328125
# training time: 81.14109086990356 s
# best model coordenates: [5, 0]
#
#
# model 6 - relative tolerance 20.8359375 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2838 - categorical_crossentropy: 0.2838 - l2_complexity: 176865.9375 - accuracy: 0.9172 - val_loss: 0.1505 - val_categorical_crossentropy: 0.1505 - val_l2_complexity: 17916.3906 - val_accuracy: 0.9542
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1356 - categorical_crossentropy: 0.1356 - l2_complexity: 249763.1562 - accuracy: 0.9594 - val_loss: 0.1150 - val_categorical_crossentropy: 0.1150 - val_l2_complexity: 23744.2070 - val_accuracy: 0.9628
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0997 - categorical_crossentropy: 0.0997 - l2_complexity: 315447.5625 - accuracy: 0.9699 - val_loss: 0.0993 - val_categorical_crossentropy: 0.0993 - val_l2_complexity: 29041.4043 - val_accuracy: 0.9672
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0805 - categorical_crossentropy: 0.0805 - l2_complexity: 378224.5938 - accuracy: 0.9753 - val_loss: 0.1002 - val_categorical_crossentropy: 0.1002 - val_l2_complexity: 34241.9492 - val_accuracy: 0.9676
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0805 - categorical_crossentropy: 0.0805 - l2_complexity: 378224.5938 - accuracy: 0.9753 - val_loss: 0.1002 - val_categorical_crossentropy: 0.1002 - val_l2_complexity: 34241.9492 - val_accuracy: 0.9676
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 7.0807 - categorical_crossentropy: 2.1082 - l2_complexity: 13091.3096 - accuracy: 0.2591 - val_loss: 3.7083e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0058 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 2ms/step - loss: 7.0807 - categorical_crossentropy: 2.1082 - l2_complexity: 13091.3096 - accuracy: 0.2591 - val_loss: 3.7083e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0058 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 3ms/step - loss: 184.9771 - categorical_crossentropy: 0.1118 - l2_complexity: 29041.4043 - accuracy: 0.9668
# best categorical cross entropy: 0.09927798807621002
# best L2: 29041.404296875
# training time: 41.45049858093262 s
# best model coordenates: [3, 0]
#
#
# model 7 - relative tolerance 20.953125 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2791 - categorical_crossentropy: 0.2791 - l2_complexity: 179346.7344 - accuracy: 0.9173 - val_loss: 0.1444 - val_categorical_crossentropy: 0.1444 - val_l2_complexity: 18158.9180 - val_accuracy: 0.9568
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1364 - categorical_crossentropy: 0.1364 - l2_complexity: 252052.2969 - accuracy: 0.9597 - val_loss: 0.1114 - val_categorical_crossentropy: 0.1114 - val_l2_complexity: 23826.6699 - val_accuracy: 0.9654
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1013 - categorical_crossentropy: 0.1013 - l2_complexity: 315608.5625 - accuracy: 0.9696 - val_loss: 0.1043 - val_categorical_crossentropy: 0.1043 - val_l2_complexity: 28942.0488 - val_accuracy: 0.9682
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0819 - categorical_crossentropy: 0.0819 - l2_complexity: 376198.6250 - accuracy: 0.9752 - val_loss: 0.0999 - val_categorical_crossentropy: 0.0999 - val_l2_complexity: 34010.3516 - val_accuracy: 0.9692
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0684 - categorical_crossentropy: 0.0684 - l2_complexity: 436535.3125 - accuracy: 0.9792 - val_loss: 0.1022 - val_categorical_crossentropy: 0.1022 - val_l2_complexity: 39054.3594 - val_accuracy: 0.9684
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0684 - categorical_crossentropy: 0.0684 - l2_complexity: 436535.3125 - accuracy: 0.9792 - val_loss: 0.1022 - val_categorical_crossentropy: 0.1022 - val_l2_complexity: 39054.3594 - val_accuracy: 0.9684
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 8.9217 - categorical_crossentropy: 2.0793 - l2_complexity: 16511.6504 - accuracy: 0.3392 - val_loss: 2.5101e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9409e-04 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 3ms/step - loss: 8.9217 - categorical_crossentropy: 2.0793 - l2_complexity: 16511.6504 - accuracy: 0.3392 - val_loss: 2.5101e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9409e-04 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 216.6264 - categorical_crossentropy: 0.1166 - l2_complexity: 34010.3516 - accuracy: 0.9650
# best categorical cross entropy: 0.09992929548025131
# best L2: 34010.3515625
# training time: 61.02681231498718 s
# best model coordenates: [4, 0]
#
#
# model 8 - relative tolerance 21.0703125 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2804 - categorical_crossentropy: 0.2804 - l2_complexity: 177896.5156 - accuracy: 0.9180 - val_loss: 0.1543 - val_categorical_crossentropy: 0.1543 - val_l2_complexity: 18010.8418 - val_accuracy: 0.9514
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1358 - categorical_crossentropy: 0.1358 - l2_complexity: 248864.1094 - accuracy: 0.9592 - val_loss: 0.1192 - val_categorical_crossentropy: 0.1192 - val_l2_complexity: 23517.4707 - val_accuracy: 0.9640
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1007 - categorical_crossentropy: 0.1007 - l2_complexity: 311298.2500 - accuracy: 0.9693 - val_loss: 0.1067 - val_categorical_crossentropy: 0.1067 - val_l2_complexity: 28632.8809 - val_accuracy: 0.9666
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0812 - categorical_crossentropy: 0.0812 - l2_complexity: 372508.5000 - accuracy: 0.9753 - val_loss: 0.1101 - val_categorical_crossentropy: 0.1101 - val_l2_complexity: 33739.3711 - val_accuracy: 0.9666
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0812 - categorical_crossentropy: 0.0812 - l2_complexity: 372508.5000 - accuracy: 0.9753 - val_loss: 0.1101 - val_categorical_crossentropy: 0.1101 - val_l2_complexity: 33739.3711 - val_accuracy: 0.9666
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 6.7952 - categorical_crossentropy: 2.1069 - l2_complexity: 12558.6934 - accuracy: 0.3314 - val_loss: 5.7036e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.9547e-04 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 5.5615e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0104 - accuracy: 0.0938 - val_loss: 4.5803e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.1911e-04 - val_accuracy: 0.1338
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.8727e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0073 - accuracy: 0.0977 - val_loss: 3.9020e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.1261e-04 - val_accuracy: 0.0658
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.5991e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0067 - accuracy: 0.0961 - val_loss: 4.6465e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.2950e-04 - val_accuracy: 0.1094
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.5991e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0067 - accuracy: 0.0961 - val_loss: 4.6465e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.2950e-04 - val_accuracy: 0.1094
# 157/157 [==============================] - 1s 2ms/step - loss: 3.9020e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 6.1261e-04 - accuracy: 0.0650
# best categorical cross entropy: 0.10666172951459885
# best L2: 0.0006126126390881836
# training time: 66.80071592330933 s
# best model coordenates: [3, 3]
#
#
# model 9 - relative tolerance 21.1875 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2775 - categorical_crossentropy: 0.2775 - l2_complexity: 177068.5469 - accuracy: 0.9190 - val_loss: 0.1578 - val_categorical_crossentropy: 0.1578 - val_l2_complexity: 17931.5566 - val_accuracy: 0.9522
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1305 - categorical_crossentropy: 0.1305 - l2_complexity: 247885.6719 - accuracy: 0.9605 - val_loss: 0.1183 - val_categorical_crossentropy: 0.1183 - val_l2_complexity: 23483.5410 - val_accuracy: 0.9624
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0962 - categorical_crossentropy: 0.0962 - l2_complexity: 312270.0000 - accuracy: 0.9702 - val_loss: 0.1103 - val_categorical_crossentropy: 0.1103 - val_l2_complexity: 28769.8730 - val_accuracy: 0.9642
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0771 - categorical_crossentropy: 0.0771 - l2_complexity: 374250.3750 - accuracy: 0.9761 - val_loss: 0.1106 - val_categorical_crossentropy: 0.1106 - val_l2_complexity: 33935.8984 - val_accuracy: 0.9646
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0771 - categorical_crossentropy: 0.0771 - l2_complexity: 374250.3750 - accuracy: 0.9761 - val_loss: 0.1106 - val_categorical_crossentropy: 0.1106 - val_l2_complexity: 33935.8984 - val_accuracy: 0.9646
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 7.1107 - categorical_crossentropy: 2.1067 - l2_complexity: 13149.2422 - accuracy: 0.2657 - val_loss: 1.5572e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0024 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 5.3697e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0101 - accuracy: 0.0957 - val_loss: 3.1047e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.8744e-04 - val_accuracy: 0.0994
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.6711e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0069 - accuracy: 0.0960 - val_loss: 3.5081e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.5076e-04 - val_accuracy: 0.1616
# 1875/1875 [==============================] - 6s 3ms/step - loss: 3.6711e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0069 - accuracy: 0.0960 - val_loss: 3.5081e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.5076e-04 - val_accuracy: 0.1616
# 157/157 [==============================] - 1s 2ms/step - loss: 3.1047e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 4.8744e-04 - accuracy: 0.1024
# best categorical cross entropy: 0.11028016358613968
# best L2: 0.00048744305968284607
# training time: 61.95058608055115 s
# best model coordenates: [3, 2]
#
#
# model 10 - relative tolerance 21.3046875 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2877 - categorical_crossentropy: 0.2877 - l2_complexity: 175381.4375 - accuracy: 0.9157 - val_loss: 0.1629 - val_categorical_crossentropy: 0.1629 - val_l2_complexity: 17624.1426 - val_accuracy: 0.9498
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1451 - categorical_crossentropy: 0.1451 - l2_complexity: 243489.4219 - accuracy: 0.9572 - val_loss: 0.1298 - val_categorical_crossentropy: 0.1298 - val_l2_complexity: 23029.3223 - val_accuracy: 0.9604
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1089 - categorical_crossentropy: 0.1089 - l2_complexity: 306066.5938 - accuracy: 0.9675 - val_loss: 0.1118 - val_categorical_crossentropy: 0.1118 - val_l2_complexity: 28192.9141 - val_accuracy: 0.9644
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0876 - categorical_crossentropy: 0.0876 - l2_complexity: 367703.0000 - accuracy: 0.9736 - val_loss: 0.1162 - val_categorical_crossentropy: 0.1162 - val_l2_complexity: 33367.1641 - val_accuracy: 0.9638
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0876 - categorical_crossentropy: 0.0876 - l2_complexity: 367703.0000 - accuracy: 0.9736 - val_loss: 0.1162 - val_categorical_crossentropy: 0.1162 - val_l2_complexity: 33367.1641 - val_accuracy: 0.9638
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 6.5682 - categorical_crossentropy: 2.1172 - l2_complexity: 12135.7910 - accuracy: 0.3361 - val_loss: 6.2206e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0098 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 5.6249e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0105 - accuracy: 0.0959 - val_loss: 2.5463e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.9977e-04 - val_accuracy: 0.1028
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.7241e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0070 - accuracy: 0.0964 - val_loss: 4.3851e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8846e-04 - val_accuracy: 0.0906
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.7241e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0070 - accuracy: 0.0964 - val_loss: 4.3851e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8846e-04 - val_accuracy: 0.0906
# 157/157 [==============================] - 1s 2ms/step - loss: 2.5463e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 3.9977e-04 - accuracy: 0.0974
# best categorical cross entropy: 0.11182267963886261
# best L2: 0.0003997684398200363
# training time: 55.555723905563354 s
# best model coordenates: [3, 2]
#
#
# model 11 - relative tolerance 21.421875 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2976 - categorical_crossentropy: 0.2976 - l2_complexity: 174537.6250 - accuracy: 0.9126 - val_loss: 0.1640 - val_categorical_crossentropy: 0.1640 - val_l2_complexity: 17619.9121 - val_accuracy: 0.9506
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1458 - categorical_crossentropy: 0.1458 - l2_complexity: 245545.5312 - accuracy: 0.9571 - val_loss: 0.1248 - val_categorical_crossentropy: 0.1248 - val_l2_complexity: 23261.9766 - val_accuracy: 0.9628
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1073 - categorical_crossentropy: 0.1073 - l2_complexity: 309509.1875 - accuracy: 0.9679 - val_loss: 0.1061 - val_categorical_crossentropy: 0.1061 - val_l2_complexity: 28485.3789 - val_accuracy: 0.9670
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0864 - categorical_crossentropy: 0.0864 - l2_complexity: 370441.1250 - accuracy: 0.9736 - val_loss: 0.1088 - val_categorical_crossentropy: 0.1088 - val_l2_complexity: 33540.7344 - val_accuracy: 0.9672
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0864 - categorical_crossentropy: 0.0864 - l2_complexity: 370441.1250 - accuracy: 0.9736 - val_loss: 0.1088 - val_categorical_crossentropy: 0.1088 - val_l2_complexity: 33540.7344 - val_accuracy: 0.9672
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 6.6768 - categorical_crossentropy: 2.1189 - l2_complexity: 12337.6016 - accuracy: 0.2270 - val_loss: 3.5737e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.6107e-05 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 5.4801e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0103 - accuracy: 0.0977 - val_loss: 2.1603e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.3917e-04 - val_accuracy: 0.1180
# 1875/1875 [==============================] - 6s 3ms/step - loss: 5.4801e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0103 - accuracy: 0.0977 - val_loss: 2.1603e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.3917e-04 - val_accuracy: 0.1180
# 157/157 [==============================] - 1s 2ms/step - loss: 3.5737e-07 - categorical_crossentropy: 2.3026 - l2_complexity: 5.6107e-05 - accuracy: 0.0988
# best categorical cross entropy: 0.1061474084854126
# best L2: 5.61066044610925e-05
# training time: 65.25389909744263 s
# best model coordenates: [3, 1]
#
#
# model 12 - relative tolerance 21.5390625 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2809 - categorical_crossentropy: 0.2809 - l2_complexity: 179224.1562 - accuracy: 0.9183 - val_loss: 0.1504 - val_categorical_crossentropy: 0.1504 - val_l2_complexity: 18141.4395 - val_accuracy: 0.9514
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1375 - categorical_crossentropy: 0.1375 - l2_complexity: 251288.9688 - accuracy: 0.9587 - val_loss: 0.1157 - val_categorical_crossentropy: 0.1157 - val_l2_complexity: 23849.8750 - val_accuracy: 0.9632
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1025 - categorical_crossentropy: 0.1025 - l2_complexity: 316884.1250 - accuracy: 0.9693 - val_loss: 0.1039 - val_categorical_crossentropy: 0.1039 - val_l2_complexity: 29155.1484 - val_accuracy: 0.9660
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0833 - categorical_crossentropy: 0.0833 - l2_complexity: 379413.6875 - accuracy: 0.9746 - val_loss: 0.0983 - val_categorical_crossentropy: 0.0983 - val_l2_complexity: 34280.5781 - val_accuracy: 0.9686
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0699 - categorical_crossentropy: 0.0699 - l2_complexity: 440715.2188 - accuracy: 0.9791 - val_loss: 0.0978 - val_categorical_crossentropy: 0.0978 - val_l2_complexity: 39446.2344 - val_accuracy: 0.9714
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0603 - categorical_crossentropy: 0.0603 - l2_complexity: 502599.0312 - accuracy: 0.9819 - val_loss: 0.1011 - val_categorical_crossentropy: 0.1011 - val_l2_complexity: 44597.7578 - val_accuracy: 0.9704
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0603 - categorical_crossentropy: 0.0603 - l2_complexity: 502599.0312 - accuracy: 0.9819 - val_loss: 0.1011 - val_categorical_crossentropy: 0.1011 - val_l2_complexity: 44597.7578 - val_accuracy: 0.9704
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 11.7780 - categorical_crossentropy: 2.0527 - l2_complexity: 21832.5762 - accuracy: 0.3746 - val_loss: 3.4842e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0055 - val_accuracy: 0.1912
# 1875/1875 [==============================] - 5s 2ms/step - loss: 11.7780 - categorical_crossentropy: 2.0527 - l2_complexity: 21832.5762 - accuracy: 0.3746 - val_loss: 3.4842e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0055 - val_accuracy: 0.1912
# 157/157 [==============================] - 1s 2ms/step - loss: 251.2499 - categorical_crossentropy: 0.1055 - l2_complexity: 39446.2344 - accuracy: 0.9708
# best categorical cross entropy: 0.0977872833609581
# best L2: 39446.234375
# training time: 58.758975982666016 s
# best model coordenates: [5, 0]
#
#
# model 13 - relative tolerance 21.65625 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2811 - categorical_crossentropy: 0.2811 - l2_complexity: 177414.1250 - accuracy: 0.9174 - val_loss: 0.1547 - val_categorical_crossentropy: 0.1547 - val_l2_complexity: 17941.8594 - val_accuracy: 0.9540
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1344 - categorical_crossentropy: 0.1344 - l2_complexity: 249388.9062 - accuracy: 0.9602 - val_loss: 0.1224 - val_categorical_crossentropy: 0.1224 - val_l2_complexity: 23605.2773 - val_accuracy: 0.9622
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0994 - categorical_crossentropy: 0.0994 - l2_complexity: 314458.4688 - accuracy: 0.9696 - val_loss: 0.1070 - val_categorical_crossentropy: 0.1070 - val_l2_complexity: 28918.0293 - val_accuracy: 0.9656
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0799 - categorical_crossentropy: 0.0799 - l2_complexity: 377720.3438 - accuracy: 0.9753 - val_loss: 0.0959 - val_categorical_crossentropy: 0.0959 - val_l2_complexity: 34157.5898 - val_accuracy: 0.9708
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0675 - categorical_crossentropy: 0.0675 - l2_complexity: 439965.5312 - accuracy: 0.9792 - val_loss: 0.0976 - val_categorical_crossentropy: 0.0976 - val_l2_complexity: 39429.9414 - val_accuracy: 0.9710
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0675 - categorical_crossentropy: 0.0675 - l2_complexity: 439965.5312 - accuracy: 0.9792 - val_loss: 0.0976 - val_categorical_crossentropy: 0.0976 - val_l2_complexity: 39429.9414 - val_accuracy: 0.9710
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.4371 - categorical_crossentropy: 2.0729 - l2_complexity: 17476.9785 - accuracy: 0.2995 - val_loss: 2.8613e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0449 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.4371 - categorical_crossentropy: 2.0729 - l2_complexity: 17476.9785 - accuracy: 0.2995 - val_loss: 2.8613e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0449 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 217.5643 - categorical_crossentropy: 0.1061 - l2_complexity: 34157.5898 - accuracy: 0.9698
# best categorical cross entropy: 0.0959409698843956
# best L2: 34157.58984375
# training time: 63.483970403671265 s
# best model coordenates: [4, 0]
#
#
# model 14 - relative tolerance 21.7734375 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2796 - categorical_crossentropy: 0.2796 - l2_complexity: 178375.9844 - accuracy: 0.9182 - val_loss: 0.1470 - val_categorical_crossentropy: 0.1470 - val_l2_complexity: 18082.6309 - val_accuracy: 0.9550
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1345 - categorical_crossentropy: 0.1345 - l2_complexity: 249084.9375 - accuracy: 0.9597 - val_loss: 0.1100 - val_categorical_crossentropy: 0.1100 - val_l2_complexity: 23570.8242 - val_accuracy: 0.9642
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0988 - categorical_crossentropy: 0.0988 - l2_complexity: 313220.6250 - accuracy: 0.9701 - val_loss: 0.1015 - val_categorical_crossentropy: 0.1015 - val_l2_complexity: 28898.4238 - val_accuracy: 0.9680
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0793 - categorical_crossentropy: 0.0793 - l2_complexity: 375516.2188 - accuracy: 0.9757 - val_loss: 0.0978 - val_categorical_crossentropy: 0.0978 - val_l2_complexity: 34043.2461 - val_accuracy: 0.9698
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0663 - categorical_crossentropy: 0.0663 - l2_complexity: 437243.3438 - accuracy: 0.9795 - val_loss: 0.0947 - val_categorical_crossentropy: 0.0947 - val_l2_complexity: 39205.9062 - val_accuracy: 0.9710
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0565 - categorical_crossentropy: 0.0565 - l2_complexity: 499851.1875 - accuracy: 0.9825 - val_loss: 0.0979 - val_categorical_crossentropy: 0.0979 - val_l2_complexity: 44463.5078 - val_accuracy: 0.9700
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0565 - categorical_crossentropy: 0.0565 - l2_complexity: 499851.1875 - accuracy: 0.9825 - val_loss: 0.0979 - val_categorical_crossentropy: 0.0979 - val_l2_complexity: 44463.5078 - val_accuracy: 0.9700
# loss function changed
# 1875/1875 [==============================] - 4s 2ms/step - loss: 11.5878 - categorical_crossentropy: 2.0482 - l2_complexity: 21477.3242 - accuracy: 0.3772 - val_loss: 1.6117e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0025 - val_accuracy: 0.1872
# 1875/1875 [==============================] - 5s 2ms/step - loss: 11.5878 - categorical_crossentropy: 2.0482 - l2_complexity: 21477.3242 - accuracy: 0.3772 - val_loss: 1.6117e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0025 - val_accuracy: 0.1872
# 157/157 [==============================] - 1s 2ms/step - loss: 249.7191 - categorical_crossentropy: 0.1150 - l2_complexity: 39205.9062 - accuracy: 0.9662
# best categorical cross entropy: 0.09472627192735672
# best L2: 39205.90625
# training time: 55.533607006073 s
# best model coordenates: [5, 0]
#
#
# model 15 - relative tolerance 21.890625 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2743 - categorical_crossentropy: 0.2743 - l2_complexity: 177622.5625 - accuracy: 0.9193 - val_loss: 0.1422 - val_categorical_crossentropy: 0.1422 - val_l2_complexity: 17944.3008 - val_accuracy: 0.9580
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1313 - categorical_crossentropy: 0.1313 - l2_complexity: 249486.8125 - accuracy: 0.9611 - val_loss: 0.1079 - val_categorical_crossentropy: 0.1079 - val_l2_complexity: 23696.5664 - val_accuracy: 0.9662
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0972 - categorical_crossentropy: 0.0972 - l2_complexity: 314406.8750 - accuracy: 0.9706 - val_loss: 0.0957 - val_categorical_crossentropy: 0.0957 - val_l2_complexity: 28961.2168 - val_accuracy: 0.9706
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0789 - categorical_crossentropy: 0.0789 - l2_complexity: 375971.7812 - accuracy: 0.9762 - val_loss: 0.0968 - val_categorical_crossentropy: 0.0968 - val_l2_complexity: 34027.0078 - val_accuracy: 0.9700
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0789 - categorical_crossentropy: 0.0789 - l2_complexity: 375971.7812 - accuracy: 0.9762 - val_loss: 0.0968 - val_categorical_crossentropy: 0.0968 - val_l2_complexity: 34027.0078 - val_accuracy: 0.9700
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 7.0284 - categorical_crossentropy: 2.1070 - l2_complexity: 12993.7344 - accuracy: 0.2433 - val_loss: 3.8490e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.0429e-05 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 5s 2ms/step - loss: 7.0284 - categorical_crossentropy: 2.1070 - l2_complexity: 12993.7344 - accuracy: 0.2433 - val_loss: 3.8490e-07 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.0429e-05 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 184.4664 - categorical_crossentropy: 0.1145 - l2_complexity: 28961.2168 - accuracy: 0.9664
# best categorical cross entropy: 0.09566426277160645
# best L2: 28961.216796875
# training time: 46.99989557266235 s
# best model coordenates: [3, 0]
#
#
# model 16 - relative tolerance 22.0078125 :
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2841 - categorical_crossentropy: 0.2841 - l2_complexity: 178369.1094 - accuracy: 0.9174 - val_loss: 0.1563 - val_categorical_crossentropy: 0.1563 - val_l2_complexity: 18112.6504 - val_accuracy: 0.9542
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1325 - categorical_crossentropy: 0.1325 - l2_complexity: 250658.1406 - accuracy: 0.9612 - val_loss: 0.1241 - val_categorical_crossentropy: 0.1241 - val_l2_complexity: 23820.7383 - val_accuracy: 0.9614
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0977 - categorical_crossentropy: 0.0977 - l2_complexity: 315674.9062 - accuracy: 0.9706 - val_loss: 0.1123 - val_categorical_crossentropy: 0.1123 - val_l2_complexity: 28999.5371 - val_accuracy: 0.9670
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0789 - categorical_crossentropy: 0.0789 - l2_complexity: 377609.4688 - accuracy: 0.9761 - val_loss: 0.1189 - val_categorical_crossentropy: 0.1189 - val_l2_complexity: 34186.3594 - val_accuracy: 0.9652
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0789 - categorical_crossentropy: 0.0789 - l2_complexity: 377609.4688 - accuracy: 0.9761 - val_loss: 0.1189 - val_categorical_crossentropy: 0.1189 - val_l2_complexity: 34186.3594 - val_accuracy: 0.9652
# loss function changed
# 1875/1875 [==============================] - 5s 3ms/step - loss: 7.1262 - categorical_crossentropy: 2.1021 - l2_complexity: 13176.9365 - accuracy: 0.3158 - val_loss: 5.4915e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 8.6216e-04 - val_accuracy: 0.1604
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 5.4362e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0102 - accuracy: 0.0990 - val_loss: 2.1818e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.4253e-04 - val_accuracy: 0.0766
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 3.7000e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0069 - accuracy: 0.0981 - val_loss: 3.5236e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.5320e-04 - val_accuracy: 0.0940
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.7000e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0069 - accuracy: 0.0981 - val_loss: 3.5236e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.5320e-04 - val_accuracy: 0.0940
# 157/157 [==============================] - 1s 2ms/step - loss: 2.1818e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 3.4253e-04 - accuracy: 0.0840
# best categorical cross entropy: 0.11231406033039093
# best L2: 0.0003425347385928035
# training time: 53.156765937805176 s
# best model coordenates: [3, 2]
#
#
# model 17 - relative tolerance 22.125 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2810 - categorical_crossentropy: 0.2810 - l2_complexity: 177156.1250 - accuracy: 0.9180 - val_loss: 0.1501 - val_categorical_crossentropy: 0.1501 - val_l2_complexity: 17947.0645 - val_accuracy: 0.9560
# Best so far
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1342 - categorical_crossentropy: 0.1342 - l2_complexity: 247821.1562 - accuracy: 0.9601 - val_loss: 0.1054 - val_categorical_crossentropy: 0.1054 - val_l2_complexity: 23432.0234 - val_accuracy: 0.9658
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0986 - categorical_crossentropy: 0.0986 - l2_complexity: 311299.8438 - accuracy: 0.9701 - val_loss: 0.0910 - val_categorical_crossentropy: 0.0910 - val_l2_complexity: 28681.5449 - val_accuracy: 0.9698
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0799 - categorical_crossentropy: 0.0799 - l2_complexity: 372876.1875 - accuracy: 0.9754 - val_loss: 0.0865 - val_categorical_crossentropy: 0.0865 - val_l2_complexity: 33799.2188 - val_accuracy: 0.9718
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0675 - categorical_crossentropy: 0.0675 - l2_complexity: 433655.0625 - accuracy: 0.9798 - val_loss: 0.0902 - val_categorical_crossentropy: 0.0902 - val_l2_complexity: 38873.4492 - val_accuracy: 0.9702
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0675 - categorical_crossentropy: 0.0675 - l2_complexity: 433655.0625 - accuracy: 0.9798 - val_loss: 0.0902 - val_categorical_crossentropy: 0.0902 - val_l2_complexity: 38873.4492 - val_accuracy: 0.9702
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.2508 - categorical_crossentropy: 2.0786 - l2_complexity: 17129.9277 - accuracy: 0.2696 - val_loss: 2.0681e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0325 - val_accuracy: 0.1282
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.2508 - categorical_crossentropy: 2.0786 - l2_complexity: 17129.9277 - accuracy: 0.2696 - val_loss: 2.0681e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0325 - val_accuracy: 0.1282
# 157/157 [==============================] - 1s 2ms/step - loss: 215.2816 - categorical_crossentropy: 0.1045 - l2_complexity: 33799.2188 - accuracy: 0.9680
# best categorical cross entropy: 0.08649702370166779
# best L2: 33799.21875
# training time: 59.2394495010376 s
# best model coordenates: [4, 0]
#
#
# model 18 - relative tolerance 22.2421875 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2876 - categorical_crossentropy: 0.2876 - l2_complexity: 175523.5469 - accuracy: 0.9154 - val_loss: 0.1529 - val_categorical_crossentropy: 0.1529 - val_l2_complexity: 17788.2246 - val_accuracy: 0.9540
# Best so far
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1384 - categorical_crossentropy: 0.1384 - l2_complexity: 247920.9375 - accuracy: 0.9590 - val_loss: 0.1065 - val_categorical_crossentropy: 0.1065 - val_l2_complexity: 23608.4688 - val_accuracy: 0.9660
# Best so far
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.1006 - categorical_crossentropy: 0.1006 - l2_complexity: 314037.0000 - accuracy: 0.9697 - val_loss: 0.0889 - val_categorical_crossentropy: 0.0889 - val_l2_complexity: 28980.9180 - val_accuracy: 0.9712
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0806 - categorical_crossentropy: 0.0806 - l2_complexity: 377332.3438 - accuracy: 0.9749 - val_loss: 0.0862 - val_categorical_crossentropy: 0.0862 - val_l2_complexity: 34202.9180 - val_accuracy: 0.9718
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0674 - categorical_crossentropy: 0.0674 - l2_complexity: 440263.2812 - accuracy: 0.9791 - val_loss: 0.0894 - val_categorical_crossentropy: 0.0894 - val_l2_complexity: 39422.9336 - val_accuracy: 0.9730
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0674 - categorical_crossentropy: 0.0674 - l2_complexity: 440263.2812 - accuracy: 0.9791 - val_loss: 0.0894 - val_categorical_crossentropy: 0.0894 - val_l2_complexity: 39422.9336 - val_accuracy: 0.9730
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.3087 - categorical_crossentropy: 2.0823 - l2_complexity: 17235.9590 - accuracy: 0.2819 - val_loss: 1.4173e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0223 - val_accuracy: 0.1170
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.3087 - categorical_crossentropy: 2.0823 - l2_complexity: 17235.9590 - accuracy: 0.2819 - val_loss: 1.4173e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0223 - val_accuracy: 0.1170
# 157/157 [==============================] - 1s 2ms/step - loss: 217.8530 - categorical_crossentropy: 0.1055 - l2_complexity: 34202.9180 - accuracy: 0.9694
# best categorical cross entropy: 0.0862186923623085
# best L2: 34202.91796875
# training time: 73.54280853271484 s
# best model coordenates: [4, 0]
#
#
# model 19 - relative tolerance 22.359375 :
# ...
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0647 - categorical_crossentropy: 0.0647 - l2_complexity: 442059.8438 - accuracy: 0.9804 - val_loss: 0.1290 - val_categorical_crossentropy: 0.1290 - val_l2_complexity: 39630.0430 - val_accuracy: 0.9624
# loss function changed
# 1875/1875 [==============================] - 5s 2ms/step - loss: 9.5367 - categorical_crossentropy: 2.0713 - l2_complexity: 17662.9121 - accuracy: 0.3221 - val_loss: 9.8807e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0155 - val_accuracy: 0.0974
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 6.1166e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0114 - accuracy: 0.0951 - val_loss: 3.2973e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 5.1768e-04 - val_accuracy: 0.0916
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 4.2690e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0080 - accuracy: 0.0976 - val_loss: 4.3511e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8312e-04 - val_accuracy: 0.0816
# 1875/1875 [==============================] - 6s 3ms/step - loss: 4.2690e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0080 - accuracy: 0.0976 - val_loss: 4.3511e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.8312e-04 - val_accuracy: 0.0816
# 157/157 [==============================] - 1s 2ms/step - loss: 3.2973e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 5.1768e-04 - accuracy: 0.0966
# best categorical cross entropy: 0.11920146644115448
# best L2: 0.0005176832783035934
# training time: 86.76383924484253 s
# best model coordenates: [4, 2]
#
#
# model 29 - relative tolerance 23.53125 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2890 - categorical_crossentropy: 0.2890 - l2_complexity: 175628.1406 - accuracy: 0.9153 - val_loss: 0.1621 - val_categorical_crossentropy: 0.1621 - val_l2_complexity: 17673.9785 - val_accuracy: 0.9496
# Best so far
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.1427 - categorical_crossentropy: 0.1427 - l2_complexity: 245308.0469 - accuracy: 0.9570 - val_loss: 0.1177 - val_categorical_crossentropy: 0.1177 - val_l2_complexity: 23273.1250 - val_accuracy: 0.9618
# Best so far
# 1875/1875 [==============================] - 9s 3ms/step - loss: 0.1037 - categorical_crossentropy: 0.1037 - l2_complexity: 309289.7812 - accuracy: 0.9681 - val_loss: 0.1013 - val_categorical_crossentropy: 0.1013 - val_l2_complexity: 28532.3184 - val_accuracy: 0.9672
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0826 - categorical_crossentropy: 0.0826 - l2_complexity: 371307.5938 - accuracy: 0.9740 - val_loss: 0.0912 - val_categorical_crossentropy: 0.0912 - val_l2_complexity: 33694.9570 - val_accuracy: 0.9702
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0686 - categorical_crossentropy: 0.0686 - l2_complexity: 432211.9062 - accuracy: 0.9786 - val_loss: 0.0944 - val_categorical_crossentropy: 0.0944 - val_l2_complexity: 38725.0469 - val_accuracy: 0.9722
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0686 - categorical_crossentropy: 0.0686 - l2_complexity: 432211.9062 - accuracy: 0.9786 - val_loss: 0.0944 - val_categorical_crossentropy: 0.0944 - val_l2_complexity: 38725.0469 - val_accuracy: 0.9722
# loss function changed
# 1875/1875 [==============================] - 5s 3ms/step - loss: 8.9802 - categorical_crossentropy: 2.0860 - l2_complexity: 16623.2480 - accuracy: 0.2725 - val_loss: 5.6727e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0089 - val_accuracy: 0.0972
# 1875/1875 [==============================] - 7s 3ms/step - loss: 8.9802 - categorical_crossentropy: 2.0860 - l2_complexity: 16623.2480 - accuracy: 0.2725 - val_loss: 5.6727e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0089 - val_accuracy: 0.0972
# 157/157 [==============================] - 1s 2ms/step - loss: 214.6176 - categorical_crossentropy: 0.0949 - l2_complexity: 33694.9570 - accuracy: 0.9732
# best categorical cross entropy: 0.09122699499130249
# best L2: 33694.95703125
# training time: 94.87313270568848 s
# best model coordenates: [4, 0]
#
#
# model 30 - relative tolerance 23.6484375 :
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2778 - categorical_crossentropy: 0.2778 - l2_complexity: 177946.2969 - accuracy: 0.9181 - val_loss: 0.1561 - val_categorical_crossentropy: 0.1561 - val_l2_complexity: 18029.6797 - val_accuracy: 0.9536
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1337 - categorical_crossentropy: 0.1337 - l2_complexity: 250239.7812 - accuracy: 0.9604 - val_loss: 0.1187 - val_categorical_crossentropy: 0.1187 - val_l2_complexity: 23670.7305 - val_accuracy: 0.9636
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1000 - categorical_crossentropy: 0.1000 - l2_complexity: 314237.0625 - accuracy: 0.9705 - val_loss: 0.1068 - val_categorical_crossentropy: 0.1068 - val_l2_complexity: 28830.7246 - val_accuracy: 0.9670
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0818 - categorical_crossentropy: 0.0818 - l2_complexity: 375036.1562 - accuracy: 0.9752 - val_loss: 0.0969 - val_categorical_crossentropy: 0.0969 - val_l2_complexity: 33827.1250 - val_accuracy: 0.9710
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0699 - categorical_crossentropy: 0.0699 - l2_complexity: 435195.9375 - accuracy: 0.9786 - val_loss: 0.0979 - val_categorical_crossentropy: 0.0979 - val_l2_complexity: 38810.3320 - val_accuracy: 0.9700
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0699 - categorical_crossentropy: 0.0699 - l2_complexity: 435195.9375 - accuracy: 0.9786 - val_loss: 0.0979 - val_categorical_crossentropy: 0.0979 - val_l2_complexity: 38810.3320 - val_accuracy: 0.9700
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.2490 - categorical_crossentropy: 2.0735 - l2_complexity: 17126.4180 - accuracy: 0.2677 - val_loss: 4.7477e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0075 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 5.8894e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0110 - accuracy: 0.0967 - val_loss: 2.8038e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.4020e-04 - val_accuracy: 0.0838
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 4.1672e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0078 - accuracy: 0.0982 - val_loss: 4.2287e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.6390e-04 - val_accuracy: 0.0942
# 1875/1875 [==============================] - 6s 3ms/step - loss: 4.1672e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0078 - accuracy: 0.0982 - val_loss: 4.2287e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.6390e-04 - val_accuracy: 0.0942
# 157/157 [==============================] - 1s 2ms/step - loss: 2.8038e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 4.4020e-04 - accuracy: 0.0810
# best categorical cross entropy: 0.09691167622804642
# best L2: 0.0004401963378768414
# training time: 111.75548553466797 s
# best model coordenates: [4, 2]
#
#
# model 31 - relative tolerance 23.765625 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2872 - categorical_crossentropy: 0.2872 - l2_complexity: 178367.7656 - accuracy: 0.9151 - val_loss: 0.1547 - val_categorical_crossentropy: 0.1547 - val_l2_complexity: 18110.6094 - val_accuracy: 0.9526
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1380 - categorical_crossentropy: 0.1380 - l2_complexity: 251885.1094 - accuracy: 0.9588 - val_loss: 0.1210 - val_categorical_crossentropy: 0.1210 - val_l2_complexity: 23918.5801 - val_accuracy: 0.9636
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1001 - categorical_crossentropy: 0.1001 - l2_complexity: 319101.0625 - accuracy: 0.9697 - val_loss: 0.1057 - val_categorical_crossentropy: 0.1057 - val_l2_complexity: 29482.5957 - val_accuracy: 0.9678
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0793 - categorical_crossentropy: 0.0793 - l2_complexity: 384047.1562 - accuracy: 0.9760 - val_loss: 0.1078 - val_categorical_crossentropy: 0.1078 - val_l2_complexity: 34855.1680 - val_accuracy: 0.9678
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0793 - categorical_crossentropy: 0.0793 - l2_complexity: 384047.1562 - accuracy: 0.9760 - val_loss: 0.1078 - val_categorical_crossentropy: 0.1078 - val_l2_complexity: 34855.1680 - val_accuracy: 0.9678
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.3256 - categorical_crossentropy: 2.1070 - l2_complexity: 13547.6777 - accuracy: 0.2384 - val_loss: 4.0417e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0063 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 5.5099e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0103 - accuracy: 0.0962 - val_loss: 2.1342e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.3507e-04 - val_accuracy: 0.0670
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 3.8182e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0072 - accuracy: 0.0960 - val_loss: 4.2747e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.7112e-04 - val_accuracy: 0.0672
# 1875/1875 [==============================] - 6s 3ms/step - loss: 3.8182e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0072 - accuracy: 0.0960 - val_loss: 4.2747e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 6.7112e-04 - val_accuracy: 0.0672
# 157/157 [==============================] - 1s 2ms/step - loss: 2.1342e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 3.3507e-04 - accuracy: 0.0618
# best categorical cross entropy: 0.10566071420907974
# best L2: 0.0003350665501784533
# training time: 82.38046789169312 s
# best model coordenates: [3, 2]
#
#
# model 32 - relative tolerance 23.8828125 :
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2888 - categorical_crossentropy: 0.2888 - l2_complexity: 177425.4375 - accuracy: 0.9154 - val_loss: 0.1563 - val_categorical_crossentropy: 0.1563 - val_l2_complexity: 17848.4902 - val_accuracy: 0.9506
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1398 - categorical_crossentropy: 0.1398 - l2_complexity: 247676.5469 - accuracy: 0.9587 - val_loss: 0.1203 - val_categorical_crossentropy: 0.1203 - val_l2_complexity: 23461.5820 - val_accuracy: 0.9644
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1010 - categorical_crossentropy: 0.1010 - l2_complexity: 312565.9375 - accuracy: 0.9694 - val_loss: 0.1112 - val_categorical_crossentropy: 0.1112 - val_l2_complexity: 28788.9570 - val_accuracy: 0.9636
# Best so far
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0805 - categorical_crossentropy: 0.0805 - l2_complexity: 375197.6250 - accuracy: 0.9764 - val_loss: 0.1091 - val_categorical_crossentropy: 0.1091 - val_l2_complexity: 34020.8281 - val_accuracy: 0.9654
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - l2_complexity: 437979.3125 - accuracy: 0.9795 - val_loss: 0.1150 - val_categorical_crossentropy: 0.1150 - val_l2_complexity: 39239.5898 - val_accuracy: 0.9650
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - l2_complexity: 437979.3125 - accuracy: 0.9795 - val_loss: 0.1150 - val_categorical_crossentropy: 0.1150 - val_l2_complexity: 39239.5898 - val_accuracy: 0.9650
# loss function changed
# 1875/1875 [==============================] - 7s 3ms/step - loss: 9.2232 - categorical_crossentropy: 2.0744 - l2_complexity: 17076.8281 - accuracy: 0.3611 - val_loss: 1.5753e-05 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0025 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 5.9651e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0112 - accuracy: 0.0972 - val_loss: 3.0209e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 4.7428e-04 - val_accuracy: 0.0776
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 4.2890e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0080 - accuracy: 0.0958 - val_loss: 4.9432e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.7608e-04 - val_accuracy: 0.1028
# 1875/1875 [==============================] - 6s 3ms/step - loss: 4.2890e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0080 - accuracy: 0.0958 - val_loss: 4.9432e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 7.7608e-04 - val_accuracy: 0.1028
# 157/157 [==============================] - 1s 2ms/step - loss: 3.0209e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 4.7428e-04 - accuracy: 0.0862
# best categorical cross entropy: 0.10909820348024368
# best L2: 0.0004742843157146126
# training time: 93.59152293205261 s
# best model coordenates: [4, 2]
#
#
# model 33 - relative tolerance 24.0 :
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2811 - categorical_crossentropy: 0.2811 - l2_complexity: 176928.4062 - accuracy: 0.9178 - val_loss: 0.1497 - val_categorical_crossentropy: 0.1497 - val_l2_complexity: 17915.6172 - val_accuracy: 0.9540
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1341 - categorical_crossentropy: 0.1341 - l2_complexity: 250822.0781 - accuracy: 0.9600 - val_loss: 0.1246 - val_categorical_crossentropy: 0.1246 - val_l2_complexity: 23833.1328 - val_accuracy: 0.9620
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0972 - categorical_crossentropy: 0.0972 - l2_complexity: 317748.8438 - accuracy: 0.9704 - val_loss: 0.1188 - val_categorical_crossentropy: 0.1188 - val_l2_complexity: 29256.0352 - val_accuracy: 0.9604
# Best so far
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0768 - categorical_crossentropy: 0.0768 - l2_complexity: 382259.9062 - accuracy: 0.9765 - val_loss: 0.1211 - val_categorical_crossentropy: 0.1211 - val_l2_complexity: 34650.1562 - val_accuracy: 0.9616
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0768 - categorical_crossentropy: 0.0768 - l2_complexity: 382259.9062 - accuracy: 0.9765 - val_loss: 0.1211 - val_categorical_crossentropy: 0.1211 - val_l2_complexity: 34650.1562 - val_accuracy: 0.9616
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.1189 - categorical_crossentropy: 2.1093 - l2_complexity: 13161.6826 - accuracy: 0.3305 - val_loss: 1.3970e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 2.1933e-04 - val_accuracy: 0.0972
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 5.4383e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0102 - accuracy: 0.0970 - val_loss: 2.2928e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.5997e-04 - val_accuracy: 0.1042
# 1875/1875 [==============================] - 6s 3ms/step - loss: 5.4383e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 0.0102 - accuracy: 0.0970 - val_loss: 2.2928e-06 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 3.5997e-04 - val_accuracy: 0.1042
# 157/157 [==============================] - 1s 2ms/step - loss: 1.3970e-06 - categorical_crossentropy: 2.3026 - l2_complexity: 2.1933e-04 - accuracy: 0.0988
# best categorical cross entropy: 0.1188044399023056
# best L2: 0.0002193266263930127
# training time: 67.03611278533936 s
# best model coordenates: [3, 1]

# %%
# Convert the list to a NumPy array for easier manipulation
accuracy_values_array = np.array(accuracy_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(accuracy_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the original data and the running average
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='blue', linestyle=':', label='Running Average')
plt.plot(tolerances, accuracy_values_array, marker='o', color='red', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
ce_values_array = np.array(ce_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(ce_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the original data and the running average
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='blue', linestyle=':', label='Running Average')
plt.plot(tolerances, ce_values_array, marker='o', color='red', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Categorical Crossentropy vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
l2_values_array = np.array(l2_values)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(l2_values_array, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, l2_values_array, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2')
plt.title('Norm L2 vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Convert the lists to NumPy arrays for easier manipulation
ce_values_array = np.array(ce_values)
l2_values_array = np.array(l2_values)

# Normalize the data between 0 and 1
scaler = MinMaxScaler()
ce_normalized = scaler.fit_transform(ce_values_array.reshape(-1, 1)).flatten()
l2_normalized = scaler.fit_transform(l2_values_array.reshape(-1, 1)).flatten()

# Calculate the mean after normalization
mean_normalized = (ce_normalized + l2_normalized) / 2.0

# Find the indices of the three smallest values of mean_normalized
min_indices = np.argsort(mean_normalized)[:3]
min_values = mean_normalized[min_indices]

# Define marcadores para os três pontos mínimos em ordem crescente
markers = ['*', 'x', 'o']

# Plot the combined graph
plt.figure(figsize=(8, 6))

# Plot Categorical Crossentropy
plt.plot(tolerances, ce_normalized, marker='o', color='red', linestyle=':', label='CE Normalized Data')

# Plot Norm L2
plt.plot(tolerances, l2_normalized, marker='o', color='blue', linestyle=':', label='L2 Normalized Data')

# Plot the mean of CE and L2
plt.plot(tolerances, mean_normalized, marker='d', color='m', label='Mean Normalized Data')

# Highlight the points with the three smallest values using different markers
for value, marker in zip(min_values, markers):
    plt.scatter(tolerances[min_indices[np.where(min_values == value)]], value, color='black', zorder=5, marker=marker)

# Create legend labels for the three smallest values
legend_labels_min_values = [f'Min Value {min_indices[i]+1}: {min_values[i]:.2f} ' for i in range(3)]

# Create legend labels including the values of the three smallest mean_normalized
legend_labels = ['CE Normalized Data', 'L2 Normalized Data', 'Mean Normalized Data']
legend_labels.extend(legend_labels_min_values)

plt.xlabel('Relative Tolerance')
plt.ylabel('Normalized Values')
plt.title('Normalized Categorical Crossentropy, Norm L2, and Mean vs Relative Tolerance')

# Adjust legend position to be outside the plot
plt.legend(legend_labels, loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
# Valores de x e y
x_values = tolerances
y1_values = best_ce_loss_values
y2_values = ce_values

# Plotar o gráfico de pontos
plt.plot(x_values, y1_values, 'bo', label='Best Value')
plt.plot(x_values, y2_values, 'ro', label='Final Value')

# Conectar os pontos com uma linha
for i in range(len(x_values)):
    if y2_values[i] > y1_values[i]:
        plt.plot([x_values[i], x_values[i]], [y1_values[i], y2_values[i]], 'r--')
    elif y2_values[i] < y1_values[i]:
        plt.plot([x_values[i], x_values[i]], [y1_values[i], y2_values[i]], 'g--')

plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Variação da Categorical Crossentropy Durante a Otimização da Norma L2 Vs Tolerância Relativa')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert the list to a NumPy array for easier manipulation
training_times_array = np.array(training_times)

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(training_times_array, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, training_times_array, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Gerando pontos 3D
x = np.array([point[0] for point in coordenates_values])
y = np.array([point[1] for point in coordenates_values])
z = np.array(tolerances)

# Definindo cores com base na tolerância (ou qualquer outra variável)
colors = z

# Plotando
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x, y, z, c=colors, cmap='plasma')  # Usando cmap='plasma' para um gradiente de cores diferente

plt.title('Número de épocas para encontrar o melhor valor vs Tolerancia Relativa')
ax.set_xlabel('Categorical Crossentropy')
ax.set_ylabel('Norma L2')
ax.set_zlabel('Tolerância Relativa')

# Definindo intervalos para os eixos x e y
ax.set_xticks(np.arange(min(x), max(x)+1, 1))
ax.set_yticks(np.arange(min(y), max(y)+1, 1))

# Adicionando barra de cores
plt.colorbar(sc, label='Tolerância Relativa')

plt.show()

# %%
# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(x, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, x, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Categorical Crossentropy')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(y, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, y, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
sum = x + y

# Calculate the running average with a window size of 3 (adjust as needed)
window_size = 3
running_avg = np.convolve(sum, np.ones(window_size)/window_size, mode='valid')

# Plot the 2D graph
plt.figure(figsize=(8, 6))
plt.plot(tolerances[window_size-1:], running_avg, color='red', linestyle=':', label='Running Average')
plt.plot(tolerances, sum, marker='o', label='Original Data')
plt.xlabel('Relative Tolerance')
plt.ylabel('Norm L2 + Categorical Crossentropy')
plt.title('Number of Epochs vs Relative Tolerance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
def sort_models(CE, L2, Time, Tol, AC, min_indices):
    num_models = len(CE)
    decimal_places = 2

    while True:
        # Ordenar os modelos de acordo com a Categorical Crossentropy
        indices = sorted(range(num_models), key=lambda i: (round(CE[i], decimal_places), round(L2[i], decimal_places), round(Time[i], decimal_places)))

        # Verificar se há empates
        is_tie = False
        for i in range(1, num_models):
            if CE[indices[i]] == CE[indices[i - 1]] and \
               L2[indices[i]] == L2[indices[i - 1]] and \
               Time[indices[i]] == Time[indices[i - 1]]:
                is_tie = True
                break

        # Se não houver empates, terminar o loop
        if not is_tie:
            break

        # Aumentar as casas decimais em caso de empate
        decimal_places += 1

    # Imprimir os modelos ordenados
    for i, idx in enumerate(indices):
        print(f'{i+1}º:')
        print(f' - Model {min_indices[idx]+1}: (Relative Tolerance={Tol[idx]}; Accuracy={AC[idx]})')
        print(f'   + Categorical Crossentropy: {CE[idx]}')
        print(f'   + Norm L2: {L2[idx]}')
        print(f'   + Training Time (seconds): {Time[idx]}')
        print()

    return Tol[0]

# %%
CE, L2, Time, Tol, AC = [], [], [], [], []

for i in range(len(min_indices)):
 CE.append(ce_values_array[min_indices[i]])
 L2.append(l2_values_array[min_indices[i]])
 Time.append(training_times_array[min_indices[i]])
 Tol.append(tolerances[min_indices[i]])
 AC.append(accuracy_values_array[min_indices[i]])

Best_Tolerance = sort_models(CE, L2, Time, Tol, AC, min_indices)
# Out:
# 1º:
#  - Model 29: (Relative Tolerance=23.53125; Accuracy=0.9732000231742859)
#    + Categorical Crossentropy: 0.0948859229683876
#    + Norm L2: 33694.95703125
#    + Training Time (seconds): 94.87313270568848
#
# 2º:
#  - Model 15: (Relative Tolerance=21.890625; Accuracy=0.9664000272750854)
#    + Categorical Crossentropy: 0.114497609436512
#    + Norm L2: 28961.216796875
#    + Training Time (seconds): 46.99989557266235
#
# 3º:
#  - Model 6: (Relative Tolerance=20.8359375; Accuracy=0.9667999744415283)
#    + Categorical Crossentropy: 0.11177074164152145
#    + Norm L2: 29041.404296875
#    + Training Time (seconds): 41.45049858093262

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)

best_ce_loss, best_L2_loss  = float('inf'), float('inf')
upgrading = 0
tolerance = Best_Tolerance
changed = False
first_run = True

current_model, checkpoint = build_model()
best_model, checkpoint = build_model()

while upgrading < 4:

    current_model, checkpoint = clonning(best_model, changed)
    training_history = current_model.fit(train_images, train_labels, validation_data=(validation_images, validation_labels), epochs=1, batch_size=32, verbose=1, callbacks=[checkpoint])

    current_L2 = training_history.history["val_l2_complexity"][0]
    current_CE = training_history.history["val_categorical_crossentropy"][0]

    if (current_CE<best_ce_loss and not changed) or first_run:
      print("Best so far")
      first_run = False
      coordenates[0] += 1
      best_model, checkpoint = clonning(current_model, changed)
      best_ce_loss = current_CE
      best_L2_loss = current_L2
      upgrading = 0
    elif(current_CE<best_ce_loss*(1 + tolerance) and current_L2<best_L2_loss and changed):
      print("Best so far")
      coordenates[1] += 1
      best_model, checkpoint = clonning(current_model, changed)
      best_L2_loss = current_L2
      upgrading = 2
    else:
      upgrading += 1

    if upgrading==2 and not changed:
      best_model, checkpoint = rebuild_model(best_model)
      current_model, checkpoint = rebuild_model(best_model)
      print("loss function changed")
      changed = True
# Out:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2794 - categorical_crossentropy: 0.2794 - l2_complexity: 178429.3438 - accuracy: 0.9196 - val_loss: 0.1518 - val_categorical_crossentropy: 0.1518 - val_l2_complexity: 18155.7559 - val_accuracy: 0.9534
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1328 - categorical_crossentropy: 0.1328 - l2_complexity: 252526.5156 - accuracy: 0.9610 - val_loss: 0.1070 - val_categorical_crossentropy: 0.1070 - val_l2_complexity: 23934.9141 - val_accuracy: 0.9662
# Best so far
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0976 - categorical_crossentropy: 0.0976 - l2_complexity: 317345.4375 - accuracy: 0.9712 - val_loss: 0.0941 - val_categorical_crossentropy: 0.0941 - val_l2_complexity: 29140.9141 - val_accuracy: 0.9716
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0783 - categorical_crossentropy: 0.0783 - l2_complexity: 378747.5938 - accuracy: 0.9766 - val_loss: 0.0906 - val_categorical_crossentropy: 0.0906 - val_l2_complexity: 34204.7695 - val_accuracy: 0.9722
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0658 - categorical_crossentropy: 0.0658 - l2_complexity: 439742.7812 - accuracy: 0.9804 - val_loss: 0.0890 - val_categorical_crossentropy: 0.0890 - val_l2_complexity: 39353.8828 - val_accuracy: 0.9736
# Best so far
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0559 - categorical_crossentropy: 0.0559 - l2_complexity: 501367.0625 - accuracy: 0.9830 - val_loss: 0.0917 - val_categorical_crossentropy: 0.0917 - val_l2_complexity: 44534.6016 - val_accuracy: 0.9730
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0559 - categorical_crossentropy: 0.0559 - l2_complexity: 501367.0625 - accuracy: 0.9830 - val_loss: 0.0917 - val_categorical_crossentropy: 0.0917 - val_l2_complexity: 44534.6016 - val_accuracy: 0.9730
# loss function changed
# 1875/1875 [==============================] - 6s 3ms/step - loss: 12.0488 - categorical_crossentropy: 2.0505 - l2_complexity: 22340.8926 - accuracy: 0.3298 - val_loss: 3.7134e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0583 - val_accuracy: 0.0874
# 1875/1875 [==============================] - 5s 3ms/step - loss: 12.0488 - categorical_crossentropy: 2.0505 - l2_complexity: 22340.8926 - accuracy: 0.3298 - val_loss: 3.7134e-04 - val_categorical_crossentropy: 2.3026 - val_l2_complexity: 0.0583 - val_accuracy: 0.0874

# %%
metrics = best_model.evaluate(test_images, test_labels)
# Out:
# 157/157 [==============================] - 1s 3ms/step - loss: 250.6617 - categorical_crossentropy: 0.1102 - l2_complexity: 39353.8828 - accuracy: 0.9700

# %%
best_model.save('best_model.h5')
